# %%
import pandas as pd
import random 

file_path = './data/ESCO/skills_en.csv'
esco_skills_dataset = pd.read_csv(file_path)

esco_skills_dataset
# Out:
#                     conceptType  \
# 0      KnowledgeSkillCompetence
# 1      KnowledgeSkillCompetence
# 2      KnowledgeSkillCompetence
# 3      KnowledgeSkillCompetence
# 4      KnowledgeSkillCompetence
# ...                         ...
# 13891  KnowledgeSkillCompetence
# 13892  KnowledgeSkillCompetence
# 13893  KnowledgeSkillCompetence
# 13894  KnowledgeSkillCompetence
# 13895  KnowledgeSkillCompetence
#
#                                               conceptUri         skillType  \
# 0      http://data.europa.eu/esco/skill/0005c151-5b5a...  skill/competence
# 1      http://data.europa.eu/esco/skill/00064735-8fad...  skill/competence
# 2      http://data.europa.eu/esco/skill/000709ed-2be5...  skill/competence
# 3      http://data.europa.eu/esco/skill/0007bdc2-dd15...  skill/competence
# 4      http://data.europa.eu/esco/skill/00090cc1-1f27...  skill/competence
# ...                                                  ...               ...
# 13891  http://data.europa.eu/esco/skill/ffef5eb3-a15e...  skill/competence
# 13892  http://data.europa.eu/esco/skill/fff0b074-5a76...  skill/competence
# 13893  http://data.europa.eu/esco/skill/fff0e2cd-d0bd...         knowledge
# 13894  http://data.europa.eu/esco/skill/fff5bc45-b506...  skill/competence
# 13895  http://data.europa.eu/esco/skill/fff74a70-4f82...  skill/competence
#
#                 reuseLevel                                     preferredLabel  \
# 0          sector-specific                               manage musical staff
# 1      occupation-specific                  supervise correctional procedures
# 2          sector-specific                    apply anti-oppressive practices
# 3          sector-specific  control compliance of railway vehicles regulat...
# 4             cross-sector                        identify available services
# ...                    ...                                                ...
# 13891      sector-specific  remediate healthcare user's occupational perfo...
# 13892      sector-specific               install transport equipment lighting
# 13893      sector-specific                        natural language processing
# 13894         cross-sector                 coordinate construction activities
# 13895         cross-sector                  position guardrails and toeboards
#
#                                                altLabels hiddenLabels  \
# 0      manage staff of music\ncoordinate duties of mu...          NaN
# 1      oversee prison procedures\nmanage correctional...          NaN
# 2      apply non-oppressive practices\napply an anti-...          NaN
# 3      monitoring of compliance with railway vehicles...          NaN
# 4      establish available services\nidentify availab...          NaN
# ...                                                  ...          ...
# 13891  restore healthcare user's occupational perform...          NaN
# 13892  install transport equipment illumination\nfix ...          NaN
# 13893                   natural language processing\nNLP          NaN
# 13894  reviewing construction progress\nconstruction ...          NaN
# 13895  positioning guardrails and toeboards\nattachme...          NaN
#
#          status              modifiedDate scopeNote definition  \
# 0      released      2016-12-20T17:43:43Z       NaN        NaN
# 1      released      2016-12-20T20:17:49Z       NaN        NaN
# 2      released      2016-12-20T19:18:19Z       NaN        NaN
# 3      released      2016-12-20T20:02:19Z       NaN        NaN
# 4      released      2016-12-20T20:15:17Z       NaN        NaN
# ...         ...                       ...       ...        ...
# 13891  released      2016-12-20T19:25:53Z       NaN        NaN
# 13892  released      2016-12-20T20:03:21Z       NaN        NaN
# 13893  released  2022-07-05T14:34:09.904Z       NaN        NaN
# 13894  released      2016-12-20T18:22:35Z       NaN        NaN
# 13895  released      2016-12-20T18:24:23Z       NaN        NaN
#
#                                                 inScheme  \
# 0      http://data.europa.eu/esco/concept-scheme/skil...
# 1      http://data.europa.eu/esco/concept-scheme/memb...
# 2      http://data.europa.eu/esco/concept-scheme/skil...
# 3      http://data.europa.eu/esco/concept-scheme/skil...
# 4      http://data.europa.eu/esco/concept-scheme/memb...
# ...                                                  ...
# 13891  http://data.europa.eu/esco/concept-scheme/memb...
# 13892  http://data.europa.eu/esco/concept-scheme/skil...
# 13893  http://data.europa.eu/esco/concept-scheme/skil...
# 13894  http://data.europa.eu/esco/concept-scheme/skil...
# 13895  http://data.europa.eu/esco/concept-scheme/skil...
#
#                                              description
# 0      Assign and manage staff tasks in areas such as...
# 1      Supervise the operations of a correctional fac...
# 2      Identify oppression in societies, economies, c...
# 3      Inspect rolling stock, components and systems ...
# 4      Identify the different services available for ...
# ...                                                  ...
# 13891  Remediate or restore the cognitive, sensorimot...
# 13892  Install lighting elements in transport equipme...
# 13893  The technologies which enable ICT devices to u...
# 13894  Coordinate the activities of several construct...
# 13895  Attach guardrails and toeboards to the scaffol...
#
# [13896 rows x 13 columns]

# %%
file_path = './data/ESCO/occupations_en.csv'
esco_occupations_dataset = pd.read_csv(file_path)

esco_occupations_dataset
# Out:
#      conceptType                                         conceptUri  \
# 0     Occupation  http://data.europa.eu/esco/occupation/00030d09...
# 1     Occupation  http://data.europa.eu/esco/occupation/000e93a3...
# 2     Occupation  http://data.europa.eu/esco/occupation/0019b951...
# 3     Occupation  http://data.europa.eu/esco/occupation/0022f466...
# 4     Occupation  http://data.europa.eu/esco/occupation/002da35b...
# ...          ...                                                ...
# 3002  Occupation  http://data.europa.eu/esco/occupation/ff656b3a...
# 3003  Occupation  http://data.europa.eu/esco/occupation/ff8d4065...
# 3004  Occupation  http://data.europa.eu/esco/occupation/ffa4dd5d...
# 3005  Occupation  http://data.europa.eu/esco/occupation/ffade2f4...
# 3006  Occupation  http://data.europa.eu/esco/occupation/ffc292f1...
#
#       iscoGroup                        preferredLabel  \
# 0          2654                    technical director
# 1          8121        metal drawing machine operator
# 2          7543            precision device inspector
# 3          3155         air traffic safety technician
# 4          2431           hospitality revenue manager
# ...         ...                                   ...
# 3002       2120                           demographer
# 3003       9612                       sorter labourer
# 3004       5414                    armoured car guard
# 3005       2422  civil service administrative officer
# 3006       8211               motor vehicle assembler
#
#                                               altLabels hiddenLabels  \
# 0     technical and operations director\nhead of tec...          NaN
# 1     metal drawing machine operator\nmetal drawing ...          NaN
# 2     inspector of precision instruments\nprecision ...          NaN
# 3     air traffic safety electronics hardware specia...          NaN
# 4     hospitality revenues manager\nyield manager\nh...          NaN
# ...                                                 ...          ...
# 3002  demography research analyst\ndemography studie...          NaN
# 3003  sorter laborer\ngrader\nyard labourer\nrecycle...          NaN
# 3004  armoured truck escort\ntruck escort\narmored c...          NaN
# 3005  government administrative officer\ncivil servi...          NaN
# 3006  automobile assembler\nmotor vehicle assembler\...          NaN
#
#         status              modifiedDate  \
# 0     released      2016-07-05T13:58:41Z
# 1     released      2016-07-05T17:09:43Z
# 2     released      2016-07-06T09:21:20Z
# 3     released      2017-01-17T11:40:37Z
# 4     released      2017-01-17T13:33:42Z
# ...        ...                       ...
# 3002  released  2022-07-05T14:42:21.456Z
# 3003  released  2021-12-08T20:18:37.546Z
# 3004  released  2022-01-13T09:51:50.643Z
# 3005  released      2016-07-05T16:17:26Z
# 3006  released  2020-12-09T11:33:03.042Z
#
#                                 regulatedProfessionNote scopeNote definition  \
# 0     http://data.europa.eu/esco/regulated-professio...       NaN        NaN
# 1     http://data.europa.eu/esco/regulated-professio...       NaN        NaN
# 2     http://data.europa.eu/esco/regulated-professio...       NaN        NaN
# 3     http://data.europa.eu/esco/regulated-professio...       NaN        NaN
# 4     http://data.europa.eu/esco/regulated-professio...       NaN        NaN
# ...                                                 ...       ...        ...
# 3002  http://data.europa.eu/esco/regulated-professio...       NaN        NaN
# 3003  http://data.europa.eu/esco/regulated-professio...       NaN        NaN
# 3004  http://data.europa.eu/esco/regulated-professio...       NaN        NaN
# 3005  http://data.europa.eu/esco/regulated-professio...       NaN        NaN
# 3006  http://data.europa.eu/esco/regulated-professio...       NaN        NaN
#
#                                                inScheme  \
# 0     http://data.europa.eu/esco/concept-scheme/occu...
# 1     http://data.europa.eu/esco/concept-scheme/memb...
# 2     http://data.europa.eu/esco/concept-scheme/occu...
# 3     http://data.europa.eu/esco/concept-scheme/memb...
# 4     http://data.europa.eu/esco/concept-scheme/memb...
# ...                                                 ...
# 3002  http://data.europa.eu/esco/concept-scheme/8ae4...
# 3003  http://data.europa.eu/esco/concept-scheme/memb...
# 3004  http://data.europa.eu/esco/concept-scheme/occu...
# 3005  http://data.europa.eu/esco/concept-scheme/occu...
# 3006  http://data.europa.eu/esco/concept-scheme/memb...
#
#                                             description       code
# 0     Technical directors realise the artistic visio...   2654.1.7
# 1     Metal drawing machine operators set up and ope...     8121.4
# 2     Precision device inspectors make sure precisio...  7543.10.3
# 3     Air traffic safety technicians provide technic...     3155.1
# 4     Hospitality revenue managers maximise revenue ...     2431.9
# ...                                                 ...        ...
# 3002  Demographers study a variety of parameters rel...     2120.2
# 3003  Sorter labourers sort recyclable materials and...     9612.2
# 3004  Armoured car guards ensure the safe transporta...   5414.1.2
# 3005  Civil service administrative officers perform ...     2422.1
# 3006  Motor vehicle assemblers install and put prefa...     8211.5
#
# [3007 rows x 14 columns]

# %%
file_path = './data/ESCO/occupationSkillRelations_en.csv'
esco_skills_occupations_dataset = pd.read_csv(file_path)

esco_skills_occupations_dataset
# Out:
#                                             occupationUri relationType  \
# 0       http://data.europa.eu/esco/occupation/00030d09...    essential
# 1       http://data.europa.eu/esco/occupation/00030d09...    essential
# 2       http://data.europa.eu/esco/occupation/00030d09...    essential
# 3       http://data.europa.eu/esco/occupation/00030d09...    essential
# 4       http://data.europa.eu/esco/occupation/00030d09...    essential
# ...                                                   ...          ...
# 123850  http://data.europa.eu/esco/occupation/ffc292f1...     optional
# 123851  http://data.europa.eu/esco/occupation/ffc292f1...     optional
# 123852  http://data.europa.eu/esco/occupation/ffc292f1...     optional
# 123853  http://data.europa.eu/esco/occupation/ffc292f1...     optional
# 123854  http://data.europa.eu/esco/occupation/ffc292f1...     optional
#
#                skillType                                           skillUri
# 0              knowledge  http://data.europa.eu/esco/skill/fed5b267-73fa...
# 1       skill/competence  http://data.europa.eu/esco/skill/05bc7677-5a64...
# 2       skill/competence  http://data.europa.eu/esco/skill/271a36a0-bc7a...
# 3       skill/competence  http://data.europa.eu/esco/skill/47ed1d37-971b...
# 4       skill/competence  http://data.europa.eu/esco/skill/591dd514-735b...
# ...                  ...                                                ...
# 123850  skill/competence  http://data.europa.eu/esco/skill/df487cde-38d4...
# 123851  skill/competence  http://data.europa.eu/esco/skill/e975b791-b488...
# 123852  skill/competence  http://data.europa.eu/esco/skill/ed938748-60ae...
# 123853  skill/competence  http://data.europa.eu/esco/skill/f30a7ea4-77dd...
# 123854  skill/competence  http://data.europa.eu/esco/skill/fd60bbcc-c3b6...
#
# [123855 rows x 4 columns]

# %%
ui_dev_row = esco_occupations_dataset[esco_occupations_dataset["preferredLabel"] == "user interface developer"]
ui_dev_row
# Out:
#      conceptType                                         conceptUri  \
# 1648  Occupation  http://data.europa.eu/esco/occupation/866c7813...
#
#       iscoGroup            preferredLabel  \
# 1648       2512  user interface developer
#
#                                               altLabels hiddenLabels  \
# 1648  user interface developers\nUI developers\nfron...          NaN
#
#         status              modifiedDate  \
# 1648  released  2022-06-10T12:29:13.844Z
#
#                                 regulatedProfessionNote scopeNote definition  \
# 1648  http://data.europa.eu/esco/regulated-professio...       NaN        NaN
#
#                                                inScheme  \
# 1648  http://data.europa.eu/esco/concept-scheme/memb...
#
#                                             description    code
# 1648  User interface developers implement, code, doc...  2512.5

# %%
it_occupations = esco_occupations_dataset[esco_occupations_dataset['iscoGroup'].astype(str).str.startswith('25')]

it_occupations
# Out:
#      conceptType                                         conceptUri  \
# 62    Occupation  http://data.europa.eu/esco/occupation/0464b062...
# 68    Occupation  http://data.europa.eu/esco/occupation/04ba4d6c...
# 109   Occupation  http://data.europa.eu/esco/occupation/07e60525...
# 118   Occupation  http://data.europa.eu/esco/occupation/092fdeeb...
# 136   Occupation  http://data.europa.eu/esco/occupation/0ab5c12c...
# ...          ...                                                ...
# 2691  Occupation  http://data.europa.eu/esco/occupation/e1c72b5f...
# 2705  Occupation  http://data.europa.eu/esco/occupation/e3229e40...
# 2851  Occupation  http://data.europa.eu/esco/occupation/f2b15a0e...
# 2950  Occupation  http://data.europa.eu/esco/occupation/faed411a...
# 2992  Occupation  http://data.europa.eu/esco/occupation/fe0fa514...
#
#       iscoGroup                     preferredLabel  \
# 62         2529         ICT security administrator
# 68         2512                   software analyst
# 109        2511               integration engineer
# 118        2513  search engine optimisation expert
# 136        2519                   ICT test analyst
# ...         ...                                ...
# 2691       2511               ICT system architect
# 2705       2511                 computer scientist
# 2851       2512                 software developer
# 2950       2511            user experience analyst
# 2992       2511               ICT business analyst
#
#                                               altLabels hiddenLabels  \
# 62    system security administrator\ninformation sec...          NaN
# 68    programming analyst\nsoftware requirement anal...          NaN
# 109   software integration engineer\nICT integration...          NaN
# 118   search engine optimization expert\nsearch engi...          NaN
# 136    test designer\nICT test analyst\nIT test analyst          NaN
# ...                                                 ...          ...
# 2691  ICT systems architects\nIT system architect\ns...          NaN
# 2705  IT scientist\nICT science researcher\ncomputer...          NaN
# 2851  software specialist\nsoftware developers\nprog...          NaN
# 2950  user experience officer\nusability analyst\nus...          NaN
# 2992  ICT business analyst\nICT business analysts\nb...          NaN
#
#         status              modifiedDate  \
# 62    released  2021-04-06T14:42:20.783Z
# 68    released      2016-12-21T12:09:45Z
# 109   released  2021-01-21T15:20:41.381Z
# 118   released      2016-07-05T17:01:40Z
# 136   released      2016-07-05T17:08:30Z
# ...        ...                       ...
# 2691  released  2022-06-17T10:17:01.324Z
# 2705  released  2022-07-05T14:42:21.456Z
# 2851  released  2022-06-10T12:29:13.844Z
# 2950  released  2022-06-17T10:17:01.324Z
# 2992  released      2017-02-02T12:46:22Z
#
#                                 regulatedProfessionNote  \
# 62    http://data.europa.eu/esco/regulated-professio...
# 68    http://data.europa.eu/esco/regulated-professio...
# 109   http://data.europa.eu/esco/regulated-professio...
# 118   http://data.europa.eu/esco/regulated-professio...
# 136   http://data.europa.eu/esco/regulated-professio...
# ...                                                 ...
# 2691  http://data.europa.eu/esco/regulated-professio...
# 2705  http://data.europa.eu/esco/regulated-professio...
# 2851  http://data.europa.eu/esco/regulated-professio...
# 2950  http://data.europa.eu/esco/regulated-professio...
# 2992  http://data.europa.eu/esco/regulated-professio...
#
#                                               scopeNote definition  \
# 62                                                  NaN        NaN
# 68                                                  NaN        NaN
# 109   Includes people performing managerial activities.        NaN
# 118                                                 NaN        NaN
# 136                                                 NaN        NaN
# ...                                                 ...        ...
# 2691  Excludes people performing development activit...        NaN
# 2705  Includes people performing in-house research a...        NaN
# 2851        Includes people performing software design.        NaN
# 2950                                                NaN        NaN
# 2992  Excludes people performing development activit...        NaN
#
#                                                inScheme  \
# 62    http://data.europa.eu/esco/concept-scheme/occu...
# 68    http://data.europa.eu/esco/concept-scheme/occu...
# 109   http://data.europa.eu/esco/concept-scheme/occu...
# 118   http://data.europa.eu/esco/concept-scheme/occu...
# 136   http://data.europa.eu/esco/concept-scheme/memb...
# ...                                                 ...
# 2691  http://data.europa.eu/esco/concept-scheme/memb...
# 2705  http://data.europa.eu/esco/concept-scheme/occu...
# 2851  http://data.europa.eu/esco/concept-scheme/occu...
# 2950  http://data.europa.eu/esco/concept-scheme/occu...
# 2992  http://data.europa.eu/esco/concept-scheme/memb...
#
#                                             description     code
# 62    ICT security administrators plan and carry out...   2529.6
# 68    Software analysts elicit and prioritise user r...   2512.2
# 109   Integration engineers develop and implement so...  2511.17
# 118   Search engine optimisation experts increase th...   2513.2
# 136   ICT test analysts work in testing environments...   2519.6
# ...                                                 ...      ...
# 2691  ICT system architects design architecture, com...  2511.14
# 2705  Computer scientists conduct research in comput...   2511.1
# 2851  Software developers implement or program all k...   2512.4
# 2950  User experience analysts assess client interac...  2511.19
# 2992  ICT business analysts are in charge of analysi...   2511.9
#
# [69 rows x 14 columns]

# %%
def get_random_occupation_uri(dataset):
    """
    Selects a random item from the given dataset and returns its occupationUri.

    Parameters:
    - dataset (pd.DataFrame): The dataset containing occupation URIs.

    Returns:
    - str: A random occupation URI from the dataset.
    """

    if not dataset.empty and 'conceptUri' in dataset.columns:
        random_index = random.randint(0, len(dataset) - 1)
        random_item = dataset.iloc[random_index]
        return random_item['conceptUri']
    else:
        return "Dataset is empty or does not contain the 'Occupation URI' column."

    
random_occupation_uri = get_random_occupation_uri(it_occupations)
random_occupation_uri
# Out:
# 'http://data.europa.eu/esco/occupation/22987b58-dbfa-4ecd-ae3f-82dd209255f6'

# %%
def get_random_skills_and_knowledge_uris(skill_occupation_dataset, occupation_uri, count_range=(0, 2)):
    """
    Retrieves 0 to 2 random skills and 0 to 2 knowledge components for a given occupation URI,
    ensuring at least one component is returned.

    Parameters:
    - skill_occupation_dataset (pd.DataFrame): The dataset containing occupation URIs and related skills/knowledge.
    - occupation_uri (str): The occupation URI for which to retrieve skills/knowledge.
    - count_range (tuple): The range (inclusive) of the number of skills/knowledge to retrieve. Default is (0, 2).

    Returns:
    - List[str]: A list containing the URIs of the randomly selected skills and knowledge components.
    """
    # Assuming a way to differentiate skills from knowledge, e.g., a column 'type' with values 'skill' or 'knowledge'
    skills = skill_occupation_dataset[
        (skill_occupation_dataset["occupationUri"] == occupation_uri) &
        (skill_occupation_dataset["relationType"] == 'essential') &
        (skill_occupation_dataset["skillType"] == 'skill/competence')
    ]
    
    knowledge = skill_occupation_dataset[
        (skill_occupation_dataset["occupationUri"] == occupation_uri) &
        (skill_occupation_dataset["relationType"] == 'essential') &
        (skill_occupation_dataset["skillType"] == 'knowledge')
    ]
    
    # Randomly sample skills and knowledge
    skills_sampled = skills.sample(n=random.randint(*count_range), replace=True) if not skills.empty else pd.DataFrame()
    knowledge_sampled = knowledge.sample(n=random.randint(*count_range), replace=True) if not knowledge.empty else pd.DataFrame()
    
    # Ensure at least one component is selected
    if skills_sampled.empty and knowledge_sampled.empty:
        if not skills.empty:
            skills_sampled = skills.sample(n=1)
        elif not knowledge.empty:
            knowledge_sampled = knowledge.sample(n=1)

    # Combine and return URIs
    combined_uris = pd.concat([skills_sampled, knowledge_sampled])['skillUri'].unique().tolist()
    return combined_uris


random_skills_knowledge = get_random_skills_and_knowledge_uris(
    esco_skills_occupations_dataset,
    random_occupation_uri
)

random_skills_knowledge
# Out:
# ['http://data.europa.eu/esco/skill/1e7ed56a-6d6b-422f-962e-38543d150755',
#  'http://data.europa.eu/esco/skill/1ca140f8-d8aa-4e02-8ddc-31cbf75dd7ae',
#  'http://data.europa.eu/esco/skill/3a5231a0-8c30-48ee-b671-08e2debd4441']

# %%
def create_job_posting_prompt(occupation_uri, skill_uris, occupations_dataset, skills_dataset):
    """
    Creates a prompt for a job posting for a given occupation, including specified skills or knowledge components
    with appropriate annotations.

    Parameters:
    - occupation_uri (str): The URI of the occupation.
    - skill_uris (list): A list of skill URIs.
    - occupations_dataset (pd.DataFrame): The occupations dataset.
    - skills_dataset (pd.DataFrame): The skills dataset.

    Returns:
    - str: A crafted prompt for the job posting.
    """
    # Get the occupation name
    occupation_name = occupations_dataset[occupations_dataset['conceptUri'] == occupation_uri]['preferredLabel'].iloc[0]
    
    # Filter the skills dataset to find matches for the provided skill URIs
    matched_skills = skills_dataset[skills_dataset['conceptUri'].isin(skill_uris)]
    
    # Prepare labels and types for the matched skills, without pre-annotation
    components = matched_skills.apply(lambda row: f"skill component: {row['preferredLabel']}".replace("skill/competence", "skill"), axis=1).tolist()
    components_str = ", ".join(components)
    
    # Crafting the prompt with instructions for GPT to annotate
    prompt = (f"A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. "
              "Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks. "
              f"Given the abovementioned definitions write a sample sentence from a job posting for a \"{occupation_name}\" role. It should contain the following components: {components_str}. "
              "Annotate these components in your response, using '##' at the beginning and end for skills, and '@@' at the beginning and end for knowledge components."
              "The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise, yet creative.")

    return prompt

sample_prompt = create_job_posting_prompt(
    random_occupation_uri, 
    random_skills_knowledge, 
    esco_occupations_dataset, 
    esco_skills_dataset
)
print(sample_prompt)
# Out:
# A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "ICT intelligent systems designer" role. It should contain the following components: skill component: microwave principles, skill component: manage changes in ICT system, skill component: organisational policies. Annotate these components in your response, using '##' at the beginning and end for skills, and '@@' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise, yet creative.

# %%
prompts = []
for _ in range(100):
    random_occupation_uri = get_random_occupation_uri(it_occupations)
    random_skill_uris = get_random_skills_and_knowledge_uris(
        esco_skills_occupations_dataset, 
        random_occupation_uri, 
    )
    prompt = create_job_posting_prompt(
        random_occupation_uri, 
        random_skill_uris, 
        esco_occupations_dataset, 
        esco_skills_dataset
    )
    prompts.append(prompt)
    
prompts
# Out:
# ['A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "ICT resilience manager" role. It should contain the following components: skill component: cyber security. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "embedded systems software developer" role. It should contain the following components: skill component: computer programming, skill component: integrated development environment software. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "numerical tool and process control programmer" role. It should contain the following components: skill component: Lisp, skill component: Scala. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "ICT system analyst" role. It should contain the following components: skill component: attack vectors, skill component: analyse business processes, skill component: ICT infrastructure, skill component: define technical requirements. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "software tester" role. It should contain the following components: skill component: report test findings, skill component: replicate customer software issues. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "ICT system developer" role. It should contain the following components: skill component: provide technical documentation, skill component: develop automated migration methods, skill component: computer programming. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "ICT system developer" role. It should contain the following components: skill component: migrate existing data, skill component: computer programming, skill component: interpret technical texts, skill component: ICT system programming. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "industrial mobile devices software developer" role. It should contain the following components: skill component: use an application-specific interface, skill component: embedded systems. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "ICT security administrator" role. It should contain the following components: skill component: operating systems. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "mobile application developer" role. It should contain the following components: skill component: computer programming, skill component: collect customer feedback on applications, skill component: interpret technical texts. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "ICT capacity planner" role. It should contain the following components: skill component: statistical analysis system software. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "embedded systems software developer" role. It should contain the following components: skill component: develop software prototype, skill component: use software libraries. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "search engine optimisation expert" role. It should contain the following components: skill component: keywords in digital content, skill component: sales strategies. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "ICT auditor manager" role. It should contain the following components: skill component: develop audit plan. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "ICT security manager" role. It should contain the following components: skill component: ICT problem management techniques. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "web developer" role. It should contain the following components: skill component: ICT debugging tools. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "ICT integration tester" role. It should contain the following components: skill component: address problems critically. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "integration engineer" role. It should contain the following components: skill component: software components suppliers, skill component: hardware components suppliers. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "database administrator" role. It should contain the following components: skill component: administer ICT system, skill component: manage database, skill component: database development tools. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "database integrator" role. It should contain the following components: skill component: integrate ICT data, skill component: manage ICT legacy implication. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "ICT security administrator" role. It should contain the following components: skill component: manage IT security compliances, skill component: organisational resilience, skill component: database development tools. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "ICT test analyst" role. It should contain the following components: skill component: report test findings, skill component: plan software testing. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "ICT business analyst" role. It should contain the following components: skill component: legal requirements of ICT products. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "ICT capacity planner" role. It should contain the following components: skill component: forecast workload, skill component: statistical analysis system software, skill component: ICT infrastructure. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "web developer" role. It should contain the following components: skill component: provide technical documentation, skill component: use an application-specific interface, skill component: content development processes. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "ICT system analyst" role. It should contain the following components: skill component: systems development life-cycle, skill component: interact with users to gather requirements, skill component: create data models. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "ICT consultant" role. It should contain the following components: skill component: ICT sales methodologies. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "ICT system integration consultant" role. It should contain the following components: skill component: systems development life-cycle. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "ICT application configurator" role. It should contain the following components: skill component: create flowchart diagram, skill component: integrated development environment software. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "data quality specialist" role. It should contain the following components: skill component: manage standards for data exchange. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "ICT network administrator" role. It should contain the following components: skill component: provide technical documentation, skill component: computer programming, skill component: ICT security legislation, skill component: forecast future ICT network needs. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "user interface developer" role. It should contain the following components: skill component: software UI design patterns, skill component: use methodologies for user-centered design, skill component: graphics editor software. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "ICT application developer" role. It should contain the following components: skill component: propose ICT solutions to business problems, skill component: computer programming, skill component: service-oriented modelling. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "database administrator" role. It should contain the following components: skill component: resource description framework query language. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "ICT system administrator" role. It should contain the following components: skill component: hardware components, skill component: manage system testing. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "ICT auditor manager" role. It should contain the following components: skill component: ensure compliance with legal requirements, skill component: attack vectors, skill component: audit techniques. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "ICT system tester" role. It should contain the following components: skill component: software anomalies, skill component: provide software testing documentation. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "user interface developer" role. It should contain the following components: skill component: web programming, skill component: integrated development environment software. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "ICT security engineer" role. It should contain the following components: skill component: ICT security standards, skill component: define technical requirements. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "blockchain architect" role. It should contain the following components: skill component: business processes. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "system configurator" role. It should contain the following components: skill component: migrate existing data, skill component: configure ICT system. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "software analyst" role. It should contain the following components: skill component: define technical requirements, skill component: define software architecture. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "software tester" role. It should contain the following components: skill component: software metrics. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "system configurator" role. It should contain the following components: skill component: cognitive psychology, skill component: interpret technical texts, skill component: ICT infrastructure. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "ICT application developer" role. It should contain the following components: skill component: propose ICT solutions to business problems. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "ICT auditor manager" role. It should contain the following components: skill component: attack vectors, skill component: quality standards, skill component: build business relationships. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "ICT system tester" role. It should contain the following components: skill component: identify ICT system weaknesses. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "digital games developer" role. It should contain the following components: skill component: debug software. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "ICT change and configuration manager" role. It should contain the following components: skill component: ICT project management methodologies, skill component: DevOps. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "ICT application developer" role. It should contain the following components: skill component: integrated development environment software. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "ICT disaster recovery analyst" role. It should contain the following components: skill component: product usage risks analysis, skill component: ICT recovery techniques, skill component: perform backups. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "database designer" role. It should contain the following components: skill component: assess ICT knowledge, skill component: database development tools, skill component: analyse business requirements. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
# ...
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "ICT change and configuration manager" role. It should contain the following components: skill component: train employees, skill component: ICT process quality models. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "cloud engineer" role. It should contain the following components: skill component: plan migration to cloud, skill component: develop with cloud services, skill component: cyber security, skill component: ICT system programming. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "data quality specialist" role. It should contain the following components: skill component: use data processing techniques, skill component: address problems critically. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "database integrator" role. It should contain the following components: skill component: balance database resources, skill component: verify formal ICT specifications. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "ICT system architect" role. It should contain the following components: skill component: business process modelling. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "database administrator" role. It should contain the following components: skill component: system backup best practice, skill component: data quality assessment. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "data scientist" role. It should contain the following components: skill component: interact professionally in research and professional environments, skill component: resource description framework query language, skill component: develop professional network with researchers and scientists. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "ICT application configurator" role. It should contain the following components: skill component: computer programming, skill component: debug software, skill component: ICT debugging tools, skill component: analyse software specifications. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "user experience analyst" role. It should contain the following components: skill component: cognitive psychology, skill component: assess users\' interaction with ICT applications, skill component: human-computer interaction, skill component: report analysis results. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "industrial mobile devices software developer" role. It should contain the following components: skill component: use software libraries. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "ICT quality assurance manager" role. It should contain the following components: skill component: perform quality audits. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "system configurator" role. It should contain the following components: skill component: develop automated migration methods, skill component: ICT system user requirements. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "ICT network administrator" role. It should contain the following components: skill component: interpret technical texts. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "database administrator" role. It should contain the following components: skill component: perform backups. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "ICT application configurator" role. It should contain the following components: skill component: debug software. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "user interface developer" role. It should contain the following components: skill component: use software libraries. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.',
#  'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "ICT intelligent systems designer" role. It should contain the following components: skill component: visual presentation techniques, skill component: resource description framework query language. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.']

# %%
from dotenv import load_dotenv
import ast

load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-4-0613", temperature=0)

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages([
    ("user", "{input}")
])

# %%
from langchain_core.output_parsers import StrOutputParser

output_parser = StrOutputParser()

# %%
prompts[20]
# Out:
# 'A knowledge component is understood as factual or theoretical information, including specifics, principles, and certifications pertinent to a field. Skill component represents an ability or expertise, often demonstrated through verbs or adjective-noun combinations, focused on job-related tasks.Given the abovementioned definitions write a sample sentence from a job posting for a "ICT security administrator" role. It should contain the following components: skill component: manage IT security compliances, skill component: organisational resilience, skill component: database development tools. Annotate these components in your response, using \'##\' at the beginning and end for skills, and \'@@\' at the beginning and end for knowledge components.The response should not contain any additional skills and knowledge components, apart from the ones mentioned above. The response should not contain addional job details. The response should be consise.'

# %%
chain = prompt | llm | output_parser

chain.invoke({"input": prompts[20]})
# Out:
# 'The ICT Security Administrator role requires the ability to ##manage IT security compliances##, demonstrate ##organisational resilience##, and proficiency in using ##database development tools##.'

# %%
results = []
for current_prompt in prompts:
    results.append(chain.invoke({"input": current_prompt}))

# %%
cleaned_results = [s[1:-1] if s.startswith('"') and s.endswith('"') else s for s in results]

cleaned_results[:5]
# Out:
# ['Applicants must have @@knowledge of ICT resilience principles@@ and ##expertise in cyber security##.',
#  'Seeking an embedded systems software developer with strong ##computer programming## skills and proficiency in using ##integrated development environment software##.',
#  'Applicants must have proficiency in ##Lisp## and ##Scala## programming languages.',
#  'We are seeking an ICT System Analyst with the ability to understand and identify ##attack vectors##, ##analyse business processes##, comprehend the complexities of ##ICT infrastructure##, and ##define technical requirements##.',
#  'Seeking a software tester with the ability to ##report test findings## and ##replicate customer software issues##.']

# %%
cleaned_results
# Out:
# ['Applicants must have @@knowledge of ICT resilience principles@@ and ##expertise in cyber security##.',
#  'Seeking an embedded systems software developer with strong ##computer programming## skills and proficiency in using ##integrated development environment software##.',
#  'Applicants must have proficiency in ##Lisp## and ##Scala## programming languages.',
#  'We are seeking an ICT System Analyst with the ability to understand and identify ##attack vectors##, ##analyse business processes##, comprehend the complexities of ##ICT infrastructure##, and ##define technical requirements##.',
#  'Seeking a software tester with the ability to ##report test findings## and ##replicate customer software issues##.',
#  'The ICT system developer role requires the ability to ##provide technical documentation##, ##develop automated migration methods##, and expertise in ##computer programming##.',
#  'The ideal candidate for the ICT system developer role should be able to ##migrate existing data##, possess strong ##computer programming## skills, have the ability to ##interpret technical texts##, and demonstrate proficiency in ##ICT system programming##.',
#  'Seeking an industrial mobile devices software developer with the ability to ##use an application-specific interface## and expertise in ##embedded systems##.',
#  'Applicants must have a deep @@knowledge of ICT security principles@@ and the ##ability to operate various operating systems##.',
#  'Looking for a mobile application developer with strong ##computer programming## skills, ability to ##collect customer feedback on applications##, and the capacity to ##interpret technical texts##.',
#  'Applicants must have a deep @@understanding of ICT capacity planning@@ and the ability to use ##statistical analysis system software## effectively.',
#  'Seeking an Embedded Systems Software Developer to ##develop software prototypes## and ##use software libraries##.',
#  'Looking for a search engine optimisation expert with a proven ability to incorporate ##keywords in digital content## and develop effective ##sales strategies##.',
#  'We are seeking an @@ICT auditor manager@@ who can ##develop audit plans## effectively.',
#  'The ideal candidate should have a deep understanding of @@ICT security principles@@ and be proficient in ##ICT problem management techniques##.',
#  'Applicants must have a solid understanding of @@web development principles@@ and proficiency in using ##ICT debugging tools##.',
#  'Applicants must have @@a deep understanding of ICT integration testing@@ and the ability to ##address problems critically##.',
#  'Looking for an Integration Engineer with the ##software components suppliers## skill and the ability to work with ##hardware components suppliers##.',
#  'Seeking a Database Administrator with the ability to ##administer ICT systems##, ##manage databases##, and utilize ##database development tools##.',
#  'Seeking a database integrator with the ability to ##integrate ICT data## and ##manage ICT legacy implications##.',
#  'The ideal candidate will be able to ##manage IT security compliances##, demonstrate strong ##organisational resilience##, and have proficiency in using ##database development tools##.',
#  'The ICT Test Analyst role requires the ability to ##plan software testing## and ##report test findings##.',
#  'Applicants must have @@knowledge of ICT business analysis@@ and ##ability to understand and apply legal requirements of ICT products##.',
#  'The ideal candidate for the ICT capacity planner role should have the ability to ##forecast workload##, proficiency in using ##statistical analysis system software##, and a deep understanding of ##ICT infrastructure##.',
#  'The ideal candidate for the web developer role should be able to ##provide technical documentation##, proficiently ##use an application-specific interface##, and understand the ##content development processes##.',
#  'As an ICT System Analyst, you will need to have the ability to ##interact with users to gather requirements##, apply your expertise in ##systems development life-cycle##, and ##create data models##.',
#  'The ideal candidate should have a deep understanding of @@ICT sales methodologies@@ and be proficient in ##ICT sales methodologies##.',
#  'Applicants must have @@knowledge of ICT system integration@@ and ##experience in systems development life-cycle##.',
#  'The ICT application configurator role requires the ability to ##create flowchart diagrams## and proficiency in using ##integrated development environment software##.',
#  '@@Understanding of data quality principles@@ is required, with the ability to ##manage standards for data exchange##.',
#  'The ICT network administrator role requires the ability to ##provide technical documentation##, expertise in ##computer programming##, a thorough understanding of ##ICT security legislation##, and the capacity to ##forecast future ICT network needs##.',
#  'Seeking a User Interface Developer with the ability to ##use methodologies for user-centered design##, proficiency in ##software UI design patterns##, and experience with ##graphics editor software##.',
#  'We are seeking an ICT application developer who can ##propose ICT solutions to business problems##, has strong ##computer programming## skills, and is proficient in ##service-oriented modelling##.',
#  'Applicants must have a solid understanding of @@database administration@@ principles and be proficient in ##resource description framework query language##.',
#  'We are seeking an ICT System Administrator with the ability to ##manage system testing## and a strong expertise in ##hardware components##.',
#  'As an ICT Auditor Manager, you will need to ##ensure compliance with legal requirements##, understand and mitigate ##attack vectors##, and apply effective ##audit techniques##.',
#  'Seeking an ICT system tester with the ability to identify and rectify ##software anomalies##, and the expertise to ##provide software testing documentation##.',
#  'Looking for a User Interface Developer with strong ##web programming## skills and proficiency in using ##integrated development environment software##.',
#  'The ideal candidate should have the ability to ##define technical requirements## and a strong understanding of ##ICT security standards##.',
#  'Applicants must have a deep understanding of @@blockchain principles@@ and the ability to ##design and implement business processes##.',
#  'Looking for a system configurator with the ability to ##migrate existing data## and ##configure ICT system##.',
#  'The ideal candidate for the Software Analyst role should be able to ##define technical requirements## and ##define software architecture##.',
#  'Applicants must have a deep @@understanding of software testing principles@@ and the ability to use ##software metrics## effectively.',
#  'System Configurator needed with strong ##cognitive psychology## skills to understand user needs, ability to ##interpret technical texts## for system configuration, and expertise in managing ##ICT infrastructure##.',
#  '@@Familiarity with ICT application development@@ is required, with the ability to ##propose ICT solutions to business problems##.',
#  'The ideal candidate for the ICT Auditor Manager role should have a strong understanding of ##attack vectors##, be able to maintain high ##quality standards##, and possess the ability to ##build business relationships##.',
#  'Applicants must have the ability to ##identify ICT system weaknesses## and possess a deep @@understanding of ICT system operations@@.',
#  'Applicants must have the ##debug software## skill and possess @@knowledge of digital game development principles@@.',
#  'The ideal candidate should have a strong command of ##ICT project management methodologies## and a proven ability to implement ##DevOps## practices.',
#  'Applicants must have a solid understanding of @@ICT application development@@ and proficiency in using ##integrated development environment software##.',
#  'The ideal candidate should be proficient in ##product usage risks analysis##, have a strong understanding of ##ICT recovery techniques##, and be able to ##perform backups## effectively.',
#  'The ideal candidate will be able to ##assess ICT knowledge##, utilize ##database development tools##, and ##analyse business requirements##.',
#  'Seeking an industrial mobile devices software developer with the ability to ##use an application-specific interface## and ##create flowchart diagrams##.',
#  'The ideal candidate should have the ability to ##execute ICT audits## and possess a deep @@understanding of IT systems and processes@@.',
#  'Applicants must have the @@knowledge of ICT intelligent systems@@ and the ##ability to use data processing techniques##.',
#  'The Chief ICT Security Officer will be responsible for ##implementing ICT safety policies##, ##monitoring developments in their field of expertise##, identifying and mitigating ##ICT network security risks##, and ensuring compliance with ##ICT security standards##.',
#  'The ICT Auditor Manager will need to ##monitor technology trends##, have expertise in ##ICT project management##, understand and apply ##control objectives for information and related technology##, and be able to ##identify legal requirements##.',
#  'The ICT system administrator will be required to ##migrate existing data##, ##administer ICT system##, manage ##software components libraries##, and understand ##ICT system user requirements##.',
#  'Looking for an Integration Engineer who can ##deploy ICT systems## and ##analyse network bandwidth requirements##.',
#  'Applicants must have a thorough understanding of @@the legal requirements of ICT products@@ and the ability to ##navigate and apply these legal requirements in the context of ICT business analysis##.',
#  'The ideal candidate will be able to ##develop ICT test suite## and have a deep understanding of the different ##levels of software testing##.',
#  'Seeking an ICT accessibility tester with proficiency in ##levels of software testing## and a strong understanding of ##application usability##.',
#  'The ideal candidate for the ICT usability tester role should be able to ##use experience map## to understand user interactions, apply principles of ##behavioural science## to predict user behaviour, and evaluate ##application usability## to ensure optimal user experience.',
#  'Applicants must have the ability to ##apply ICT systems theory## and possess a deep @@understanding of ICT systems architecture@@.',
#  '@@Knowledge of embedded system design principles@@ is required, with the ability to ##develop creative ideas## for system improvements.',
#  'Applicants must have a deep @@understanding of ICT intelligent systems@@ and be proficient in the ##design process##.',
#  'Applicants must have the ability to ##analyse business requirements## and possess @@knowledge of ICT capacity planning@@.',
#  'The ideal candidate should be able to ##develop software prototype## and apply ##scientific research methodology##.',
#  'The ideal candidate should be able to ##utilise computer-aided software engineering tools##, apply ##engineering principles## in software development, and proficiently use ##tools for software configuration management##.',
#  'The ideal candidate will be able to ##manage ICT virtualisation environments## and ##perform project management## tasks effectively.',
#  '@@Understanding of search engine optimisation principles@@ is required, with the ability to ##manage content development projects## effectively.',
#  'The ICT Security Engineer role requires the ability to ##define technical requirements##, apply ##business analysis## skills, ##define data quality criteria##, and have expertise in ##information architecture##.',
#  'The ICT system administrator role requires the ability to ##interpret technical texts## and ##implement ICT recovery systems##.',
#  'The ideal candidate should be able to ##use an application-specific interface##, identify and rectify ##software anomalies##, and understand different ##levels of software testing##.',
#  'The ICT Security Manager should have a strong understanding of ##internet governance## and the ability to navigate the ##legal requirements of ICT products##.',
#  'Seeking a digital games developer with strong ##computer programming## skills, the ability to ##execute analytical mathematical calculations##, and expertise in ##3D texturing##.',
#  'The ideal candidate should have the ability to ##analyse ICT system##, apply effective ##audit techniques##, and adhere to ##ICT quality policy##.',
#  'We are seeking a Web Developer with the ability to ##debug software## and proficiency in ##style sheet languages##.',
#  'Applicants must have @@a deep understanding of ICT network administration@@ and ##proficiency in computer programming##.',
#  'Applicants must be proficient in using ##ICT debugging tools## and have a strong command of ##resource description framework query language##.',
#  'The ideal candidate should be able to ##utilise content types## effectively and understand the ##legal requirements of ICT products##.',
#  'Seeking a digital forensics expert with the ability to ##query languages##, maintain ##information confidentiality##, and ##manage data for legal matters##.',
#  'We are seeking a software tester with the ability to @@understand and apply software testing principles@@ and ##address problems critically##.',
#  'The ideal candidate will be able to ##train employees## on various ICT process quality models and ensure their effective implementation.',
#  'We are seeking a Cloud Engineer who can ##plan migration to cloud##, ##develop with cloud services##, has a strong understanding of ##cyber security##, and is proficient in ##ICT system programming##.',
#  'We are seeking a Data Quality Specialist who can ##use data processing techniques## to ensure the accuracy and integrity of our data, and who can ##address problems critically## to identify and resolve any data quality issues.',
#  'Seeking a Database Integrator with the ability to ##balance database resources## and ##verify formal ICT specifications##.',
#  'Applicants must have @@knowledge of ICT system architecture@@ and ##skills in business process modelling##.',
#  'Seeking a Database Administrator proficient in ##system backup best practices## and ##data quality assessment##.',
#  'The ideal candidate for our Data Scientist role should be able to ##interact professionally in research and professional environments##, have proficiency in the ##resource description framework query language##, and be able to ##develop a professional network with researchers and scientists##.',
#  'The ICT application configurator role requires the ability to ##analyse software specifications##, expertise in ##computer programming##, proficiency in using ##ICT debugging tools##, and the skill to ##debug software##.',
#  "The ideal candidate for the User Experience Analyst role should have a strong understanding of ##cognitive psychology##, with the ability to ##assess users' interaction with ICT applications##. They should also have expertise in ##human-computer interaction## and be able to effectively ##report analysis results##.",
#  'Applicants must have a solid understanding of @@industrial mobile devices software development@@ and the ability to ##use software libraries## effectively.',
#  'We are seeking an ICT quality assurance manager with the ability to ##perform quality audits## and a deep @@understanding of ICT quality standards@@.',
#  'Looking for a system configurator able to ##develop automated migration methods## and understand ##ICT system user requirements##.',
#  'Applicants must have the ability to ##interpret technical texts## related to @@ICT network administration@@.',
#  '@@Understanding of database structures, theories, principles, and practices@@ is required, with the ability to ##perform backups##.',
#  'Applicants must have a solid understanding of @@ICT application configuration@@ and the ability to ##debug software##.',
#  'Applicants should have the @@knowledge of various software libraries@@ and the ##ability to use these software libraries## effectively for user interface development.',
#  'The ICT intelligent systems designer role requires the ability to utilize ##visual presentation techniques## and proficiency in the ##resource description framework query language##.']

# %%
def convert_to_bio_tagged_sentences(sentence):
    """
    Convert a sentence with special markers for skills (##) and knowledge (@@)
    into a list of tuples containing each word and its corresponding BIO tag.
    Each word is tagged twice, once for its role as a skill, and once for knowledge.
    """
    # Splitting the sentence into words, handling markers within words
    words = sentence.replace('##', ' ## ').replace('@@', ' @@ ').split()
    tagged_words = []
    
    skill_tag = 'O'  # Initialize skill tag state
    knowledge_tag = 'O'  # Initialize knowledge tag state

    for word in words:
        # Handle skill and knowledge markers
        if word == '##':
            if skill_tag == 'O':
                skill_tag = 'B-Skill'  # Begin skill entity
            else:
                skill_tag = 'O'  # End skill entity, reset tag
            continue  # Skip the marker itself
        
        if word == '@@':
            if knowledge_tag == 'O':
                knowledge_tag = 'B-Knowledge'  # Begin knowledge entity
            else:
                knowledge_tag = 'O'  # End knowledge entity, reset tag
            continue  # Skip the marker itself
        
        # Append the word with its current skill and knowledge tags
        tagged_words.append((word, skill_tag, knowledge_tag))

        # If currently within an entity, switch to the inside tag
        if skill_tag == 'B-Skill':
            skill_tag = 'I-Skill'
        if knowledge_tag == 'B-Knowledge':
            knowledge_tag = 'I-Knowledge'
    
    return tagged_words
# Out:
# [('The', 'O', 'O'),
#  ('ICT', 'O', 'O'),
#  ('system', 'O', 'O'),
#  ('developer', 'O', 'O'),
#  ('role', 'O', 'O'),
#  ('requires', 'O', 'O'),
#  ('the', 'O', 'O'),
#  ('ability', 'O', 'O'),
#  ('to', 'O', 'O'),
#  ('provide', 'B-Skill', 'O'),
#  ('technical', 'I-Skill', 'O'),
#  ('documentation', 'I-Skill', 'O'),
#  (',', 'O', 'O'),
#  ('develop', 'B-Skill', 'O'),
#  ('automated', 'I-Skill', 'O'),
#  ('migration', 'I-Skill', 'O'),
#  ('methods', 'I-Skill', 'O'),
#  (',', 'O', 'O'),
#  ('and', 'O', 'O'),
#  ('expertise', 'O', 'O'),
#  ('in', 'O', 'O'),
#  ('computer', 'B-Skill', 'O'),
#  ('programming', 'I-Skill', 'O'),
#  ('.', 'O', 'O')]

# %%
bio_splitted_sentences = []

for cleaned_result in cleaned_results:
    bio_splitted_sentences.append(convert_to_bio_tagged_sentences(cleaned_result))

# %%
bio_splitted_sentences
# Out:
# [[('Applicants', 'O', 'O'),
#   ('must', 'O', 'O'),
#   ('have', 'O', 'O'),
#   ('knowledge', 'O', 'B-Knowledge'),
#   ('of', 'O', 'I-Knowledge'),
#   ('ICT', 'O', 'I-Knowledge'),
#   ('resilience', 'O', 'I-Knowledge'),
#   ('principles', 'O', 'I-Knowledge'),
#   ('and', 'O', 'O'),
#   ('expertise', 'B-Skill', 'O'),
#   ('in', 'I-Skill', 'O'),
#   ('cyber', 'I-Skill', 'O'),
#   ('security', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('Seeking', 'O', 'O'),
#   ('an', 'O', 'O'),
#   ('embedded', 'O', 'O'),
#   ('systems', 'O', 'O'),
#   ('software', 'O', 'O'),
#   ('developer', 'O', 'O'),
#   ('with', 'O', 'O'),
#   ('strong', 'O', 'O'),
#   ('computer', 'B-Skill', 'O'),
#   ('programming', 'I-Skill', 'O'),
#   ('skills', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('proficiency', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('using', 'O', 'O'),
#   ('integrated', 'B-Skill', 'O'),
#   ('development', 'I-Skill', 'O'),
#   ('environment', 'I-Skill', 'O'),
#   ('software', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('Applicants', 'O', 'O'),
#   ('must', 'O', 'O'),
#   ('have', 'O', 'O'),
#   ('proficiency', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('Lisp', 'B-Skill', 'O'),
#   ('and', 'O', 'O'),
#   ('Scala', 'B-Skill', 'O'),
#   ('programming', 'O', 'O'),
#   ('languages.', 'O', 'O')],
#  [('We', 'O', 'O'),
#   ('are', 'O', 'O'),
#   ('seeking', 'O', 'O'),
#   ('an', 'O', 'O'),
#   ('ICT', 'O', 'O'),
#   ('System', 'O', 'O'),
#   ('Analyst', 'O', 'O'),
#   ('with', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('understand', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('identify', 'O', 'O'),
#   ('attack', 'B-Skill', 'O'),
#   ('vectors', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('analyse', 'B-Skill', 'O'),
#   ('business', 'I-Skill', 'O'),
#   ('processes', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('comprehend', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('complexities', 'O', 'O'),
#   ('of', 'O', 'O'),
#   ('ICT', 'B-Skill', 'O'),
#   ('infrastructure', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('define', 'B-Skill', 'O'),
#   ('technical', 'I-Skill', 'O'),
#   ('requirements', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('Seeking', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('software', 'O', 'O'),
#   ('tester', 'O', 'O'),
#   ('with', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('report', 'B-Skill', 'O'),
#   ('test', 'I-Skill', 'O'),
#   ('findings', 'I-Skill', 'O'),
#   ('and', 'O', 'O'),
#   ('replicate', 'B-Skill', 'O'),
#   ('customer', 'I-Skill', 'O'),
#   ('software', 'I-Skill', 'O'),
#   ('issues', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('The', 'O', 'O'),
#   ('ICT', 'O', 'O'),
#   ('system', 'O', 'O'),
#   ('developer', 'O', 'O'),
#   ('role', 'O', 'O'),
#   ('requires', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('provide', 'B-Skill', 'O'),
#   ('technical', 'I-Skill', 'O'),
#   ('documentation', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('develop', 'B-Skill', 'O'),
#   ('automated', 'I-Skill', 'O'),
#   ('migration', 'I-Skill', 'O'),
#   ('methods', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('expertise', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('computer', 'B-Skill', 'O'),
#   ('programming', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('The', 'O', 'O'),
#   ('ideal', 'O', 'O'),
#   ('candidate', 'O', 'O'),
#   ('for', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ICT', 'O', 'O'),
#   ('system', 'O', 'O'),
#   ('developer', 'O', 'O'),
#   ('role', 'O', 'O'),
#   ('should', 'O', 'O'),
#   ('be', 'O', 'O'),
#   ('able', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('migrate', 'B-Skill', 'O'),
#   ('existing', 'I-Skill', 'O'),
#   ('data', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('possess', 'O', 'O'),
#   ('strong', 'O', 'O'),
#   ('computer', 'B-Skill', 'O'),
#   ('programming', 'I-Skill', 'O'),
#   ('skills,', 'O', 'O'),
#   ('have', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('interpret', 'B-Skill', 'O'),
#   ('technical', 'I-Skill', 'O'),
#   ('texts', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('demonstrate', 'O', 'O'),
#   ('proficiency', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('ICT', 'B-Skill', 'O'),
#   ('system', 'I-Skill', 'O'),
#   ('programming', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('Seeking', 'O', 'O'),
#   ('an', 'O', 'O'),
#   ('industrial', 'O', 'O'),
#   ('mobile', 'O', 'O'),
#   ('devices', 'O', 'O'),
#   ('software', 'O', 'O'),
#   ('developer', 'O', 'O'),
#   ('with', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('use', 'B-Skill', 'O'),
#   ('an', 'I-Skill', 'O'),
#   ('application-specific', 'I-Skill', 'O'),
#   ('interface', 'I-Skill', 'O'),
#   ('and', 'O', 'O'),
#   ('expertise', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('embedded', 'B-Skill', 'O'),
#   ('systems', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('Applicants', 'O', 'O'),
#   ('must', 'O', 'O'),
#   ('have', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('deep', 'O', 'O'),
#   ('knowledge', 'O', 'B-Knowledge'),
#   ('of', 'O', 'I-Knowledge'),
#   ('ICT', 'O', 'I-Knowledge'),
#   ('security', 'O', 'I-Knowledge'),
#   ('principles', 'O', 'I-Knowledge'),
#   ('and', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'B-Skill', 'O'),
#   ('to', 'I-Skill', 'O'),
#   ('operate', 'I-Skill', 'O'),
#   ('various', 'I-Skill', 'O'),
#   ('operating', 'I-Skill', 'O'),
#   ('systems', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('Looking', 'O', 'O'),
#   ('for', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('mobile', 'O', 'O'),
#   ('application', 'O', 'O'),
#   ('developer', 'O', 'O'),
#   ('with', 'O', 'O'),
#   ('strong', 'O', 'O'),
#   ('computer', 'B-Skill', 'O'),
#   ('programming', 'I-Skill', 'O'),
#   ('skills,', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('collect', 'B-Skill', 'O'),
#   ('customer', 'I-Skill', 'O'),
#   ('feedback', 'I-Skill', 'O'),
#   ('on', 'I-Skill', 'O'),
#   ('applications', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('capacity', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('interpret', 'B-Skill', 'O'),
#   ('technical', 'I-Skill', 'O'),
#   ('texts', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('Applicants', 'O', 'O'),
#   ('must', 'O', 'O'),
#   ('have', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('deep', 'O', 'O'),
#   ('understanding', 'O', 'B-Knowledge'),
#   ('of', 'O', 'I-Knowledge'),
#   ('ICT', 'O', 'I-Knowledge'),
#   ('capacity', 'O', 'I-Knowledge'),
#   ('planning', 'O', 'I-Knowledge'),
#   ('and', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('use', 'O', 'O'),
#   ('statistical', 'B-Skill', 'O'),
#   ('analysis', 'I-Skill', 'O'),
#   ('system', 'I-Skill', 'O'),
#   ('software', 'I-Skill', 'O'),
#   ('effectively.', 'O', 'O')],
#  [('Seeking', 'O', 'O'),
#   ('an', 'O', 'O'),
#   ('Embedded', 'O', 'O'),
#   ('Systems', 'O', 'O'),
#   ('Software', 'O', 'O'),
#   ('Developer', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('develop', 'B-Skill', 'O'),
#   ('software', 'I-Skill', 'O'),
#   ('prototypes', 'I-Skill', 'O'),
#   ('and', 'O', 'O'),
#   ('use', 'B-Skill', 'O'),
#   ('software', 'I-Skill', 'O'),
#   ('libraries', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('Looking', 'O', 'O'),
#   ('for', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('search', 'O', 'O'),
#   ('engine', 'O', 'O'),
#   ('optimisation', 'O', 'O'),
#   ('expert', 'O', 'O'),
#   ('with', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('proven', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('incorporate', 'O', 'O'),
#   ('keywords', 'B-Skill', 'O'),
#   ('in', 'I-Skill', 'O'),
#   ('digital', 'I-Skill', 'O'),
#   ('content', 'I-Skill', 'O'),
#   ('and', 'O', 'O'),
#   ('develop', 'O', 'O'),
#   ('effective', 'O', 'O'),
#   ('sales', 'B-Skill', 'O'),
#   ('strategies', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('We', 'O', 'O'),
#   ('are', 'O', 'O'),
#   ('seeking', 'O', 'O'),
#   ('an', 'O', 'O'),
#   ('ICT', 'O', 'B-Knowledge'),
#   ('auditor', 'O', 'I-Knowledge'),
#   ('manager', 'O', 'I-Knowledge'),
#   ('who', 'O', 'O'),
#   ('can', 'O', 'O'),
#   ('develop', 'B-Skill', 'O'),
#   ('audit', 'I-Skill', 'O'),
#   ('plans', 'I-Skill', 'O'),
#   ('effectively.', 'O', 'O')],
#  [('The', 'O', 'O'),
#   ('ideal', 'O', 'O'),
#   ('candidate', 'O', 'O'),
#   ('should', 'O', 'O'),
#   ('have', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('deep', 'O', 'O'),
#   ('understanding', 'O', 'O'),
#   ('of', 'O', 'O'),
#   ('ICT', 'O', 'B-Knowledge'),
#   ('security', 'O', 'I-Knowledge'),
#   ('principles', 'O', 'I-Knowledge'),
#   ('and', 'O', 'O'),
#   ('be', 'O', 'O'),
#   ('proficient', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('ICT', 'B-Skill', 'O'),
#   ('problem', 'I-Skill', 'O'),
#   ('management', 'I-Skill', 'O'),
#   ('techniques', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('Applicants', 'O', 'O'),
#   ('must', 'O', 'O'),
#   ('have', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('solid', 'O', 'O'),
#   ('understanding', 'O', 'O'),
#   ('of', 'O', 'O'),
#   ('web', 'O', 'B-Knowledge'),
#   ('development', 'O', 'I-Knowledge'),
#   ('principles', 'O', 'I-Knowledge'),
#   ('and', 'O', 'O'),
#   ('proficiency', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('using', 'O', 'O'),
#   ('ICT', 'B-Skill', 'O'),
#   ('debugging', 'I-Skill', 'O'),
#   ('tools', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('Applicants', 'O', 'O'),
#   ('must', 'O', 'O'),
#   ('have', 'O', 'O'),
#   ('a', 'O', 'B-Knowledge'),
#   ('deep', 'O', 'I-Knowledge'),
#   ('understanding', 'O', 'I-Knowledge'),
#   ('of', 'O', 'I-Knowledge'),
#   ('ICT', 'O', 'I-Knowledge'),
#   ('integration', 'O', 'I-Knowledge'),
#   ('testing', 'O', 'I-Knowledge'),
#   ('and', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('address', 'B-Skill', 'O'),
#   ('problems', 'I-Skill', 'O'),
#   ('critically', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('Looking', 'O', 'O'),
#   ('for', 'O', 'O'),
#   ('an', 'O', 'O'),
#   ('Integration', 'O', 'O'),
#   ('Engineer', 'O', 'O'),
#   ('with', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('software', 'B-Skill', 'O'),
#   ('components', 'I-Skill', 'O'),
#   ('suppliers', 'I-Skill', 'O'),
#   ('skill', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('work', 'O', 'O'),
#   ('with', 'O', 'O'),
#   ('hardware', 'B-Skill', 'O'),
#   ('components', 'I-Skill', 'O'),
#   ('suppliers', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('Seeking', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('Database', 'O', 'O'),
#   ('Administrator', 'O', 'O'),
#   ('with', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('administer', 'B-Skill', 'O'),
#   ('ICT', 'I-Skill', 'O'),
#   ('systems', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('manage', 'B-Skill', 'O'),
#   ('databases', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('utilize', 'O', 'O'),
#   ('database', 'B-Skill', 'O'),
#   ('development', 'I-Skill', 'O'),
#   ('tools', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('Seeking', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('database', 'O', 'O'),
#   ('integrator', 'O', 'O'),
#   ('with', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('integrate', 'B-Skill', 'O'),
#   ('ICT', 'I-Skill', 'O'),
#   ('data', 'I-Skill', 'O'),
#   ('and', 'O', 'O'),
#   ('manage', 'B-Skill', 'O'),
#   ('ICT', 'I-Skill', 'O'),
#   ('legacy', 'I-Skill', 'O'),
#   ('implications', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('The', 'O', 'O'),
#   ('ideal', 'O', 'O'),
#   ('candidate', 'O', 'O'),
#   ('will', 'O', 'O'),
#   ('be', 'O', 'O'),
#   ('able', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('manage', 'B-Skill', 'O'),
#   ('IT', 'I-Skill', 'O'),
#   ('security', 'I-Skill', 'O'),
#   ('compliances', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('demonstrate', 'O', 'O'),
#   ('strong', 'O', 'O'),
#   ('organisational', 'B-Skill', 'O'),
#   ('resilience', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('have', 'O', 'O'),
#   ('proficiency', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('using', 'O', 'O'),
#   ('database', 'B-Skill', 'O'),
#   ('development', 'I-Skill', 'O'),
#   ('tools', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('The', 'O', 'O'),
#   ('ICT', 'O', 'O'),
#   ('Test', 'O', 'O'),
#   ('Analyst', 'O', 'O'),
#   ('role', 'O', 'O'),
#   ('requires', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('plan', 'B-Skill', 'O'),
#   ('software', 'I-Skill', 'O'),
#   ('testing', 'I-Skill', 'O'),
#   ('and', 'O', 'O'),
#   ('report', 'B-Skill', 'O'),
#   ('test', 'I-Skill', 'O'),
#   ('findings', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('Applicants', 'O', 'O'),
#   ('must', 'O', 'O'),
#   ('have', 'O', 'O'),
#   ('knowledge', 'O', 'B-Knowledge'),
#   ('of', 'O', 'I-Knowledge'),
#   ('ICT', 'O', 'I-Knowledge'),
#   ('business', 'O', 'I-Knowledge'),
#   ('analysis', 'O', 'I-Knowledge'),
#   ('and', 'O', 'O'),
#   ('ability', 'B-Skill', 'O'),
#   ('to', 'I-Skill', 'O'),
#   ('understand', 'I-Skill', 'O'),
#   ('and', 'I-Skill', 'O'),
#   ('apply', 'I-Skill', 'O'),
#   ('legal', 'I-Skill', 'O'),
#   ('requirements', 'I-Skill', 'O'),
#   ('of', 'I-Skill', 'O'),
#   ('ICT', 'I-Skill', 'O'),
#   ('products', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('The', 'O', 'O'),
#   ('ideal', 'O', 'O'),
#   ('candidate', 'O', 'O'),
#   ('for', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ICT', 'O', 'O'),
#   ('capacity', 'O', 'O'),
#   ('planner', 'O', 'O'),
#   ('role', 'O', 'O'),
#   ('should', 'O', 'O'),
#   ('have', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('forecast', 'B-Skill', 'O'),
#   ('workload', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('proficiency', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('using', 'O', 'O'),
#   ('statistical', 'B-Skill', 'O'),
#   ('analysis', 'I-Skill', 'O'),
#   ('system', 'I-Skill', 'O'),
#   ('software', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('deep', 'O', 'O'),
#   ('understanding', 'O', 'O'),
#   ('of', 'O', 'O'),
#   ('ICT', 'B-Skill', 'O'),
#   ('infrastructure', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('The', 'O', 'O'),
#   ('ideal', 'O', 'O'),
#   ('candidate', 'O', 'O'),
#   ('for', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('web', 'O', 'O'),
#   ('developer', 'O', 'O'),
#   ('role', 'O', 'O'),
#   ('should', 'O', 'O'),
#   ('be', 'O', 'O'),
#   ('able', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('provide', 'B-Skill', 'O'),
#   ('technical', 'I-Skill', 'O'),
#   ('documentation', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('proficiently', 'O', 'O'),
#   ('use', 'B-Skill', 'O'),
#   ('an', 'I-Skill', 'O'),
#   ('application-specific', 'I-Skill', 'O'),
#   ('interface', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('understand', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('content', 'B-Skill', 'O'),
#   ('development', 'I-Skill', 'O'),
#   ('processes', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('As', 'O', 'O'),
#   ('an', 'O', 'O'),
#   ('ICT', 'O', 'O'),
#   ('System', 'O', 'O'),
#   ('Analyst,', 'O', 'O'),
#   ('you', 'O', 'O'),
#   ('will', 'O', 'O'),
#   ('need', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('have', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('interact', 'B-Skill', 'O'),
#   ('with', 'I-Skill', 'O'),
#   ('users', 'I-Skill', 'O'),
#   ('to', 'I-Skill', 'O'),
#   ('gather', 'I-Skill', 'O'),
#   ('requirements', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('apply', 'O', 'O'),
#   ('your', 'O', 'O'),
#   ('expertise', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('systems', 'B-Skill', 'O'),
#   ('development', 'I-Skill', 'O'),
#   ('life-cycle', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('create', 'B-Skill', 'O'),
#   ('data', 'I-Skill', 'O'),
#   ('models', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('The', 'O', 'O'),
#   ('ideal', 'O', 'O'),
#   ('candidate', 'O', 'O'),
#   ('should', 'O', 'O'),
#   ('have', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('deep', 'O', 'O'),
#   ('understanding', 'O', 'O'),
#   ('of', 'O', 'O'),
#   ('ICT', 'O', 'B-Knowledge'),
#   ('sales', 'O', 'I-Knowledge'),
#   ('methodologies', 'O', 'I-Knowledge'),
#   ('and', 'O', 'O'),
#   ('be', 'O', 'O'),
#   ('proficient', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('ICT', 'B-Skill', 'O'),
#   ('sales', 'I-Skill', 'O'),
#   ('methodologies', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('Applicants', 'O', 'O'),
#   ('must', 'O', 'O'),
#   ('have', 'O', 'O'),
#   ('knowledge', 'O', 'B-Knowledge'),
#   ('of', 'O', 'I-Knowledge'),
#   ('ICT', 'O', 'I-Knowledge'),
#   ('system', 'O', 'I-Knowledge'),
#   ('integration', 'O', 'I-Knowledge'),
#   ('and', 'O', 'O'),
#   ('experience', 'B-Skill', 'O'),
#   ('in', 'I-Skill', 'O'),
#   ('systems', 'I-Skill', 'O'),
#   ('development', 'I-Skill', 'O'),
#   ('life-cycle', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('The', 'O', 'O'),
#   ('ICT', 'O', 'O'),
#   ('application', 'O', 'O'),
#   ('configurator', 'O', 'O'),
#   ('role', 'O', 'O'),
#   ('requires', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('create', 'B-Skill', 'O'),
#   ('flowchart', 'I-Skill', 'O'),
#   ('diagrams', 'I-Skill', 'O'),
#   ('and', 'O', 'O'),
#   ('proficiency', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('using', 'O', 'O'),
#   ('integrated', 'B-Skill', 'O'),
#   ('development', 'I-Skill', 'O'),
#   ('environment', 'I-Skill', 'O'),
#   ('software', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('Understanding', 'O', 'B-Knowledge'),
#   ('of', 'O', 'I-Knowledge'),
#   ('data', 'O', 'I-Knowledge'),
#   ('quality', 'O', 'I-Knowledge'),
#   ('principles', 'O', 'I-Knowledge'),
#   ('is', 'O', 'O'),
#   ('required,', 'O', 'O'),
#   ('with', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('manage', 'B-Skill', 'O'),
#   ('standards', 'I-Skill', 'O'),
#   ('for', 'I-Skill', 'O'),
#   ('data', 'I-Skill', 'O'),
#   ('exchange', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('The', 'O', 'O'),
#   ('ICT', 'O', 'O'),
#   ('network', 'O', 'O'),
#   ('administrator', 'O', 'O'),
#   ('role', 'O', 'O'),
#   ('requires', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('provide', 'B-Skill', 'O'),
#   ('technical', 'I-Skill', 'O'),
#   ('documentation', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('expertise', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('computer', 'B-Skill', 'O'),
#   ('programming', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('thorough', 'O', 'O'),
#   ('understanding', 'O', 'O'),
#   ('of', 'O', 'O'),
#   ('ICT', 'B-Skill', 'O'),
#   ('security', 'I-Skill', 'O'),
#   ('legislation', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('capacity', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('forecast', 'B-Skill', 'O'),
#   ('future', 'I-Skill', 'O'),
#   ('ICT', 'I-Skill', 'O'),
#   ('network', 'I-Skill', 'O'),
#   ('needs', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('Seeking', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('User', 'O', 'O'),
#   ('Interface', 'O', 'O'),
#   ('Developer', 'O', 'O'),
#   ('with', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('use', 'B-Skill', 'O'),
#   ('methodologies', 'I-Skill', 'O'),
#   ('for', 'I-Skill', 'O'),
#   ('user-centered', 'I-Skill', 'O'),
#   ('design', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('proficiency', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('software', 'B-Skill', 'O'),
#   ('UI', 'I-Skill', 'O'),
#   ('design', 'I-Skill', 'O'),
#   ('patterns', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('experience', 'O', 'O'),
#   ('with', 'O', 'O'),
#   ('graphics', 'B-Skill', 'O'),
#   ('editor', 'I-Skill', 'O'),
#   ('software', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('We', 'O', 'O'),
#   ('are', 'O', 'O'),
#   ('seeking', 'O', 'O'),
#   ('an', 'O', 'O'),
#   ('ICT', 'O', 'O'),
#   ('application', 'O', 'O'),
#   ('developer', 'O', 'O'),
#   ('who', 'O', 'O'),
#   ('can', 'O', 'O'),
#   ('propose', 'B-Skill', 'O'),
#   ('ICT', 'I-Skill', 'O'),
#   ('solutions', 'I-Skill', 'O'),
#   ('to', 'I-Skill', 'O'),
#   ('business', 'I-Skill', 'O'),
#   ('problems', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('has', 'O', 'O'),
#   ('strong', 'O', 'O'),
#   ('computer', 'B-Skill', 'O'),
#   ('programming', 'I-Skill', 'O'),
#   ('skills,', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('is', 'O', 'O'),
#   ('proficient', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('service-oriented', 'B-Skill', 'O'),
#   ('modelling', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('Applicants', 'O', 'O'),
#   ('must', 'O', 'O'),
#   ('have', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('solid', 'O', 'O'),
#   ('understanding', 'O', 'O'),
#   ('of', 'O', 'O'),
#   ('database', 'O', 'B-Knowledge'),
#   ('administration', 'O', 'I-Knowledge'),
#   ('principles', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('be', 'O', 'O'),
#   ('proficient', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('resource', 'B-Skill', 'O'),
#   ('description', 'I-Skill', 'O'),
#   ('framework', 'I-Skill', 'O'),
#   ('query', 'I-Skill', 'O'),
#   ('language', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('We', 'O', 'O'),
#   ('are', 'O', 'O'),
#   ('seeking', 'O', 'O'),
#   ('an', 'O', 'O'),
#   ('ICT', 'O', 'O'),
#   ('System', 'O', 'O'),
#   ('Administrator', 'O', 'O'),
#   ('with', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('manage', 'B-Skill', 'O'),
#   ('system', 'I-Skill', 'O'),
#   ('testing', 'I-Skill', 'O'),
#   ('and', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('strong', 'O', 'O'),
#   ('expertise', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('hardware', 'B-Skill', 'O'),
#   ('components', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('As', 'O', 'O'),
#   ('an', 'O', 'O'),
#   ('ICT', 'O', 'O'),
#   ('Auditor', 'O', 'O'),
#   ('Manager,', 'O', 'O'),
#   ('you', 'O', 'O'),
#   ('will', 'O', 'O'),
#   ('need', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('ensure', 'B-Skill', 'O'),
#   ('compliance', 'I-Skill', 'O'),
#   ('with', 'I-Skill', 'O'),
#   ('legal', 'I-Skill', 'O'),
#   ('requirements', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('understand', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('mitigate', 'O', 'O'),
#   ('attack', 'B-Skill', 'O'),
#   ('vectors', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('apply', 'O', 'O'),
#   ('effective', 'O', 'O'),
#   ('audit', 'B-Skill', 'O'),
#   ('techniques', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('Seeking', 'O', 'O'),
#   ('an', 'O', 'O'),
#   ('ICT', 'O', 'O'),
#   ('system', 'O', 'O'),
#   ('tester', 'O', 'O'),
#   ('with', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('identify', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('rectify', 'O', 'O'),
#   ('software', 'B-Skill', 'O'),
#   ('anomalies', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('expertise', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('provide', 'B-Skill', 'O'),
#   ('software', 'I-Skill', 'O'),
#   ('testing', 'I-Skill', 'O'),
#   ('documentation', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('Looking', 'O', 'O'),
#   ('for', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('User', 'O', 'O'),
#   ('Interface', 'O', 'O'),
#   ('Developer', 'O', 'O'),
#   ('with', 'O', 'O'),
#   ('strong', 'O', 'O'),
#   ('web', 'B-Skill', 'O'),
#   ('programming', 'I-Skill', 'O'),
#   ('skills', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('proficiency', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('using', 'O', 'O'),
#   ('integrated', 'B-Skill', 'O'),
#   ('development', 'I-Skill', 'O'),
#   ('environment', 'I-Skill', 'O'),
#   ('software', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('The', 'O', 'O'),
#   ('ideal', 'O', 'O'),
#   ('candidate', 'O', 'O'),
#   ('should', 'O', 'O'),
#   ('have', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('define', 'B-Skill', 'O'),
#   ('technical', 'I-Skill', 'O'),
#   ('requirements', 'I-Skill', 'O'),
#   ('and', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('strong', 'O', 'O'),
#   ('understanding', 'O', 'O'),
#   ('of', 'O', 'O'),
#   ('ICT', 'B-Skill', 'O'),
#   ('security', 'I-Skill', 'O'),
#   ('standards', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('Applicants', 'O', 'O'),
#   ('must', 'O', 'O'),
#   ('have', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('deep', 'O', 'O'),
#   ('understanding', 'O', 'O'),
#   ('of', 'O', 'O'),
#   ('blockchain', 'O', 'B-Knowledge'),
#   ('principles', 'O', 'I-Knowledge'),
#   ('and', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('design', 'B-Skill', 'O'),
#   ('and', 'I-Skill', 'O'),
#   ('implement', 'I-Skill', 'O'),
#   ('business', 'I-Skill', 'O'),
#   ('processes', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('Looking', 'O', 'O'),
#   ('for', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('system', 'O', 'O'),
#   ('configurator', 'O', 'O'),
#   ('with', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('migrate', 'B-Skill', 'O'),
#   ('existing', 'I-Skill', 'O'),
#   ('data', 'I-Skill', 'O'),
#   ('and', 'O', 'O'),
#   ('configure', 'B-Skill', 'O'),
#   ('ICT', 'I-Skill', 'O'),
#   ('system', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('The', 'O', 'O'),
#   ('ideal', 'O', 'O'),
#   ('candidate', 'O', 'O'),
#   ('for', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('Software', 'O', 'O'),
#   ('Analyst', 'O', 'O'),
#   ('role', 'O', 'O'),
#   ('should', 'O', 'O'),
#   ('be', 'O', 'O'),
#   ('able', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('define', 'B-Skill', 'O'),
#   ('technical', 'I-Skill', 'O'),
#   ('requirements', 'I-Skill', 'O'),
#   ('and', 'O', 'O'),
#   ('define', 'B-Skill', 'O'),
#   ('software', 'I-Skill', 'O'),
#   ('architecture', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('Applicants', 'O', 'O'),
#   ('must', 'O', 'O'),
#   ('have', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('deep', 'O', 'O'),
#   ('understanding', 'O', 'B-Knowledge'),
#   ('of', 'O', 'I-Knowledge'),
#   ('software', 'O', 'I-Knowledge'),
#   ('testing', 'O', 'I-Knowledge'),
#   ('principles', 'O', 'I-Knowledge'),
#   ('and', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('use', 'O', 'O'),
#   ('software', 'B-Skill', 'O'),
#   ('metrics', 'I-Skill', 'O'),
#   ('effectively.', 'O', 'O')],
#  [('System', 'O', 'O'),
#   ('Configurator', 'O', 'O'),
#   ('needed', 'O', 'O'),
#   ('with', 'O', 'O'),
#   ('strong', 'O', 'O'),
#   ('cognitive', 'B-Skill', 'O'),
#   ('psychology', 'I-Skill', 'O'),
#   ('skills', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('understand', 'O', 'O'),
#   ('user', 'O', 'O'),
#   ('needs,', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('interpret', 'B-Skill', 'O'),
#   ('technical', 'I-Skill', 'O'),
#   ('texts', 'I-Skill', 'O'),
#   ('for', 'O', 'O'),
#   ('system', 'O', 'O'),
#   ('configuration,', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('expertise', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('managing', 'O', 'O'),
#   ('ICT', 'B-Skill', 'O'),
#   ('infrastructure', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('Familiarity', 'O', 'B-Knowledge'),
#   ('with', 'O', 'I-Knowledge'),
#   ('ICT', 'O', 'I-Knowledge'),
#   ('application', 'O', 'I-Knowledge'),
#   ('development', 'O', 'I-Knowledge'),
#   ('is', 'O', 'O'),
#   ('required,', 'O', 'O'),
#   ('with', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('propose', 'B-Skill', 'O'),
#   ('ICT', 'I-Skill', 'O'),
#   ('solutions', 'I-Skill', 'O'),
#   ('to', 'I-Skill', 'O'),
#   ('business', 'I-Skill', 'O'),
#   ('problems', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('The', 'O', 'O'),
#   ('ideal', 'O', 'O'),
#   ('candidate', 'O', 'O'),
#   ('for', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ICT', 'O', 'O'),
#   ('Auditor', 'O', 'O'),
#   ('Manager', 'O', 'O'),
#   ('role', 'O', 'O'),
#   ('should', 'O', 'O'),
#   ('have', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('strong', 'O', 'O'),
#   ('understanding', 'O', 'O'),
#   ('of', 'O', 'O'),
#   ('attack', 'B-Skill', 'O'),
#   ('vectors', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('be', 'O', 'O'),
#   ('able', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('maintain', 'O', 'O'),
#   ('high', 'O', 'O'),
#   ('quality', 'B-Skill', 'O'),
#   ('standards', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('possess', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('build', 'B-Skill', 'O'),
#   ('business', 'I-Skill', 'O'),
#   ('relationships', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('Applicants', 'O', 'O'),
#   ('must', 'O', 'O'),
#   ('have', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('identify', 'B-Skill', 'O'),
#   ('ICT', 'I-Skill', 'O'),
#   ('system', 'I-Skill', 'O'),
#   ('weaknesses', 'I-Skill', 'O'),
#   ('and', 'O', 'O'),
#   ('possess', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('deep', 'O', 'O'),
#   ('understanding', 'O', 'B-Knowledge'),
#   ('of', 'O', 'I-Knowledge'),
#   ('ICT', 'O', 'I-Knowledge'),
#   ('system', 'O', 'I-Knowledge'),
#   ('operations', 'O', 'I-Knowledge'),
#   ('.', 'O', 'O')],
#  [('Applicants', 'O', 'O'),
#   ('must', 'O', 'O'),
#   ('have', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('debug', 'B-Skill', 'O'),
#   ('software', 'I-Skill', 'O'),
#   ('skill', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('possess', 'O', 'O'),
#   ('knowledge', 'O', 'B-Knowledge'),
#   ('of', 'O', 'I-Knowledge'),
#   ('digital', 'O', 'I-Knowledge'),
#   ('game', 'O', 'I-Knowledge'),
#   ('development', 'O', 'I-Knowledge'),
#   ('principles', 'O', 'I-Knowledge'),
#   ('.', 'O', 'O')],
#  [('The', 'O', 'O'),
#   ('ideal', 'O', 'O'),
#   ('candidate', 'O', 'O'),
#   ('should', 'O', 'O'),
#   ('have', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('strong', 'O', 'O'),
#   ('command', 'O', 'O'),
#   ('of', 'O', 'O'),
#   ('ICT', 'B-Skill', 'O'),
#   ('project', 'I-Skill', 'O'),
#   ('management', 'I-Skill', 'O'),
#   ('methodologies', 'I-Skill', 'O'),
#   ('and', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('proven', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('implement', 'O', 'O'),
#   ('DevOps', 'B-Skill', 'O'),
#   ('practices.', 'O', 'O')],
#  [('Applicants', 'O', 'O'),
#   ('must', 'O', 'O'),
#   ('have', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('solid', 'O', 'O'),
#   ('understanding', 'O', 'O'),
#   ('of', 'O', 'O'),
#   ('ICT', 'O', 'B-Knowledge'),
#   ('application', 'O', 'I-Knowledge'),
#   ('development', 'O', 'I-Knowledge'),
#   ('and', 'O', 'O'),
#   ('proficiency', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('using', 'O', 'O'),
#   ('integrated', 'B-Skill', 'O'),
#   ('development', 'I-Skill', 'O'),
#   ('environment', 'I-Skill', 'O'),
#   ('software', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('The', 'O', 'O'),
#   ('ideal', 'O', 'O'),
#   ('candidate', 'O', 'O'),
#   ('should', 'O', 'O'),
#   ('be', 'O', 'O'),
#   ('proficient', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('product', 'B-Skill', 'O'),
#   ('usage', 'I-Skill', 'O'),
#   ('risks', 'I-Skill', 'O'),
#   ('analysis', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('have', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('strong', 'O', 'O'),
#   ('understanding', 'O', 'O'),
#   ('of', 'O', 'O'),
#   ('ICT', 'B-Skill', 'O'),
#   ('recovery', 'I-Skill', 'O'),
#   ('techniques', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('be', 'O', 'O'),
#   ('able', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('perform', 'B-Skill', 'O'),
#   ('backups', 'I-Skill', 'O'),
#   ('effectively.', 'O', 'O')],
#  [('The', 'O', 'O'),
#   ('ideal', 'O', 'O'),
#   ('candidate', 'O', 'O'),
#   ('will', 'O', 'O'),
#   ('be', 'O', 'O'),
#   ('able', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('assess', 'B-Skill', 'O'),
#   ('ICT', 'I-Skill', 'O'),
#   ('knowledge', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('utilize', 'O', 'O'),
#   ('database', 'B-Skill', 'O'),
#   ('development', 'I-Skill', 'O'),
#   ('tools', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('analyse', 'B-Skill', 'O'),
#   ('business', 'I-Skill', 'O'),
#   ('requirements', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('Seeking', 'O', 'O'),
#   ('an', 'O', 'O'),
#   ('industrial', 'O', 'O'),
#   ('mobile', 'O', 'O'),
#   ('devices', 'O', 'O'),
#   ('software', 'O', 'O'),
#   ('developer', 'O', 'O'),
#   ('with', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('use', 'B-Skill', 'O'),
#   ('an', 'I-Skill', 'O'),
#   ('application-specific', 'I-Skill', 'O'),
#   ('interface', 'I-Skill', 'O'),
#   ('and', 'O', 'O'),
#   ('create', 'B-Skill', 'O'),
#   ('flowchart', 'I-Skill', 'O'),
#   ('diagrams', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('The', 'O', 'O'),
#   ('ideal', 'O', 'O'),
#   ('candidate', 'O', 'O'),
#   ('should', 'O', 'O'),
#   ('have', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('execute', 'B-Skill', 'O'),
#   ('ICT', 'I-Skill', 'O'),
#   ('audits', 'I-Skill', 'O'),
#   ('and', 'O', 'O'),
#   ('possess', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('deep', 'O', 'O'),
#   ('understanding', 'O', 'B-Knowledge'),
#   ('of', 'O', 'I-Knowledge'),
#   ('IT', 'O', 'I-Knowledge'),
#   ('systems', 'O', 'I-Knowledge'),
#   ('and', 'O', 'I-Knowledge'),
#   ('processes', 'O', 'I-Knowledge'),
#   ('.', 'O', 'O')],
#  [('Applicants', 'O', 'O'),
#   ('must', 'O', 'O'),
#   ('have', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('knowledge', 'O', 'B-Knowledge'),
#   ('of', 'O', 'I-Knowledge'),
#   ('ICT', 'O', 'I-Knowledge'),
#   ('intelligent', 'O', 'I-Knowledge'),
#   ('systems', 'O', 'I-Knowledge'),
#   ('and', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'B-Skill', 'O'),
#   ('to', 'I-Skill', 'O'),
#   ('use', 'I-Skill', 'O'),
#   ('data', 'I-Skill', 'O'),
#   ('processing', 'I-Skill', 'O'),
#   ('techniques', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('The', 'O', 'O'),
#   ('Chief', 'O', 'O'),
#   ('ICT', 'O', 'O'),
#   ('Security', 'O', 'O'),
#   ('Officer', 'O', 'O'),
#   ('will', 'O', 'O'),
#   ('be', 'O', 'O'),
#   ('responsible', 'O', 'O'),
#   ('for', 'O', 'O'),
#   ('implementing', 'B-Skill', 'O'),
#   ('ICT', 'I-Skill', 'O'),
#   ('safety', 'I-Skill', 'O'),
#   ('policies', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('monitoring', 'B-Skill', 'O'),
#   ('developments', 'I-Skill', 'O'),
#   ('in', 'I-Skill', 'O'),
#   ('their', 'I-Skill', 'O'),
#   ('field', 'I-Skill', 'O'),
#   ('of', 'I-Skill', 'O'),
#   ('expertise', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('identifying', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('mitigating', 'O', 'O'),
#   ('ICT', 'B-Skill', 'O'),
#   ('network', 'I-Skill', 'O'),
#   ('security', 'I-Skill', 'O'),
#   ('risks', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('ensuring', 'O', 'O'),
#   ('compliance', 'O', 'O'),
#   ('with', 'O', 'O'),
#   ('ICT', 'B-Skill', 'O'),
#   ('security', 'I-Skill', 'O'),
#   ('standards', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('The', 'O', 'O'),
#   ('ICT', 'O', 'O'),
#   ('Auditor', 'O', 'O'),
#   ('Manager', 'O', 'O'),
#   ('will', 'O', 'O'),
#   ('need', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('monitor', 'B-Skill', 'O'),
#   ('technology', 'I-Skill', 'O'),
#   ('trends', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('have', 'O', 'O'),
#   ('expertise', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('ICT', 'B-Skill', 'O'),
#   ('project', 'I-Skill', 'O'),
#   ('management', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('understand', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('apply', 'O', 'O'),
#   ('control', 'B-Skill', 'O'),
#   ('objectives', 'I-Skill', 'O'),
#   ('for', 'I-Skill', 'O'),
#   ('information', 'I-Skill', 'O'),
#   ('and', 'I-Skill', 'O'),
#   ('related', 'I-Skill', 'O'),
#   ('technology', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('be', 'O', 'O'),
#   ('able', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('identify', 'B-Skill', 'O'),
#   ('legal', 'I-Skill', 'O'),
#   ('requirements', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('The', 'O', 'O'),
#   ('ICT', 'O', 'O'),
#   ('system', 'O', 'O'),
#   ('administrator', 'O', 'O'),
#   ('will', 'O', 'O'),
#   ('be', 'O', 'O'),
#   ('required', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('migrate', 'B-Skill', 'O'),
#   ('existing', 'I-Skill', 'O'),
#   ('data', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('administer', 'B-Skill', 'O'),
#   ('ICT', 'I-Skill', 'O'),
#   ('system', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('manage', 'O', 'O'),
#   ('software', 'B-Skill', 'O'),
#   ('components', 'I-Skill', 'O'),
#   ('libraries', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('understand', 'O', 'O'),
#   ('ICT', 'B-Skill', 'O'),
#   ('system', 'I-Skill', 'O'),
#   ('user', 'I-Skill', 'O'),
#   ('requirements', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('Looking', 'O', 'O'),
#   ('for', 'O', 'O'),
#   ('an', 'O', 'O'),
#   ('Integration', 'O', 'O'),
#   ('Engineer', 'O', 'O'),
#   ('who', 'O', 'O'),
#   ('can', 'O', 'O'),
#   ('deploy', 'B-Skill', 'O'),
#   ('ICT', 'I-Skill', 'O'),
#   ('systems', 'I-Skill', 'O'),
#   ('and', 'O', 'O'),
#   ('analyse', 'B-Skill', 'O'),
#   ('network', 'I-Skill', 'O'),
#   ('bandwidth', 'I-Skill', 'O'),
#   ('requirements', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('Applicants', 'O', 'O'),
#   ('must', 'O', 'O'),
#   ('have', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('thorough', 'O', 'O'),
#   ('understanding', 'O', 'O'),
#   ('of', 'O', 'O'),
#   ('the', 'O', 'B-Knowledge'),
#   ('legal', 'O', 'I-Knowledge'),
#   ('requirements', 'O', 'I-Knowledge'),
#   ('of', 'O', 'I-Knowledge'),
#   ('ICT', 'O', 'I-Knowledge'),
#   ('products', 'O', 'I-Knowledge'),
#   ('and', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('navigate', 'B-Skill', 'O'),
#   ('and', 'I-Skill', 'O'),
#   ('apply', 'I-Skill', 'O'),
#   ('these', 'I-Skill', 'O'),
#   ('legal', 'I-Skill', 'O'),
#   ('requirements', 'I-Skill', 'O'),
#   ('in', 'I-Skill', 'O'),
#   ('the', 'I-Skill', 'O'),
#   ('context', 'I-Skill', 'O'),
#   ('of', 'I-Skill', 'O'),
#   ('ICT', 'I-Skill', 'O'),
#   ('business', 'I-Skill', 'O'),
#   ('analysis', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('The', 'O', 'O'),
#   ('ideal', 'O', 'O'),
#   ('candidate', 'O', 'O'),
#   ('will', 'O', 'O'),
#   ('be', 'O', 'O'),
#   ('able', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('develop', 'B-Skill', 'O'),
#   ('ICT', 'I-Skill', 'O'),
#   ('test', 'I-Skill', 'O'),
#   ('suite', 'I-Skill', 'O'),
#   ('and', 'O', 'O'),
#   ('have', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('deep', 'O', 'O'),
#   ('understanding', 'O', 'O'),
#   ('of', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('different', 'O', 'O'),
#   ('levels', 'B-Skill', 'O'),
#   ('of', 'I-Skill', 'O'),
#   ('software', 'I-Skill', 'O'),
#   ('testing', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('Seeking', 'O', 'O'),
#   ('an', 'O', 'O'),
#   ('ICT', 'O', 'O'),
#   ('accessibility', 'O', 'O'),
#   ('tester', 'O', 'O'),
#   ('with', 'O', 'O'),
#   ('proficiency', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('levels', 'B-Skill', 'O'),
#   ('of', 'I-Skill', 'O'),
#   ('software', 'I-Skill', 'O'),
#   ('testing', 'I-Skill', 'O'),
#   ('and', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('strong', 'O', 'O'),
#   ('understanding', 'O', 'O'),
#   ('of', 'O', 'O'),
#   ('application', 'B-Skill', 'O'),
#   ('usability', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('The', 'O', 'O'),
#   ('ideal', 'O', 'O'),
#   ('candidate', 'O', 'O'),
#   ('for', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ICT', 'O', 'O'),
#   ('usability', 'O', 'O'),
#   ('tester', 'O', 'O'),
#   ('role', 'O', 'O'),
#   ('should', 'O', 'O'),
#   ('be', 'O', 'O'),
#   ('able', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('use', 'B-Skill', 'O'),
#   ('experience', 'I-Skill', 'O'),
#   ('map', 'I-Skill', 'O'),
#   ('to', 'O', 'O'),
#   ('understand', 'O', 'O'),
#   ('user', 'O', 'O'),
#   ('interactions,', 'O', 'O'),
#   ('apply', 'O', 'O'),
#   ('principles', 'O', 'O'),
#   ('of', 'O', 'O'),
#   ('behavioural', 'B-Skill', 'O'),
#   ('science', 'I-Skill', 'O'),
#   ('to', 'O', 'O'),
#   ('predict', 'O', 'O'),
#   ('user', 'O', 'O'),
#   ('behaviour,', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('evaluate', 'O', 'O'),
#   ('application', 'B-Skill', 'O'),
#   ('usability', 'I-Skill', 'O'),
#   ('to', 'O', 'O'),
#   ('ensure', 'O', 'O'),
#   ('optimal', 'O', 'O'),
#   ('user', 'O', 'O'),
#   ('experience.', 'O', 'O')],
#  [('Applicants', 'O', 'O'),
#   ('must', 'O', 'O'),
#   ('have', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('apply', 'B-Skill', 'O'),
#   ('ICT', 'I-Skill', 'O'),
#   ('systems', 'I-Skill', 'O'),
#   ('theory', 'I-Skill', 'O'),
#   ('and', 'O', 'O'),
#   ('possess', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('deep', 'O', 'O'),
#   ('understanding', 'O', 'B-Knowledge'),
#   ('of', 'O', 'I-Knowledge'),
#   ('ICT', 'O', 'I-Knowledge'),
#   ('systems', 'O', 'I-Knowledge'),
#   ('architecture', 'O', 'I-Knowledge'),
#   ('.', 'O', 'O')],
#  [('Knowledge', 'O', 'B-Knowledge'),
#   ('of', 'O', 'I-Knowledge'),
#   ('embedded', 'O', 'I-Knowledge'),
#   ('system', 'O', 'I-Knowledge'),
#   ('design', 'O', 'I-Knowledge'),
#   ('principles', 'O', 'I-Knowledge'),
#   ('is', 'O', 'O'),
#   ('required,', 'O', 'O'),
#   ('with', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('develop', 'B-Skill', 'O'),
#   ('creative', 'I-Skill', 'O'),
#   ('ideas', 'I-Skill', 'O'),
#   ('for', 'O', 'O'),
#   ('system', 'O', 'O'),
#   ('improvements.', 'O', 'O')],
#  [('Applicants', 'O', 'O'),
#   ('must', 'O', 'O'),
#   ('have', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('deep', 'O', 'O'),
#   ('understanding', 'O', 'B-Knowledge'),
#   ('of', 'O', 'I-Knowledge'),
#   ('ICT', 'O', 'I-Knowledge'),
#   ('intelligent', 'O', 'I-Knowledge'),
#   ('systems', 'O', 'I-Knowledge'),
#   ('and', 'O', 'O'),
#   ('be', 'O', 'O'),
#   ('proficient', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('design', 'B-Skill', 'O'),
#   ('process', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('Applicants', 'O', 'O'),
#   ('must', 'O', 'O'),
#   ('have', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('analyse', 'B-Skill', 'O'),
#   ('business', 'I-Skill', 'O'),
#   ('requirements', 'I-Skill', 'O'),
#   ('and', 'O', 'O'),
#   ('possess', 'O', 'O'),
#   ('knowledge', 'O', 'B-Knowledge'),
#   ('of', 'O', 'I-Knowledge'),
#   ('ICT', 'O', 'I-Knowledge'),
#   ('capacity', 'O', 'I-Knowledge'),
#   ('planning', 'O', 'I-Knowledge'),
#   ('.', 'O', 'O')],
#  [('The', 'O', 'O'),
#   ('ideal', 'O', 'O'),
#   ('candidate', 'O', 'O'),
#   ('should', 'O', 'O'),
#   ('be', 'O', 'O'),
#   ('able', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('develop', 'B-Skill', 'O'),
#   ('software', 'I-Skill', 'O'),
#   ('prototype', 'I-Skill', 'O'),
#   ('and', 'O', 'O'),
#   ('apply', 'O', 'O'),
#   ('scientific', 'B-Skill', 'O'),
#   ('research', 'I-Skill', 'O'),
#   ('methodology', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('The', 'O', 'O'),
#   ('ideal', 'O', 'O'),
#   ('candidate', 'O', 'O'),
#   ('should', 'O', 'O'),
#   ('be', 'O', 'O'),
#   ('able', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('utilise', 'B-Skill', 'O'),
#   ('computer-aided', 'I-Skill', 'O'),
#   ('software', 'I-Skill', 'O'),
#   ('engineering', 'I-Skill', 'O'),
#   ('tools', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('apply', 'O', 'O'),
#   ('engineering', 'B-Skill', 'O'),
#   ('principles', 'I-Skill', 'O'),
#   ('in', 'O', 'O'),
#   ('software', 'O', 'O'),
#   ('development,', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('proficiently', 'O', 'O'),
#   ('use', 'O', 'O'),
#   ('tools', 'B-Skill', 'O'),
#   ('for', 'I-Skill', 'O'),
#   ('software', 'I-Skill', 'O'),
#   ('configuration', 'I-Skill', 'O'),
#   ('management', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('The', 'O', 'O'),
#   ('ideal', 'O', 'O'),
#   ('candidate', 'O', 'O'),
#   ('will', 'O', 'O'),
#   ('be', 'O', 'O'),
#   ('able', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('manage', 'B-Skill', 'O'),
#   ('ICT', 'I-Skill', 'O'),
#   ('virtualisation', 'I-Skill', 'O'),
#   ('environments', 'I-Skill', 'O'),
#   ('and', 'O', 'O'),
#   ('perform', 'B-Skill', 'O'),
#   ('project', 'I-Skill', 'O'),
#   ('management', 'I-Skill', 'O'),
#   ('tasks', 'O', 'O'),
#   ('effectively.', 'O', 'O')],
#  [('Understanding', 'O', 'B-Knowledge'),
#   ('of', 'O', 'I-Knowledge'),
#   ('search', 'O', 'I-Knowledge'),
#   ('engine', 'O', 'I-Knowledge'),
#   ('optimisation', 'O', 'I-Knowledge'),
#   ('principles', 'O', 'I-Knowledge'),
#   ('is', 'O', 'O'),
#   ('required,', 'O', 'O'),
#   ('with', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('manage', 'B-Skill', 'O'),
#   ('content', 'I-Skill', 'O'),
#   ('development', 'I-Skill', 'O'),
#   ('projects', 'I-Skill', 'O'),
#   ('effectively.', 'O', 'O')],
#  [('The', 'O', 'O'),
#   ('ICT', 'O', 'O'),
#   ('Security', 'O', 'O'),
#   ('Engineer', 'O', 'O'),
#   ('role', 'O', 'O'),
#   ('requires', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('define', 'B-Skill', 'O'),
#   ('technical', 'I-Skill', 'O'),
#   ('requirements', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('apply', 'O', 'O'),
#   ('business', 'B-Skill', 'O'),
#   ('analysis', 'I-Skill', 'O'),
#   ('skills,', 'O', 'O'),
#   ('define', 'B-Skill', 'O'),
#   ('data', 'I-Skill', 'O'),
#   ('quality', 'I-Skill', 'O'),
#   ('criteria', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('have', 'O', 'O'),
#   ('expertise', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('information', 'B-Skill', 'O'),
#   ('architecture', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('The', 'O', 'O'),
#   ('ICT', 'O', 'O'),
#   ('system', 'O', 'O'),
#   ('administrator', 'O', 'O'),
#   ('role', 'O', 'O'),
#   ('requires', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('interpret', 'B-Skill', 'O'),
#   ('technical', 'I-Skill', 'O'),
#   ('texts', 'I-Skill', 'O'),
#   ('and', 'O', 'O'),
#   ('implement', 'B-Skill', 'O'),
#   ('ICT', 'I-Skill', 'O'),
#   ('recovery', 'I-Skill', 'O'),
#   ('systems', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('The', 'O', 'O'),
#   ('ideal', 'O', 'O'),
#   ('candidate', 'O', 'O'),
#   ('should', 'O', 'O'),
#   ('be', 'O', 'O'),
#   ('able', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('use', 'B-Skill', 'O'),
#   ('an', 'I-Skill', 'O'),
#   ('application-specific', 'I-Skill', 'O'),
#   ('interface', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('identify', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('rectify', 'O', 'O'),
#   ('software', 'B-Skill', 'O'),
#   ('anomalies', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('understand', 'O', 'O'),
#   ('different', 'O', 'O'),
#   ('levels', 'B-Skill', 'O'),
#   ('of', 'I-Skill', 'O'),
#   ('software', 'I-Skill', 'O'),
#   ('testing', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('The', 'O', 'O'),
#   ('ICT', 'O', 'O'),
#   ('Security', 'O', 'O'),
#   ('Manager', 'O', 'O'),
#   ('should', 'O', 'O'),
#   ('have', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('strong', 'O', 'O'),
#   ('understanding', 'O', 'O'),
#   ('of', 'O', 'O'),
#   ('internet', 'B-Skill', 'O'),
#   ('governance', 'I-Skill', 'O'),
#   ('and', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('navigate', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('legal', 'B-Skill', 'O'),
#   ('requirements', 'I-Skill', 'O'),
#   ('of', 'I-Skill', 'O'),
#   ('ICT', 'I-Skill', 'O'),
#   ('products', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('Seeking', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('digital', 'O', 'O'),
#   ('games', 'O', 'O'),
#   ('developer', 'O', 'O'),
#   ('with', 'O', 'O'),
#   ('strong', 'O', 'O'),
#   ('computer', 'B-Skill', 'O'),
#   ('programming', 'I-Skill', 'O'),
#   ('skills,', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('execute', 'B-Skill', 'O'),
#   ('analytical', 'I-Skill', 'O'),
#   ('mathematical', 'I-Skill', 'O'),
#   ('calculations', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('expertise', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('3D', 'B-Skill', 'O'),
#   ('texturing', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('The', 'O', 'O'),
#   ('ideal', 'O', 'O'),
#   ('candidate', 'O', 'O'),
#   ('should', 'O', 'O'),
#   ('have', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('analyse', 'B-Skill', 'O'),
#   ('ICT', 'I-Skill', 'O'),
#   ('system', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('apply', 'O', 'O'),
#   ('effective', 'O', 'O'),
#   ('audit', 'B-Skill', 'O'),
#   ('techniques', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('adhere', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('ICT', 'B-Skill', 'O'),
#   ('quality', 'I-Skill', 'O'),
#   ('policy', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('We', 'O', 'O'),
#   ('are', 'O', 'O'),
#   ('seeking', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('Web', 'O', 'O'),
#   ('Developer', 'O', 'O'),
#   ('with', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('debug', 'B-Skill', 'O'),
#   ('software', 'I-Skill', 'O'),
#   ('and', 'O', 'O'),
#   ('proficiency', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('style', 'B-Skill', 'O'),
#   ('sheet', 'I-Skill', 'O'),
#   ('languages', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('Applicants', 'O', 'O'),
#   ('must', 'O', 'O'),
#   ('have', 'O', 'O'),
#   ('a', 'O', 'B-Knowledge'),
#   ('deep', 'O', 'I-Knowledge'),
#   ('understanding', 'O', 'I-Knowledge'),
#   ('of', 'O', 'I-Knowledge'),
#   ('ICT', 'O', 'I-Knowledge'),
#   ('network', 'O', 'I-Knowledge'),
#   ('administration', 'O', 'I-Knowledge'),
#   ('and', 'O', 'O'),
#   ('proficiency', 'B-Skill', 'O'),
#   ('in', 'I-Skill', 'O'),
#   ('computer', 'I-Skill', 'O'),
#   ('programming', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('Applicants', 'O', 'O'),
#   ('must', 'O', 'O'),
#   ('be', 'O', 'O'),
#   ('proficient', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('using', 'O', 'O'),
#   ('ICT', 'B-Skill', 'O'),
#   ('debugging', 'I-Skill', 'O'),
#   ('tools', 'I-Skill', 'O'),
#   ('and', 'O', 'O'),
#   ('have', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('strong', 'O', 'O'),
#   ('command', 'O', 'O'),
#   ('of', 'O', 'O'),
#   ('resource', 'B-Skill', 'O'),
#   ('description', 'I-Skill', 'O'),
#   ('framework', 'I-Skill', 'O'),
#   ('query', 'I-Skill', 'O'),
#   ('language', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('The', 'O', 'O'),
#   ('ideal', 'O', 'O'),
#   ('candidate', 'O', 'O'),
#   ('should', 'O', 'O'),
#   ('be', 'O', 'O'),
#   ('able', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('utilise', 'B-Skill', 'O'),
#   ('content', 'I-Skill', 'O'),
#   ('types', 'I-Skill', 'O'),
#   ('effectively', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('understand', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('legal', 'B-Skill', 'O'),
#   ('requirements', 'I-Skill', 'O'),
#   ('of', 'I-Skill', 'O'),
#   ('ICT', 'I-Skill', 'O'),
#   ('products', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('Seeking', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('digital', 'O', 'O'),
#   ('forensics', 'O', 'O'),
#   ('expert', 'O', 'O'),
#   ('with', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('query', 'B-Skill', 'O'),
#   ('languages', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('maintain', 'O', 'O'),
#   ('information', 'B-Skill', 'O'),
#   ('confidentiality', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('manage', 'B-Skill', 'O'),
#   ('data', 'I-Skill', 'O'),
#   ('for', 'I-Skill', 'O'),
#   ('legal', 'I-Skill', 'O'),
#   ('matters', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('We', 'O', 'O'),
#   ('are', 'O', 'O'),
#   ('seeking', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('software', 'O', 'O'),
#   ('tester', 'O', 'O'),
#   ('with', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('understand', 'O', 'B-Knowledge'),
#   ('and', 'O', 'I-Knowledge'),
#   ('apply', 'O', 'I-Knowledge'),
#   ('software', 'O', 'I-Knowledge'),
#   ('testing', 'O', 'I-Knowledge'),
#   ('principles', 'O', 'I-Knowledge'),
#   ('and', 'O', 'O'),
#   ('address', 'B-Skill', 'O'),
#   ('problems', 'I-Skill', 'O'),
#   ('critically', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('The', 'O', 'O'),
#   ('ideal', 'O', 'O'),
#   ('candidate', 'O', 'O'),
#   ('will', 'O', 'O'),
#   ('be', 'O', 'O'),
#   ('able', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('train', 'B-Skill', 'O'),
#   ('employees', 'I-Skill', 'O'),
#   ('on', 'O', 'O'),
#   ('various', 'O', 'O'),
#   ('ICT', 'O', 'O'),
#   ('process', 'O', 'O'),
#   ('quality', 'O', 'O'),
#   ('models', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('ensure', 'O', 'O'),
#   ('their', 'O', 'O'),
#   ('effective', 'O', 'O'),
#   ('implementation.', 'O', 'O')],
#  [('We', 'O', 'O'),
#   ('are', 'O', 'O'),
#   ('seeking', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('Cloud', 'O', 'O'),
#   ('Engineer', 'O', 'O'),
#   ('who', 'O', 'O'),
#   ('can', 'O', 'O'),
#   ('plan', 'B-Skill', 'O'),
#   ('migration', 'I-Skill', 'O'),
#   ('to', 'I-Skill', 'O'),
#   ('cloud', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('develop', 'B-Skill', 'O'),
#   ('with', 'I-Skill', 'O'),
#   ('cloud', 'I-Skill', 'O'),
#   ('services', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('has', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('strong', 'O', 'O'),
#   ('understanding', 'O', 'O'),
#   ('of', 'O', 'O'),
#   ('cyber', 'B-Skill', 'O'),
#   ('security', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('is', 'O', 'O'),
#   ('proficient', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('ICT', 'B-Skill', 'O'),
#   ('system', 'I-Skill', 'O'),
#   ('programming', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('We', 'O', 'O'),
#   ('are', 'O', 'O'),
#   ('seeking', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('Data', 'O', 'O'),
#   ('Quality', 'O', 'O'),
#   ('Specialist', 'O', 'O'),
#   ('who', 'O', 'O'),
#   ('can', 'O', 'O'),
#   ('use', 'B-Skill', 'O'),
#   ('data', 'I-Skill', 'O'),
#   ('processing', 'I-Skill', 'O'),
#   ('techniques', 'I-Skill', 'O'),
#   ('to', 'O', 'O'),
#   ('ensure', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('accuracy', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('integrity', 'O', 'O'),
#   ('of', 'O', 'O'),
#   ('our', 'O', 'O'),
#   ('data,', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('who', 'O', 'O'),
#   ('can', 'O', 'O'),
#   ('address', 'B-Skill', 'O'),
#   ('problems', 'I-Skill', 'O'),
#   ('critically', 'I-Skill', 'O'),
#   ('to', 'O', 'O'),
#   ('identify', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('resolve', 'O', 'O'),
#   ('any', 'O', 'O'),
#   ('data', 'O', 'O'),
#   ('quality', 'O', 'O'),
#   ('issues.', 'O', 'O')],
#  [('Seeking', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('Database', 'O', 'O'),
#   ('Integrator', 'O', 'O'),
#   ('with', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('balance', 'B-Skill', 'O'),
#   ('database', 'I-Skill', 'O'),
#   ('resources', 'I-Skill', 'O'),
#   ('and', 'O', 'O'),
#   ('verify', 'B-Skill', 'O'),
#   ('formal', 'I-Skill', 'O'),
#   ('ICT', 'I-Skill', 'O'),
#   ('specifications', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('Applicants', 'O', 'O'),
#   ('must', 'O', 'O'),
#   ('have', 'O', 'O'),
#   ('knowledge', 'O', 'B-Knowledge'),
#   ('of', 'O', 'I-Knowledge'),
#   ('ICT', 'O', 'I-Knowledge'),
#   ('system', 'O', 'I-Knowledge'),
#   ('architecture', 'O', 'I-Knowledge'),
#   ('and', 'O', 'O'),
#   ('skills', 'B-Skill', 'O'),
#   ('in', 'I-Skill', 'O'),
#   ('business', 'I-Skill', 'O'),
#   ('process', 'I-Skill', 'O'),
#   ('modelling', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('Seeking', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('Database', 'O', 'O'),
#   ('Administrator', 'O', 'O'),
#   ('proficient', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('system', 'B-Skill', 'O'),
#   ('backup', 'I-Skill', 'O'),
#   ('best', 'I-Skill', 'O'),
#   ('practices', 'I-Skill', 'O'),
#   ('and', 'O', 'O'),
#   ('data', 'B-Skill', 'O'),
#   ('quality', 'I-Skill', 'O'),
#   ('assessment', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('The', 'O', 'O'),
#   ('ideal', 'O', 'O'),
#   ('candidate', 'O', 'O'),
#   ('for', 'O', 'O'),
#   ('our', 'O', 'O'),
#   ('Data', 'O', 'O'),
#   ('Scientist', 'O', 'O'),
#   ('role', 'O', 'O'),
#   ('should', 'O', 'O'),
#   ('be', 'O', 'O'),
#   ('able', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('interact', 'B-Skill', 'O'),
#   ('professionally', 'I-Skill', 'O'),
#   ('in', 'I-Skill', 'O'),
#   ('research', 'I-Skill', 'O'),
#   ('and', 'I-Skill', 'O'),
#   ('professional', 'I-Skill', 'O'),
#   ('environments', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('have', 'O', 'O'),
#   ('proficiency', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('resource', 'B-Skill', 'O'),
#   ('description', 'I-Skill', 'O'),
#   ('framework', 'I-Skill', 'O'),
#   ('query', 'I-Skill', 'O'),
#   ('language', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('be', 'O', 'O'),
#   ('able', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('develop', 'B-Skill', 'O'),
#   ('a', 'I-Skill', 'O'),
#   ('professional', 'I-Skill', 'O'),
#   ('network', 'I-Skill', 'O'),
#   ('with', 'I-Skill', 'O'),
#   ('researchers', 'I-Skill', 'O'),
#   ('and', 'I-Skill', 'O'),
#   ('scientists', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('The', 'O', 'O'),
#   ('ICT', 'O', 'O'),
#   ('application', 'O', 'O'),
#   ('configurator', 'O', 'O'),
#   ('role', 'O', 'O'),
#   ('requires', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('analyse', 'B-Skill', 'O'),
#   ('software', 'I-Skill', 'O'),
#   ('specifications', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('expertise', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('computer', 'B-Skill', 'O'),
#   ('programming', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('proficiency', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('using', 'O', 'O'),
#   ('ICT', 'B-Skill', 'O'),
#   ('debugging', 'I-Skill', 'O'),
#   ('tools', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('and', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('skill', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('debug', 'B-Skill', 'O'),
#   ('software', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('The', 'O', 'O'),
#   ('ideal', 'O', 'O'),
#   ('candidate', 'O', 'O'),
#   ('for', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('User', 'O', 'O'),
#   ('Experience', 'O', 'O'),
#   ('Analyst', 'O', 'O'),
#   ('role', 'O', 'O'),
#   ('should', 'O', 'O'),
#   ('have', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('strong', 'O', 'O'),
#   ('understanding', 'O', 'O'),
#   ('of', 'O', 'O'),
#   ('cognitive', 'B-Skill', 'O'),
#   ('psychology', 'I-Skill', 'O'),
#   (',', 'O', 'O'),
#   ('with', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('assess', 'B-Skill', 'O'),
#   ("users'", 'I-Skill', 'O'),
#   ('interaction', 'I-Skill', 'O'),
#   ('with', 'I-Skill', 'O'),
#   ('ICT', 'I-Skill', 'O'),
#   ('applications', 'I-Skill', 'O'),
#   ('.', 'O', 'O'),
#   ('They', 'O', 'O'),
#   ('should', 'O', 'O'),
#   ('also', 'O', 'O'),
#   ('have', 'O', 'O'),
#   ('expertise', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('human-computer', 'B-Skill', 'O'),
#   ('interaction', 'I-Skill', 'O'),
#   ('and', 'O', 'O'),
#   ('be', 'O', 'O'),
#   ('able', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('effectively', 'O', 'O'),
#   ('report', 'B-Skill', 'O'),
#   ('analysis', 'I-Skill', 'O'),
#   ('results', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('Applicants', 'O', 'O'),
#   ('must', 'O', 'O'),
#   ('have', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('solid', 'O', 'O'),
#   ('understanding', 'O', 'O'),
#   ('of', 'O', 'O'),
#   ('industrial', 'O', 'B-Knowledge'),
#   ('mobile', 'O', 'I-Knowledge'),
#   ('devices', 'O', 'I-Knowledge'),
#   ('software', 'O', 'I-Knowledge'),
#   ('development', 'O', 'I-Knowledge'),
#   ('and', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('use', 'B-Skill', 'O'),
#   ('software', 'I-Skill', 'O'),
#   ('libraries', 'I-Skill', 'O'),
#   ('effectively.', 'O', 'O')],
#  [('We', 'O', 'O'),
#   ('are', 'O', 'O'),
#   ('seeking', 'O', 'O'),
#   ('an', 'O', 'O'),
#   ('ICT', 'O', 'O'),
#   ('quality', 'O', 'O'),
#   ('assurance', 'O', 'O'),
#   ('manager', 'O', 'O'),
#   ('with', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('perform', 'B-Skill', 'O'),
#   ('quality', 'I-Skill', 'O'),
#   ('audits', 'I-Skill', 'O'),
#   ('and', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('deep', 'O', 'O'),
#   ('understanding', 'O', 'B-Knowledge'),
#   ('of', 'O', 'I-Knowledge'),
#   ('ICT', 'O', 'I-Knowledge'),
#   ('quality', 'O', 'I-Knowledge'),
#   ('standards', 'O', 'I-Knowledge'),
#   ('.', 'O', 'O')],
#  [('Looking', 'O', 'O'),
#   ('for', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('system', 'O', 'O'),
#   ('configurator', 'O', 'O'),
#   ('able', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('develop', 'B-Skill', 'O'),
#   ('automated', 'I-Skill', 'O'),
#   ('migration', 'I-Skill', 'O'),
#   ('methods', 'I-Skill', 'O'),
#   ('and', 'O', 'O'),
#   ('understand', 'O', 'O'),
#   ('ICT', 'B-Skill', 'O'),
#   ('system', 'I-Skill', 'O'),
#   ('user', 'I-Skill', 'O'),
#   ('requirements', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('Applicants', 'O', 'O'),
#   ('must', 'O', 'O'),
#   ('have', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('interpret', 'B-Skill', 'O'),
#   ('technical', 'I-Skill', 'O'),
#   ('texts', 'I-Skill', 'O'),
#   ('related', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('ICT', 'O', 'B-Knowledge'),
#   ('network', 'O', 'I-Knowledge'),
#   ('administration', 'O', 'I-Knowledge'),
#   ('.', 'O', 'O')],
#  [('Understanding', 'O', 'B-Knowledge'),
#   ('of', 'O', 'I-Knowledge'),
#   ('database', 'O', 'I-Knowledge'),
#   ('structures,', 'O', 'I-Knowledge'),
#   ('theories,', 'O', 'I-Knowledge'),
#   ('principles,', 'O', 'I-Knowledge'),
#   ('and', 'O', 'I-Knowledge'),
#   ('practices', 'O', 'I-Knowledge'),
#   ('is', 'O', 'O'),
#   ('required,', 'O', 'O'),
#   ('with', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('perform', 'B-Skill', 'O'),
#   ('backups', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('Applicants', 'O', 'O'),
#   ('must', 'O', 'O'),
#   ('have', 'O', 'O'),
#   ('a', 'O', 'O'),
#   ('solid', 'O', 'O'),
#   ('understanding', 'O', 'O'),
#   ('of', 'O', 'O'),
#   ('ICT', 'O', 'B-Knowledge'),
#   ('application', 'O', 'I-Knowledge'),
#   ('configuration', 'O', 'I-Knowledge'),
#   ('and', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('debug', 'B-Skill', 'O'),
#   ('software', 'I-Skill', 'O'),
#   ('.', 'O', 'O')],
#  [('Applicants', 'O', 'O'),
#   ('should', 'O', 'O'),
#   ('have', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('knowledge', 'O', 'B-Knowledge'),
#   ('of', 'O', 'I-Knowledge'),
#   ('various', 'O', 'I-Knowledge'),
#   ('software', 'O', 'I-Knowledge'),
#   ('libraries', 'O', 'I-Knowledge'),
#   ('and', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'B-Skill', 'O'),
#   ('to', 'I-Skill', 'O'),
#   ('use', 'I-Skill', 'O'),
#   ('these', 'I-Skill', 'O'),
#   ('software', 'I-Skill', 'O'),
#   ('libraries', 'I-Skill', 'O'),
#   ('effectively', 'O', 'O'),
#   ('for', 'O', 'O'),
#   ('user', 'O', 'O'),
#   ('interface', 'O', 'O'),
#   ('development.', 'O', 'O')],
#  [('The', 'O', 'O'),
#   ('ICT', 'O', 'O'),
#   ('intelligent', 'O', 'O'),
#   ('systems', 'O', 'O'),
#   ('designer', 'O', 'O'),
#   ('role', 'O', 'O'),
#   ('requires', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('ability', 'O', 'O'),
#   ('to', 'O', 'O'),
#   ('utilize', 'O', 'O'),
#   ('visual', 'B-Skill', 'O'),
#   ('presentation', 'I-Skill', 'O'),
#   ('techniques', 'I-Skill', 'O'),
#   ('and', 'O', 'O'),
#   ('proficiency', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('the', 'O', 'O'),
#   ('resource', 'B-Skill', 'O'),
#   ('description', 'I-Skill', 'O'),
#   ('framework', 'I-Skill', 'O'),
#   ('query', 'I-Skill', 'O'),
#   ('language', 'I-Skill', 'O'),
#   ('.', 'O', 'O')]]

# %%
import json

with open("data/generated_data.json", 'w') as f:
    json.dump(cleaned_results, f)

# %%
def append_sentences_to_conll(filename, sentences_to_append):
    """
    Append given sentences to a CoNLL-format file, ensuring proper formatting.
    
    Args:
    - filename (str): Path to the CoNLL file.
    - sentences_to_append (list of list of tuples): Sentences to append, where each
      sentence is represented as a list of tuples, each containing a word followed
      by its skill tag and knowledge tag.
    """
    # Open the file to append
    with open(filename, 'a') as file:
        # For each sentence in the list
        for sentence in sentences_to_append:
            # Ensure each new sentence starts on a new line
            file.write("\n")  # This line ensures separation from previous content
            for word, skill_tag, knowledge_tag in sentence:
                # Write each word with its skill and knowledge tags, followed by a newline
                file.write(f"{word}\t{skill_tag}\t{knowledge_tag}\n")

append_sentences_to_conll("data/SkillSpan/Skills/skillspan_tech_train_enriched.conll", bio_splitted_sentences)
