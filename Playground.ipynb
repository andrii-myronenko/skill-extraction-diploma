# %%
# !which conda
# !which python

# %%
# !pip install transformers
# !pip install sentence-transformers

# !pip -q install langchain huggingface_hub openai
# !pip install pandas
# !pip install numpy
# !pip install python-dotenv

# !pip install fireworks-ai

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import pandas as pd

file_path = './data/Benchmark dataset/tech_test_annotations.csv'
test_dataset = pd.read_csv(file_path)

test_dataset
# Out:
#                                                sentence  \
# 0                               django postgresql redis
# 1                               django postgresql redis
# 2                               django postgresql redis
# 3                               django postgresql redis
# 4                               django postgresql redis
# ...                                                 ...
# 1159  Independently and quick adoption of new techno...
# 1160  Willingness to speak at conferences and engage...
# 1161  Willingness to speak at conferences and engage...
# 1162  Effective oral and written English communicati...
# 1163  Effective oral and written English communicati...
#
#                                     span sub_span  \
# 0                                 django      NaN
# 1                             postgresql      NaN
# 2                                  redis      NaN
# 3                                 django      NaN
# 4                             postgresql      NaN
# ...                                  ...      ...
# 1159  quick adoption of new technologies      NaN
# 1160                speak at conferences      NaN
# 1161             engage in the community      NaN
# 1162                       communication      NaN
# 1163                             English      NaN
#
#                                   label
# 0                     LABEL NOT PRESENT
# 1                            PostgreSQL
# 2                     LABEL NOT PRESENT
# 3                     LABEL NOT PRESENT
# 4                            PostgreSQL
# ...                                 ...
# 1159              emergent technologies
# 1160                address an audience
# 1161  communicate with target community
# 1162                      communication
# 1163                            English
#
# [1164 rows x 4 columns]

# %%
test_dataset.shape
# Out:
# (1164, 4)

# %%
file_path = './data/Benchmark dataset/tech_validation_annotations.csv'
validation_dataset = pd.read_csv(file_path)

validation_dataset
# Out:
#                                               sentence  \
# 0                              javascript reactjs java
# 1                              javascript reactjs java
# 2                              javascript reactjs java
# 3                              javascript reactjs java
# 4                              javascript reactjs java
# ..                                                 ...
# 288  2 ) Knowledge of public and private cloud offe...
# 289  2 ) Knowledge of public and private cloud offe...
# 290  3 ) Data warehousing/ETL experience would be u...
# 291  4 ) Knowledge of fixed income instruments and ...
# 292  4 ) Knowledge of fixed income instruments and ...
#
#                                    span                 sub_span  \
# 0                            javascript                      NaN
# 1                               reactjs                      NaN
# 2                                  java                      NaN
# 3                            javascript                      NaN
# 4                               reactjs                      NaN
# ..                                  ...                      ...
# 288  public and private cloud offerings   public cloud offerings
# 289  public and private cloud offerings  private cloud offerings
# 290                Data warehousing/ETL                      NaN
# 291            fixed income instruments                      NaN
# 292                      reference data                      NaN
#
#                                      label
# 0                               JavaScript
# 1                        LABEL NOT PRESENT
# 2              Java (computer programming)
# 3                               JavaScript
# 4                        LABEL NOT PRESENT
# ..                                     ...
# 288                     cloud technologies
# 289                      LABEL NOT PRESENT
# 290  implement data warehousing techniques
# 291                      LABEL NOT PRESENT
# 292                      LABEL NOT PRESENT
#
# [293 rows x 4 columns]

# %%
validation_dataset.shape
# Out:
# (293, 4)

# %%
def dataset_insights(df):
    filtered_dataset = df[~df['label'].isin(['LABEL NOT PRESENT', 'UNDERSPECIFIED'])]
    unique_skills_with_label = filtered_dataset['span'].nunique()
    total_skills_with_label = filtered_dataset['span'].count()
    label_not_present_count = df[df['label'] == 'LABEL NOT PRESENT']['span'].count()
    underspecified_count = df[df['label'] == 'UNDERSPECIFIED']['span'].count()
    insights = {
        'Unique Skills with Labels': unique_skills_with_label,
        'Total Annotated Skills': total_skills_with_label,
        'LABEL NOT PRESENT Count': label_not_present_count,
        'UNDERSPECIFIED Count': underspecified_count
    }

    return insights

dataset_insights(test_dataset)
# Out:
# {'Unique Skills with Labels': 437,
#  'Total Annotated Skills': 674,
#  'LABEL NOT PRESENT Count': 390,
#  'UNDERSPECIFIED Count': 100}

# %%
dataset_insights(validation_dataset)
# Out:
# {'Unique Skills with Labels': 89,
#  'Total Annotated Skills': 153,
#  'LABEL NOT PRESENT Count': 127,
#  'UNDERSPECIFIED Count': 13}

# %%
from sentence_transformers import SentenceTransformer, util
model = SentenceTransformer('intfloat/e5-large-v2')

query_embedding = model.encode('Java (computer programming)')
passage_embedding = model.encode(['javascript reactjs java',
                                  'Able to frame problems drive teams to collect data guide the analysis and to present the data to influence leadership'])

print("Similarity:", util.dot_score(query_embedding, passage_embedding))
# Out:
# Similarity: tensor([[0.8491, 0.7260]])

# %%
file_path = './data/ESCO/skills_en.csv'
esco_dataset = pd.read_csv(file_path)

esco_dataset
# Out:
#                     conceptType  \
# 0      KnowledgeSkillCompetence
# 1      KnowledgeSkillCompetence
# 2      KnowledgeSkillCompetence
# 3      KnowledgeSkillCompetence
# 4      KnowledgeSkillCompetence
# ...                         ...
# 13891  KnowledgeSkillCompetence
# 13892  KnowledgeSkillCompetence
# 13893  KnowledgeSkillCompetence
# 13894  KnowledgeSkillCompetence
# 13895  KnowledgeSkillCompetence
#
#                                               conceptUri         skillType  \
# 0      http://data.europa.eu/esco/skill/0005c151-5b5a...  skill/competence
# 1      http://data.europa.eu/esco/skill/00064735-8fad...  skill/competence
# 2      http://data.europa.eu/esco/skill/000709ed-2be5...  skill/competence
# 3      http://data.europa.eu/esco/skill/0007bdc2-dd15...  skill/competence
# 4      http://data.europa.eu/esco/skill/00090cc1-1f27...  skill/competence
# ...                                                  ...               ...
# 13891  http://data.europa.eu/esco/skill/ffef5eb3-a15e...  skill/competence
# 13892  http://data.europa.eu/esco/skill/fff0b074-5a76...  skill/competence
# 13893  http://data.europa.eu/esco/skill/fff0e2cd-d0bd...         knowledge
# 13894  http://data.europa.eu/esco/skill/fff5bc45-b506...  skill/competence
# 13895  http://data.europa.eu/esco/skill/fff74a70-4f82...  skill/competence
#
#                 reuseLevel                                     preferredLabel  \
# 0          sector-specific                               manage musical staff
# 1      occupation-specific                  supervise correctional procedures
# 2          sector-specific                    apply anti-oppressive practices
# 3          sector-specific  control compliance of railway vehicles regulat...
# 4             cross-sector                        identify available services
# ...                    ...                                                ...
# 13891      sector-specific  remediate healthcare user's occupational perfo...
# 13892      sector-specific               install transport equipment lighting
# 13893      sector-specific                        natural language processing
# 13894         cross-sector                 coordinate construction activities
# 13895         cross-sector                  position guardrails and toeboards
#
#                                                altLabels hiddenLabels  \
# 0      manage staff of music\ncoordinate duties of mu...          NaN
# 1      oversee prison procedures\nmanage correctional...          NaN
# 2      apply non-oppressive practices\napply an anti-...          NaN
# 3      monitoring of compliance with railway vehicles...          NaN
# 4      establish available services\nidentify availab...          NaN
# ...                                                  ...          ...
# 13891  restore healthcare user's occupational perform...          NaN
# 13892  install transport equipment illumination\nfix ...          NaN
# 13893                   natural language processing\nNLP          NaN
# 13894  reviewing construction progress\nconstruction ...          NaN
# 13895  positioning guardrails and toeboards\nattachme...          NaN
#
#          status              modifiedDate scopeNote definition  \
# 0      released      2016-12-20T17:43:43Z       NaN        NaN
# 1      released      2016-12-20T20:17:49Z       NaN        NaN
# 2      released      2016-12-20T19:18:19Z       NaN        NaN
# 3      released      2016-12-20T20:02:19Z       NaN        NaN
# 4      released      2016-12-20T20:15:17Z       NaN        NaN
# ...         ...                       ...       ...        ...
# 13891  released      2016-12-20T19:25:53Z       NaN        NaN
# 13892  released      2016-12-20T20:03:21Z       NaN        NaN
# 13893  released  2022-07-05T14:34:09.904Z       NaN        NaN
# 13894  released      2016-12-20T18:22:35Z       NaN        NaN
# 13895  released      2016-12-20T18:24:23Z       NaN        NaN
#
#                                                 inScheme  \
# 0      http://data.europa.eu/esco/concept-scheme/skil...
# 1      http://data.europa.eu/esco/concept-scheme/memb...
# 2      http://data.europa.eu/esco/concept-scheme/skil...
# 3      http://data.europa.eu/esco/concept-scheme/skil...
# 4      http://data.europa.eu/esco/concept-scheme/memb...
# ...                                                  ...
# 13891  http://data.europa.eu/esco/concept-scheme/memb...
# 13892  http://data.europa.eu/esco/concept-scheme/skil...
# 13893  http://data.europa.eu/esco/concept-scheme/skil...
# 13894  http://data.europa.eu/esco/concept-scheme/skil...
# 13895  http://data.europa.eu/esco/concept-scheme/skil...
#
#                                              description
# 0      Assign and manage staff tasks in areas such as...
# 1      Supervise the operations of a correctional fac...
# 2      Identify oppression in societies, economies, c...
# 3      Inspect rolling stock, components and systems ...
# 4      Identify the different services available for ...
# ...                                                  ...
# 13891  Remediate or restore the cognitive, sensorimot...
# 13892  Install lighting elements in transport equipme...
# 13893  The technologies which enable ICT devices to u...
# 13894  Coordinate the activities of several construct...
# 13895  Attach guardrails and toeboards to the scaffol...
#
# [13896 rows x 13 columns]

# %%
# !docker run --name skill-extraction-redis -d -p 6379:6379 -v ./redis_data:/data redis/redis-stack:latest

import redis 

client = redis.Redis(host='localhost', port=6379, db=0)

keys = client.keys('skill:*')

print(len(keys))

for key in keys[0:5]:
    skill_data = client.json().get(key)
    label = skill_data['label']

    print(f"Key: {key.decode('utf-8')}, Label: {label}" )
# Out:
# 13896
# Key: skill:06063, Label: conserve new media
# Key: skill:06483, Label: maintain gaming equipment
# Key: skill:07497, Label: economics
# Key: skill:03605, Label: examine cell specimens microscopically
# Key: skill:08146, Label: strategic planning

# %%
import numpy as np

def create_query_table(query, queries, encoded_queries, extra_params={}):
    results_list = []
    for i, encoded_query in enumerate(encoded_queries):
        result_docs = (
            client.ft("idx:skills")
            .search(
                query,
                {
                    "query_vector": np.array(
                        encoded_query, dtype=np.float32
                    ).tobytes()
                }
                | extra_params,
            )
            .docs
        )
        for doc in result_docs:
            vector_score = round(1 - float(doc.vector_score), 2)
            results_list.append(
                {
                    "query": queries[i],
                    "score": vector_score,
                    "label": doc.label,
                }
            )

    # Optional: convert the table to Markdown using Pandas
    queries_table = pd.DataFrame(results_list)
    queries_table.sort_values(
        by=["query", "score"], ascending=[True, False], inplace=True
    )
    queries_table["query"] = queries_table.groupby("query")["query"].transform(
        lambda x: [x.iloc[0]] + [""] * (len(x) - 1)
    )
    queries_table.to_markdown(index=False)
    
    return queries_table

# %%
from redis.commands.search.query import Query

queries = ["plan business strategy"]
encoded_queries = model.encode(queries)

query = (
    Query("(*)=>[KNN 5 @embedding $query_vector AS vector_score]")
    .sort_by("vector_score")
    .return_fields('vector_score', 'label')
    .dialect(2)
)


create_query_table(query, queries, encoded_queries)
# Out:
#                     query  score                              label
# 0  plan business strategy   0.95            plan marketing strategy
# 1                           0.92             develop business plans
# 2                           0.91             analyse business plans
# 3                           0.90           plan marketing campaigns
# 4                           0.90  make strategic business decisions

# %%
import os

def load_text_files(folder_path):
    text_data_with_names = []
    text_contents_only = []
    
    for filename in os.listdir(folder_path):
        if filename.endswith(".txt"):
            file_path = os.path.join(folder_path, filename)
            
            with open(file_path, 'r', encoding='utf-8') as file:
                content = file.read()
                # Store content and file names in a list of dictionaries
                text_data_with_names.append({
                    'file_name': filename,
                    'content': content
                })
                # Store just the content in a separate list
                text_contents_only.append(content)
    
    return text_data_with_names, text_contents_only

folder_path = './data/Job postings'
job_postings_with_names, job_postings_contents = load_text_files(folder_path)

for job_posting in job_postings_with_names:
    print(job_posting['file_name'], len(job_posting['content']))
# Out:
# 5.txt 2820
# 4.txt 4828
# 3.txt 1497
# 2.txt 2192
# 1.txt 1108

# %%
from langchain import LLMChain, PromptTemplate
from langchain.memory import ConversationBufferWindowMemory

template = """
You are a recruiter.
Your task is to thoroughly analyze the following job posting. 
Extract a complete list of required skills, encompassing both technical and interpersonal aspects. 
Ensure this list is non-repetitive, and reflective of the varied skill sets demanded. 
Present your findings in a single python array. Each skill should be a string enclosed in double quotes 
Output just the array, wihtout any other text. 
Start your response with "[" symbol, and finish with "]". Make sure your response doesn't include anything else.

Job posting:
{job_posing}

Response:"""

prompt_template = PromptTemplate(input_variables=["job_posing"], template=template)

# %%
from langchain.llms.fireworks import Fireworks 

llm = Fireworks(model="accounts/fireworks/models/llama-v2-70b-chat", max_tokens=256, temperature=1)

# %%
responses = []
for job_posting in job_postings_contents:
    prompt_val = prompt_template.invoke({"job_posing": job_posting})
    prompt = prompt_val.to_string()
    output = llm(prompt)
    responses.append(output)

for response in responses:
    print(response)
# Out:
# [
# "Node/Nest JS",
# "ReactJS",
# "PostgreSQL",
# "MongoDB",
# "Redis",
# "Python",
# "REST APIs",
# "AWS cloud services",
# "Kubernetes",
# "Infrastructure as Code (IAAC)",
# "OpenAI API",
# "LLM propmt engineering",
# "Twilio",
# "CRMs",
# "Mail",
# "Follow Up Boss",
# "Outlook",
# "Architecture",
# "Design",
# "Development",
# "Team management",
# "Mentoring",
# "Code reviews",
# "Git repositories",
# "Coding practices",
# "Security",
# "Efficiency",
# "Cloud infrastructure",
# "Performance",
# "Scalability",
# "UX/UI",
# "Sales",
# "Product development",
# "Dashboard",
# "Call center software",
# "Speech to text",
# "Transcribe",
# "Conversation analyze software"
# ]
#
#
# [
# "Microsoft Dynamics 365",
# "ERP systems",
# "project management",
# "Microsoft Project",
# "project planning",
# "task distribution",
# "project documentation",
# "budget management",
# "time management",
# "scope management",
# "risk management",
# "client communication",
# "team management",
# "interviewing",
# "recruiting",
# "project methodology",
# "ERP implementation",
# "data collection",
# "Go-Live",
# "Ukrainian language",
# "English language",
# "fluency",
# "project management certification",
# "PMI",
# "IPMA",
# "teamwork",
# "communication skills",
# "result-oriented",
# "quality-oriented",
# "motivation",
# "inspiration",
# "potential realization",
# "freelance cooperation",
# "hourly rate",
# "full-time cooperation",
# "career growth",
# "advanced training",
# "Microsoft international certification",
# "remote work",
# "paid vacation",
# "sick leave",
# "standardized working hours",
# "competitive remuneration",
# "permanent full-time contract"
# ]
#
# [ "Extensive experience in Windows application development",
# "Good understanding of the Windows installation & packaging process",
# "Proficient in C++",
# "Effective communication skills",
# "Ability to work independently in a remote-first environment",
# "Ability to occasionally collaborate (join meetings) with co-workers working in the PDT time zone",
# "Strong writing and verbal skills in English",
# "Improve the virtual mic Windows installer to ensure it is not falsely flagged by antivirus software",
# "Develop features to register the software with the server during the initial installation and unregister during the uninstallation process",
# "Closely collaborate with other engineers"
# ]
#
#
# ["SQL", "Java", "JavaScript", "frontend frameworks", "HTML", "CSS", "AJAX", "REST", "single-page apps", "Upper-intermediate English", "React", "Angular", "D3", "C3", "bootstrap", "JAX-WS", "Jersey", "scalable web app design", "Amazon Web Services", "Linux", "ETL", "open-source projects"]
#
# [
# "Desire to learn and grow",
# "Product-oriented mindset",
# "Java 11 or higher experience",
# "Good knowledge of Spring (Boot, Security, MVC, Data JPA, Batch)",
# "Experience with microservices",
# "Knowledge of Docker and Kubernetes",
# "Intermediate or higher English level",
# "Microservice architecture",
# "monorepo",
# "Spring (Boot, Batch, Cloud, MVC, JPA) + Java 17",
# "Scala",
# "Go",
# "Bazel (build tool by Google)",
# "Kubernetes cluster on bare metal",
# "Gitlab CI",
# "Persistence: PostgreSQL, CockroachDB, Clickhouse, Apache Spark, Apache Kafka, Redis, Elasticsearch",
# "Frontend tech: ReactJS + TypeScript",
# "Tests: JUnit, Mockito, Playwright, Test Containers",
# "Monitoring: Sentry, Grafana"
# ]

# %%
import ast

skills_lists = []

for response in responses:
    array_start = response.find('[')
    array_end = response.find(']', array_start)

    array_string = response[array_start:array_end+1].strip()
    skills_lists.append(ast.literal_eval(array_string))

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)

for skills in skills_lists[:5]:  # Process only the first 5 arrays
    queries = skills  # Each sublist is an array of skills/queries
    encoded_queries = model.encode(queries)

    # Constructing the query might involve replacing placeholders
    query = (
        Query("(*)=>[KNN 5 @embedding $query_vector AS vector_score]")
        .sort_by("vector_score")
        .return_fields('vector_score', 'label')
        .dialect(2)
    )

    # Call the function that creates and prints the table
    table = create_query_table(query, queries, encoded_queries)
    print(table)
    print("\n")  # Just to add space between tables

# Reset pandas options after printing
pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')
pd.reset_option('display.width')
# Out:
#                              query  score                                          label
# 35              AWS cloud services   0.86                    develop with cloud services
# 36                                   0.85                             cloud technologies
# 37                                   0.84                              SAP Data Services
# 38                                   0.84                  manage cloud data and storage
# 39                                   0.83                           automate cloud tasks
# 85                    Architecture   0.91                           architectural design
# 86                                   0.89                           architectural theory
# 87                                   0.88                         landscape architecture
# 88                                   0.87                          historic architecture
# 89                                   0.87                                    archaeology
# 65                            CRMs   0.86               customer relationship management
# 66                                   0.83  use customer relationship management software
# 67                                   0.83                                         WebCMS
# 68                                   0.83                            document management
# 69                                   0.82                      health records management
# 170           Call center software   0.90                       call-centre technologies
# 171                                  0.88                                office software
# 172                                  0.87                            industrial software
# 173                                  0.86                                   CAD software
# 174                                  0.85                                   CAM software
# 135           Cloud infrastructure   0.90                             ICT infrastructure
# 136                                  0.89                            rail infrastructure
# 137                                  0.88                             cloud technologies
# 138                                  0.88             e-learning software infrastructure
# 139                                  0.85                  manage cloud data and storage
# 110                   Code reviews   0.88                        conduct ICT code review
# 111                                  0.87                                   book reviews
# 112                                  0.86                      review ship documentation
# 113                                  0.86                                  review drafts
# 114                                  0.85                       review translation works
# 120               Coding practices   0.88               implement ICT coding conventions
# 121                                  0.88                                clinical coding
# 122                                  0.87             perform clinical coding procedures
# 123                                  0.85                   good manufacturing practices
# 124                                  0.85                                test procedures
# 185  Conversation analyze software   0.84   use communication and collaboration software
# 186                                  0.84           statistical analysis system software
# 187                                  0.84                         audio editing software
# 188                                  0.83                 specialised astrology software
# 189                                  0.83                      design job analysis tools
# 165                      Dashboard   0.84                                        sensors
# 166                                  0.83                                       database
# 167                                  0.82                                  web analytics
# 168                                  0.81                                        Angular
# 169                                  0.81                                    manage data
# 90                          Design   0.91                                design hardware
# 91                                   0.91                               design buildings
# 92                                   0.90                                 design process
# 93                                   0.90                                   design floor
# 94                                   0.90                           architectural design
# 95                     Development   0.88                           personal development
# 96                                   0.87                          watershed development
# 97                                   0.87                        Incremental development
# 98                                   0.87                              Agile development
# 99                                   0.87                             development delays
# 130                     Efficiency   0.90                              energy efficiency
# 131                                  0.90                               work efficiently
# 132                                  0.87                                         energy
# 133                                  0.86                                     aesthetics
# 134                                  0.86              advise on efficiency improvements
# 75                  Follow Up Boss   0.89                 follow up orders for customers
# 76                                   0.89                    follow up complaint reports
# 77                                   0.88                          follow-up lab results
# 78                                   0.88                     provide customer follow-up
# 79                                   0.86            provide customer follow-up services
# 115               Git repositories   0.84                                         DevOps
# 116                                  0.83                             Visual Studio .NET
# 117                                  0.83                            software frameworks
# 118                                  0.83          maintain a central project repository
# 119                                  0.83                           blockchain platforms
# 45   Infrastructure as Code (IAAC)   0.82                             ICT infrastructure
# 46                                   0.81            ensure infrastructure accessibility
# 47                                   0.81       promote innovative infrastructure design
# 48                                   0.81                          mobility as a service
# 49                                   0.81               implement ICT coding conventions
# 40                      Kubernetes   0.87                                         DevOps
# 41                                   0.83                           blockchain platforms
# 42                                   0.83                                  Apache Tomcat
# 43                                   0.83                                         Hadoop
# 44                                   0.83                               machine learning
# 55          LLM propmt engineering   0.83                     approve engineering design
# 56                                   0.83                              physical medicine
# 57                                   0.83                         mechanical engineering
# 58                                   0.83                     manage engineering project
# 59                                   0.83                      read engineering drawings
# 70                            Mail   0.88                                   collect mail
# 71                                   0.88                                    handle mail
# 72                                   0.87                                  register mail
# 73                                   0.86                         deliver correspondence
# 74                                   0.85                       organise mail deliveries
# 105                      Mentoring   0.92                             mentor individuals
# 106                                  0.91                             provide mentorship
# 107                                  0.89              mentor other health professionals
# 108                                  0.89                    mentor individual employees
# 109                                  0.85                       provide learning support
# 15                         MongoDB   0.90                                          NoSQL
# 16                                   0.87                                         Hadoop
# 17                                   0.86                                     PostgreSQL
# 18                                   0.86                                          MySQL
# 19                                   0.85                                     SQL Server
# 0                     Node/Nest JS   0.85                                     JavaScript
# 1                                    0.84                           JavaScript Framework
# 2                                    0.84                                     TypeScript
# 3                                    0.83                                   CoffeeScript
# 4                                    0.83                             Visual Studio .NET
# 50                      OpenAI API   0.84                               machine learning
# 51                                   0.84                              Open source model
# 52                                   0.83                                  deep learning
# 53                                   0.82                    natural language processing
# 54                                   0.82                     artificial neural networks
# 80                         Outlook   0.84                                        Angular
# 81                                   0.84                                          logic
# 82                                   0.84                                office software
# 83                                   0.83                          office administration
# 84                                   0.83                           use microsoft office
# 140                    Performance   0.90                          performance diagnosis
# 141                                  0.89                   provide performance feedback
# 142                                  0.89                      conduct performance tests
# 143                                  0.88                communicate performance aspects
# 144                                  0.88                              cue a performance
# 10                      PostgreSQL   1.00                                     PostgreSQL
# 11                                   0.90                                          MySQL
# 12                                   0.89                                          NoSQL
# 13                                   0.88                                     SQL Server
# 14                                   0.87                                            SQL
# 160            Product development   0.91                         develop product design
# 161                                  0.90                           develop new products
# 162                                  0.89                        product data management
# 163                                  0.88                             product life-cycle
# 164                                  0.88                pharmaceutical drug development
# 25                          Python   0.90                  Python (computer programming)
# 26                                   0.89                                     JavaScript
# 27                                   0.89                                            PHP
# 28                                   0.88                                            C++
# 29                                   0.87                                           Perl
# 30                       REST APIs   0.85                                         WebCMS
# 31                                   0.84                             Internet of Things
# 32                                   0.84                                         DevOps
# 33                                   0.84                               software metrics
# 34                                   0.84                               embedded systems
# 5                          ReactJS   0.90                                     JavaScript
# 6                                    0.87                                     TypeScript
# 7                                    0.87                           JavaScript Framework
# 8                                    0.85                                   CoffeeScript
# 9                                    0.84                     use functional programming
# 20                           Redis   0.84                                          NoSQL
# 21                                   0.84                                         Hadoop
# 22                                   0.83                                        Ansible
# 23                                   0.83                                     PostgreSQL
# 24                                   0.83                                          MySQL
# 155                          Sales   0.91                               sales activities
# 156                                  0.88                           set sales promotions
# 157                                  0.87                                  sell products
# 158                                  0.87                                  sell services
# 159                                  0.87                     supervise sales activities
# 145                    Scalability   0.86                          application usability
# 146                                  0.84                          distributed computing
# 147                                  0.83                                       Solidity
# 148                                  0.83                           manage profitability
# 149                                  0.83                                      logistics
# 125                       Security   0.89                               security threats
# 126                                  0.88                                 cyber security
# 127                                  0.88                           security regulations
# 128                                  0.88                      monitor security measures
# 129                                  0.88                                security panels
# 175                 Speech to text   0.85                  type texts from audio sources
# 176                                  0.85                             speech recognition
# 177                                  0.85                               transcribe texts
# 178                                  0.85                                translate texts
# 179                                  0.85                                 proofread text
# 100                Team management   0.92                                  manage a team
# 101                                  0.91                           personnel management
# 102                                  0.89                                  team building
# 103                                  0.88                             project management
# 104                                  0.88                               manage personnel
# 180                     Transcribe   0.94                               transcribe texts
# 181                                  0.92                           transcribe dialogues
# 182                                  0.91                        transcribe medical data
# 183                                  0.90                transcribe musical compositions
# 184                                  0.88         transcribe ideas into musical notation
# 60                          Twilio   0.81                                            iOS
# 61                                   0.80                             Internet of Things
# 62                                   0.80                                  Windows Phone
# 63                                   0.80                          mobility as a service
# 64                                   0.79                                     TypeScript
# 150                          UX/UI   0.88                          design user interface
# 151                                  0.86                          application usability
# 152                                  0.85                     human-computer interaction
# 153                                  0.85                    software UI design patterns
# 154                                  0.85                  design application interfaces
#                                      query  score                                             label
# 80                      ERP implementation   0.87                  government policy implementation
# 81                                           0.85           manage government policy implementation
# 82                                           0.85                check implementation security plan
# 83                                           0.85                                business processes
# 84                                           0.85                    implement strategic management
# 5                              ERP systems   0.89                       database management systems
# 6                                            0.88                                e-commerce systems
# 7                                            0.88                                       ATM systems
# 8                                            0.86                       learning management systems
# 9                                            0.86                                business processes
# 100                       English language   0.90                                           English
# 101                                          0.86                                     write English
# 102                                          0.86                                     sign language
# 103                                          0.85                                  aviation English
# 104                                          0.85                        understand written English
# 90                                 Go-Live   0.86                                      perform live
# 91                                           0.84                            give live presentation
# 92                                           0.84                                operate sound live
# 93                                           0.83                    organise sale of live products
# 94                                           0.83                    present during live broadcasts
# 120                                   IPMA   0.83                                     IPC standards
# 121                                          0.79                                              MOEM
# 122                                          0.79                                              STAF
# 123                                          0.79                                               APL
# 124                                          0.78                                           patents
# 0                   Microsoft Dynamics 365   0.84                                 Adobe Illustrator
# 1                                            0.84                                  Microsoft Access
# 2                                            0.84                                   Microsoft Visio
# 3                                            0.83                                 Agile development
# 4                                            0.83                                Visual Studio .NET
# 15                       Microsoft Project   0.86                              Microsoft Visual C++
# 16                                           0.84                             project commissioning
# 17                                           0.84                                manage ICT project
# 18                                           0.84                              use microsoft office
# 19                                           0.84                                Visual Studio .NET
# 185  Microsoft international certification   0.82           international import export regulations
# 186                                          0.82      regulations for international transportation
# 187                                          0.82       foreign languages for international careers
# 188                                          0.82                         international development
# 189                                          0.82  prepare documentation for international shipping
# 115                                    PMI   0.81                                   cost management
# 116                                          0.81                                         petroleum
# 117                                          0.81                         meet productivity targets
# 118                                          0.81                                     parts pricing
# 119                                          0.81                                lean manufacturing
# 95                      Ukrainian language   0.90                                   write Ukrainian
# 96                                           0.89                       understand spoken Ukrainian
# 97                                           0.88                      understand written Ukrainian
# 98                                           0.88                                         Ukrainian
# 99                                           0.86                    interact verbally in Ukrainian
# 180                      advanced training   0.88                                advanced materials
# 181                                          0.88                 apply advanced driving techniques
# 182                                          0.87                       training  subject expertise
# 183                                          0.86                      apply advanced manufacturing
# 184                                          0.86                                 evaluate training
# 35                       budget management   0.94                                   cost management
# 36                                           0.93                              financial management
# 37                                           0.91                                    manage budgets
# 38                                           0.90                                project management
# 39                                           0.90                             collection management
# 175                          career growth   0.88                        provide career counselling
# 176                                          0.88                                  advise on career
# 177                                          0.87                              personal development
# 178                                          0.86                         strive for company growth
# 179                                          0.86                       manage personal progression
# 55                    client communication   0.91                    teach communication to clients
# 56                                           0.88           communicate technicalities with clients
# 57                                           0.87             promote communication between parties
# 58                                           0.87                          protect client interests
# 59                                           0.87                        communicate with customers
# 130                   communication skills   0.89                                     communication
# 131                                          0.89              apply technical communication skills
# 132                                          0.89                      use communication techniques
# 133                                          0.88                             communication studies
# 134                                          0.88                           communication disorders
# 210               competitive remuneration   0.85                      ensure price competitiveness
# 211                                          0.84                                   competition law
# 212                                          0.84                    sports competition information
# 213                                          0.84                      develop competition policies
# 214                                          0.84           develop competitive strategies in sport
# 85                         data collection   0.92                                       gather data
# 86                                           0.90                            collect financial data
# 87                                           0.90                             collect customer data
# 88                                           0.90                           collect biological data
# 89                                           0.90                                  collect ICT data
# 105                                fluency   0.86                                          spelling
# 106                                          0.84                             manage a good diction
# 107                                          0.83                                           grammar
# 108                                          0.83                                       use dialect
# 109                                          0.83                                     speak dialect
# 160                  freelance cooperation   0.85                     create cooperation modalities
# 161                                          0.85                      cooperate with professionals
# 162                                          0.85                 establish collaborative relations
# 163                                          0.84                        coordinate membership work
# 164                                          0.84             cooperate in linguistic process steps
# 170                  full-time cooperation   0.84                     create cooperation modalities
# 171                                          0.83        collaborate in company's daily operations
# 172                                          0.83             cooperate at inter-professional level
# 173                                          0.83                 establish collaborative relations
# 174                                          0.83               ensure cross-department cooperation
# 165                            hourly rate   0.91                         calculate rates per hours
# 166                                          0.86                          calculate insurance rate
# 167                                          0.85                                    market pricing
# 168                                          0.85                                     parts pricing
# 169                                          0.85                                      quote prices
# 150                            inspiration   0.85                     inspire enthusiasm for nature
# 151                                          0.84                                        aesthetics
# 152                                          0.84                      stimulate creative processes
# 153                                          0.83                       express yourself creatively
# 154                                          0.83                            develop creative ideas
# 65                            interviewing   0.92                                  interview people
# 66                                           0.89                               document interviews
# 67                                           0.89                          give interviews to media
# 68                                           0.89                              interview techniques
# 69                                           0.88                        explain interview purposes
# 145                             motivation   0.87                                   motivate others
# 146                                          0.87                  demonstrate motivation for sales
# 147                                          0.86                                show determination
# 148                                          0.86                               motivate supporters
# 149                                          0.86                                motivate in sports
# 195                          paid vacation   0.83                  show professional responsibility
# 196                                          0.82                                    prepared meals
# 197                                          0.82                              personnel management
# 198                                          0.82                                 prepare paychecks
# 199                                          0.82                                   train employees
# 215           permanent full-time contract   0.83                                  manage contracts
# 216                                          0.83                           apply permanent make-up
# 217                                          0.82                           complete administration
# 218                                          0.82         ensure contract termination and follow-up
# 219                                          0.82                complete membership administration
# 155                  potential realization   0.83                              personal development
# 156                                          0.82                           Prototyping development
# 157                                          0.82                            produce prepress proof
# 158                                          0.82                            prospect new customers
# 159                                          0.82                                         reflexion
# 30                   project documentation   0.93                       draft project documentation
# 31                                           0.93                         document project progress
# 32                                           0.90                        manage project information
# 33                                           0.89                        provide user documentation
# 34                                           0.89                             provide documentation
# 10                      project management   1.00                                project management
# 11                                           0.92                           Lean project management
# 12                                           0.90                     project management principles
# 13                                           0.90                          Agile project management
# 14                                           0.90                            ICT project management
# 110       project management certification   0.90                                project management
# 111                                          0.88                  project configuration management
# 112                                          0.87                            ICT project management
# 113                                          0.87                     project management principles
# 114                                          0.86                           Lean project management
# 75                     project methodology   0.90                     project management principles
# 76                                           0.90                                project management
# 77                                           0.89              ICT project management methodologies
# 78                                           0.89                   scientific research methodology
# 79                                           0.89                   customise project methodologies
# 20                        project planning   0.93                                project management
# 21                                           0.91                                strategic planning
# 22                                           0.91                                    urban planning
# 23                                           0.89                     project management principles
# 24                                           0.89                                  airport planning
# 140                       quality-oriented   0.86                                    manage quality
# 141                                          0.84                                 quality standards
# 142                                          0.84                  set quality assurance objectives
# 143                                          0.83                           oversee quality control
# 144                                          0.83                     liaise with quality assurance
# 70                              recruiting   0.90                                 recruit personnel
# 71                                           0.89                                 recruit employees
# 72                                           0.87                                   recruit members
# 73                                           0.87                              personnel management
# 74                                           0.87                               recruit bus drivers
# 190                            remote work   0.85                                       manage work
# 191                                          0.84                              follow work schedule
# 192                                          0.84                                     work in teams
# 193                                          0.84                                work independently
# 194                                          0.84                              visit places of work
# 135                        result-oriented   0.87                          results-based management
# 136                                          0.83                                think analytically
# 137                                          0.83                             analyse goal progress
# 138                                          0.83                       analyse business objectives
# 139                                          0.83                         interpret medical results
# 50                         risk management   1.00                                   risk management
# 51                                           0.93                        enterprise risk management
# 52                                           0.91                                    risk modelling
# 53                                           0.90                             manage financial risk
# 54                                           0.90                         advise on risk management
# 45                        scope management   0.86                                     manage canopy
# 46                                           0.86                                  manage contracts
# 47                                           0.85                             manage claims process
# 48                                           0.85                                    manage revenue
# 49                                           0.85                     manage medium term objectives
# 200                             sick leave   0.85                                 infection control
# 201                                          0.85                     health and safety regulations
# 202                                          0.85                                   disability care
# 203                                          0.84                                     labour market
# 204                                          0.84                               social security law
# 205             standardized working hours   0.88                    accurately estimate work hours
# 206                                          0.86                              follow work schedule
# 207                                          0.85          measure working time in goods production
# 208                                          0.84          consider time zones in execution of work
# 209                                          0.84                           maintain work standards
# 25                       task distribution   0.88                             task algorithmisation
# 26                                           0.86                          manage schedule of tasks
# 27                                           0.86                        distribute control signals
# 28                                           0.85                        provide power distribution
# 29                                           0.85                        handle tasks independently
# 60                         team management   0.92                                     manage a team
# 61                                           0.91                              personnel management
# 62                                           0.89                                     team building
# 63                                           0.88                                project management
# 64                                           0.88                                  manage personnel
# 125                               teamwork   0.92                               teamwork principles
# 126                                          0.90                                     plan teamwork
# 127                                          0.88                                     team building
# 128                                          0.87              facilitate teamwork between students
# 129                                          0.87                                     work in teams
# 40                         time management   0.93                                       manage time
# 41                                           0.90                              personnel management
# 42                                           0.89                                project management
# 43                                           0.89            manage time in agricultural production
# 44                                           0.88                            manage time in tourism
#                                                 query  score                                              label
# 25  Ability to occasionally collaborate (join meet...   0.85         collaborate in company's daily operations
# 26                                                      0.85           consider time zones in execution of work
# 27                                                      0.83                          cooperate with colleagues
# 28                                                      0.83                             liaise with colleagues
# 29                                                      0.83       use communication and collaboration software
# 20  Ability to work independently in a remote-firs...   0.87                         handle tasks independently
# 21                                                      0.86                  work independently in agriculture
# 22                                                      0.86                                 work independently
# 23                                                      0.86            work independently in forestry services
# 24                                                      0.85                  work independently in landscaping
# 45           Closely collaborate with other engineers   0.95                         collaborate with engineers
# 46                                                      0.90                              liaise with engineers
# 47                                                      0.89                          cooperate with colleagues
# 48                                                      0.89                         collaborate with designers
# 49                                                      0.88                       coordinate engineering teams
# 40  Develop features to register the software with...   0.86                                   install software
# 41                                                      0.85              manage signoff of an installed system
# 42                                                      0.84                      implement anti-virus software
# 43                                                      0.84                           install operating system
# 44                                                      0.83                         develop software prototype
# 15                     Effective communication skills   0.88               apply technical communication skills
# 16                                                      0.86                       use communication techniques
# 17                                                      0.86              promote communication between parties
# 18                                                      0.86  promote good habits to avoid communication dis...
# 19                                                      0.86                     teach communication to clients
# 0   Extensive experience in Windows application de...   0.84                      Rapid application development
# 1                                                       0.83                    oversee development of software
# 2                                                       0.83               develop data processing applications
# 3                                                       0.82                                 Visual Studio .NET
# 4                                                       0.82                               Microsoft Visual C++
# 5   Good understanding of the Windows installation...   0.85                     analyse packaging requirements
# 6                                                       0.85                           install operating system
# 7                                                       0.84                ensure quality control in packaging
# 8                                                       0.84     demonstrate proficiency in packaging standards
# 9                                                       0.84                       good manufacturing practices
# 35  Improve the virtual mic Windows installer to e...   0.85                      implement anti-virus software
# 36                                                      0.83                                  install falsework
# 37                                                      0.83                                   install software
# 38                                                      0.82                 assist audiologists with screening
# 39                                                      0.82                implement a virtual private network
# 10                                  Proficient in C++   0.86                                                C++
# 11                                                      0.85                             have computer literacy
# 12                                                      0.84                     apply basic programming skills
# 13                                                      0.83                        provide technical expertise
# 14                                                      0.83                    use object-oriented programming
# 30        Strong writing and verbal skills in English   0.86                         understand written English
# 31                                                      0.86                                      write English
# 32                                                      0.86                       interact verbally in English
# 33                                                      0.85                    use specific writing techniques
# 34                                                      0.85                             study relevant writing
#
#
#                           query  score                                      label
# 30                         AJAX   1.00                                       AJAX
# 31                                0.85                             Ajax Framework
# 32                                0.83                                      Dutch
# 33                                0.82                                        PHP
# 34                                0.81                              Apache Tomcat
# 90          Amazon Web Services   0.84                      mobility as a service
# 91                                0.84                         e-commerce systems
# 92                                0.84                           customer service
# 93                                0.84                develop with cloud services
# 94                                0.84                             use e-services
# 55                      Angular   1.00                                    Angular
# 56                                0.84                                 JavaScript
# 57                                0.83                                        CSS
# 58                                0.83                                Objective-C
# 59                                0.83                                        iOS
# 65                           C3   0.84                                     SAP R3
# 66                                0.82                                        DB2
# 67                                0.82                                         C#
# 68                                0.81                                    Angular
# 69                                0.81                                   graphite
# 25                          CSS   1.00                                        CSS
# 26                                0.86                                 JavaScript
# 27                                0.86                           computer science
# 28                                0.85                                       Sass
# 29                                0.85                                     WebCMS
# 60                           D3   0.86                                     SAP R3
# 61                                0.82                                        DB2
# 62                                0.81                                       AJAX
# 63                                0.81                             defense system
# 64                                0.80                                          R
# 100                         ETL   0.83                                        APL
# 101                               0.83                                  logistics
# 102                               0.82                             data warehouse
# 103                               0.81                            pallets loading
# 104                               0.81                           manage logistics
# 20                         HTML   0.89                                        CSS
# 21                                0.89                                 JavaScript
# ...
# 6                                 0.86                Java (computer programming)
# 7                                 0.86                                 JavaScript
# 8                                 0.84                                      Malay
# 9                                 0.84                                      Scala
# 10                   JavaScript   1.00                                 JavaScript
# 11                                0.91                       JavaScript Framework
# 12                                0.90                                 TypeScript
# 13                                0.88                               CoffeeScript
# 14                                0.88                                        PHP
# 80                       Jersey   0.82                                   Albanian
# 81                                0.81                                  Icelandic
# 82                                0.81                                    Latvian
# 83                                0.81                                     Basque
# 84                                0.81                                      Welsh
# 95                        Linux   0.88                          operating systems
# 96                                0.86                                        PHP
# 97                                0.86                                 Kali Linux
# 98                                0.86                                        iOS
# 99                                0.86                                       Perl
# 35                         REST   0.85                                manage time
# 36                                0.85                                collect tax
# 37                                0.85                          exercise patience
# 38                                0.84                                gather data
# 39                                0.84  promote balance between rest and activity
# 50                        React   0.86                                    Angular
# 51                                0.85                                 JavaScript
# 52                                0.84                           meet commitments
# 53                                0.84       react to physical changes or hazards
# 54                                0.84                           handle chemicals
# 0                           SQL   1.00                                        SQL
# 1                                 0.94                                 SQL Server
# 2                                 0.91                                   database
# 3                                 0.89                                      MySQL
# 4                                 0.87                                 PostgreSQL
# 45   Upper-intermediate English   0.84                 understand written English
# 46                                0.83                           aviation English
# 47                                0.83               interact verbally in English
# 48                                0.83                              write English
# 49                                0.83                  understand spoken English
# 70                    bootstrap   0.85                                        CSS
# 71                                0.84                                 JavaScript
# 72                                0.84                                     MATLAB
# 73                                0.84                           machine learning
# 74                                0.83                                        PHP
# 15          frontend frameworks   0.91                        software frameworks
# 16                                0.88                       JavaScript Framework
# 17                                0.87          mobile device software frameworks
# 18                                0.87                             Ajax Framework
# 19                                0.86       decentralized application frameworks
# 105        open-source projects   0.86               operate open source software
# 106                               0.85                        software frameworks
# 107                               0.85                          Open source model
# 108                               0.84                         project management
# 109                               0.84     receive key information about projects
# 85      scalable web app design   0.85                      application usability
# 86                                0.85                   design web-based courses
# 87                                0.85              design application interfaces
# 88                                0.84                 maintain responsive design
# 89                                0.84              Rapid application development
# 40             single-page apps   0.84                                   OmniPage
# 41                                0.84                      application usability
# 42                                0.83              design application interfaces
# 43                                0.83      use an application-specific interface
# 44                                0.82                                    ASP.NET
#                                                 query  score                                              label
# 60                       Bazel (build tool by Google)   0.83           Cain and Abel (penetration testing tool)
# 61                                                      0.82  Jenkins (tools for software configuration mana...
# 62                                                      0.82                                       Apache Maven
# 63                                                      0.81  Chef (tools for software configuration managem...
# 64                                                      0.81         John The Ripper (penetration testing tool)
# 0                            Desire to learn and grow   0.90                   demonstrate willingness to learn
# 1                                                       0.85                              demonstrate curiosity
# 2                                                       0.85                          strive for company growth
# 3                                                       0.85                               personal development
# 4                                                       0.84                            develop personal skills
# 20                      Experience with microservices   0.82                        characteristics of services
# 21                                                      0.82                     manage the customer experience
# 22                                                      0.82                       use software design patterns
# 23                                                      0.82                                 use experience map
# 24                                                      0.82                        develop with cloud services
# 80                Frontend tech: ReactJS + TypeScript   0.86                                         TypeScript
# 81                                                      0.83                 implement front-end website design
# 82                                                      0.82                                         JavaScript
# 83                                                      0.82                               JavaScript Framework
# 84                                                      0.81                         use functional programming
# 70                                          Gitlab CI   0.81                                             DevOps
# 71                                                      0.80                                             Joomla
# 72                                                      0.80                                       Apache Maven
# 73                                                      0.80                            manage digital identity
# 74                                                      0.80                                  Agile development
# 55                                                 Go   0.85                                              plan
# 56                                                      0.84                                     make decisions
# 57                                                      0.84                                                  R
# 58                                                      0.84                                        gather data
# 59                                                      0.83                                               sing
# 15  Good knowledge of Spring (Boot, Security, MVC,...   0.82  apply knowledge of philosophy, ethics and reli...
# 16                                                      0.82                             have computer literacy
# 17                                                      0.82                       use software design patterns
# 18                                                      0.82                                 business knowledge
# 19                                                      0.81  apply knowledge of science, technology and eng...
# 30               Intermediate or higher English level   0.85                             update language skills
# 31                                                      0.85                         understand written English
# 32                                                      0.84      improve students' language examination skills
# 33                                                      0.84                                      write English
# 34                                                      0.84                          understand spoken English
# 10                       Java 11 or higher experience   0.84                                 use experience map
# 11                                                      0.82                             update language skills
# 12                                                      0.82                         levels of software testing
# 13                                                      0.82                        Java (computer programming)
# 14                                                      0.81                                 Visual Studio .NET
# 25                 Knowledge of Docker and Kubernetes   0.83                                types of containers
# 26                                                      0.82                      manage cloud data and storage
# 27                                                      0.82                                 business knowledge
# 28                                                      0.82                                 install containers
# 29                                                      0.81               keep up to date on product knowledge
# 65                   Kubernetes cluster on bare metal   0.81                       pour molten metal into cores
# 66                                                      0.81                              deploy cloud resource
# 67                                                      0.80                      weld in hyperbaric conditions
# 68                                                      0.80                               do cloud refactoring
# 69                                                      0.80                                         cast metal
# 35                          Microservice architecture   0.86                          design cloud architecture
# 36                                                      0.85                        hybrid vehicle architecture
# 37                                                      0.85                             hardware architectures
# 38                                                      0.84                       software architecture models
# 39                                                      0.84                           information architecture
# 90                        Monitoring: Sentry, Grafana   0.83                          monitor security measures
# 91                                                      0.83                          monitor building security
# 92                                                      0.83                         monitor automated machines
# 93                                                      0.83                            monitor heavy machinery
# 94                                                      0.83                                  monitor ticketing
# 75  Persistence: PostgreSQL, CockroachDB, Clickhou...   0.85                                         PostgreSQL
# 76                                                      0.83                                              NoSQL
# 77                                                      0.82                                         SQL Server
# 78                                                      0.82                         Oracle Relational Database
# 79                                                      0.82                                              MySQL
# 5                            Product-oriented mindset   0.86                              product comprehension
# 6                                                       0.85                            plan product management
# 7                                                       0.84                           perform product planning
# 8                                                       0.84                             manage product testing
# 9                                                       0.84                                 product life-cycle
# 50                                              Scala   1.00                                              Scala
# 51                                                      0.84                                              SPARK
# 52                                                      0.84                                           Galician
# 53                                                      0.84                                             Basque
# 54                                                      0.83                                            Latvian
# 45    Spring (Boot, Batch, Cloud, MVC, JPA) + Java 17   0.84                                      Apache Tomcat
# 46                                                      0.84                                       Apache Maven
# 47                                                      0.83                                         JavaScript
# 48                                                      0.82                                   machine learning
# 49                                                      0.82                                    Adobe Photoshop
# 85  Tests: JUnit, Mockito, Playwright, Test Contai...   0.85                      perform software unit testing
# 86                                                      0.84                      tools for ICT test automation
# 87                                                      0.84                             execute software tests
# 88                                                      0.84                              plan software testing
# 89                                                      0.84                                       manage tests
# 40                                           monorepo   0.81                                         polygraphy
# 41                                                      0.80                              isometric perspective
# 42                                                      0.79                                        microoptics
# 43                                                      0.79                                        reprography
# 44                                                      0.79                                              Taleo
