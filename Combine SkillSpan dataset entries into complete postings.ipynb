# %%
from dotenv import load_dotenv

load_dotenv()

import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/andriimyronenko/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import pandas as pd
import json

base_path = 'data/SkillSpan/json/'
file_names = ['dev.json', 'train.json', 'test.json']

dfs = {}

for file_name in file_names:
    file_path = base_path + file_name
    with open(file_path, 'r') as file:
        json_data = json.load(file)
        dfs[file_name.split('.')[0]] = pd.DataFrame(json_data)

dev_df = dfs['dev']
train_df = dfs['train']
test_df = dfs['test']

print("Dev DataFrame:")
print(dev_df.head())

print("\nTrain DataFrame:")
print(train_df.head())

print("\nTest DataFrame:")
print(test_df.head())
# Out:
# Dev DataFrame:
#    idx                                             tokens  \
# 0    1  [DevOps, Engineer, (, CI, CD, Cloud, Docker, J...
# 1    1  [<ADDRESS>, <ADDRESS>, <LOCATION>, -, <LOCATION>]
# 2    1                        [Date, posted:, 2021-04-22]
# 3    1                [Likes:, 0, Dislikes:, 0, Love:, 0]
# 4    1                                [Job, description:]
#
#                        tags_skill                  tags_knowledge source
# 0  [O, O, O, O, O, O, O, O, O, O]  [O, O, O, O, O, O, O, O, O, O]   tech
# 1                 [O, O, O, O, O]                 [O, O, O, O, O]   tech
# 2                       [O, O, O]                       [O, O, O]   tech
# 3              [O, O, O, O, O, O]              [O, O, O, O, O, O]   tech
# 4                          [O, O]                          [O, O]   tech
#
# Train DataFrame:
#    idx                                             tokens  \
# 0    1  [Senior, QA, Engineer, (, m/f/d, ), <ORGANIZAT...
# 1    1  [<ADDRESS>, <ADDRESS>, <ADDRESS>, <ADDRESS>, <...
# 2    1                        [Date, posted:, 2021-07-14]
# 3    1                [Likes:, 0, Dislikes:, 0, Love:, 0]
# 4    1                                [Job, description:]
#
#               tags_skill         tags_knowledge source
# 0  [O, O, O, O, O, O, O]  [O, O, O, O, O, O, O]   tech
# 1        [O, O, O, O, O]        [O, O, O, O, O]   tech
# 2              [O, O, O]              [O, O, O]   tech
# 3     [O, O, O, O, O, O]     [O, O, O, O, O, O]   tech
# 4                 [O, O]                 [O, O]   tech
#
# Test DataFrame:
#    idx                                             tokens  \
# 0    1  [Full, Stack, Software, Engineer, -, Java, /, ...
# 1    1  [<ORGANIZATION>, <ORGANIZATION>, <ORGANIZATION...
# 2    1  [<ADDRESS>, <ADDRESS>, <LOCATION>, -, <LOCATION>]
# 3    1                        [Date, posted:, 2021-03-04]
# 4    1                [Likes:, 0, Dislikes:, 0, Love:, 0]
#
#                  tags_skill            tags_knowledge source
# 0  [O, O, O, O, O, O, O, O]  [O, O, O, O, O, O, O, O]   tech
# 1           [O, O, O, O, O]           [O, O, O, O, O]   tech
# 2           [O, O, O, O, O]           [O, O, O, O, O]   tech
# 3                 [O, O, O]                 [O, O, O]   tech
# 4        [O, O, O, O, O, O]        [O, O, O, O, O, O]   tech

# %%
def process_entries(group):
    combined_text = []
    combined_skills = []
    combined_knowledge = []
    source = None

    for _, row in group.iterrows():
        combined_text.extend(row['tokens'])
        
        temp_skills = []
        temp_knowledge = []
        
        for token, skill_tag, knowledge_tag in zip(row['tokens'], row['tags_skill'], row['tags_knowledge']):
            if skill_tag.startswith('B'):
                temp_skills.append(token)
            elif skill_tag.startswith('I') and temp_skills:
                temp_skills[-1] += f' {token}'
            
            if knowledge_tag.startswith('B'):
                temp_knowledge.append(token)
            elif knowledge_tag.startswith('I') and temp_knowledge:
                temp_knowledge[-1] += f' {token}'

        if temp_skills:
            combined_skills.extend(temp_skills)
        if temp_knowledge:
            combined_knowledge.extend(temp_knowledge)
        source = row['source']

    text = ' '.join(combined_text)
    
    return pd.Series([text, combined_skills, combined_knowledge, source], index=['text', 'skills', 'knowledge', 'source'])

def process_dataframe(df):
    grouped_df = df.groupby('idx').apply(process_entries).reset_index()
    return grouped_df

processed_dev_df = process_dataframe(dev_df)
processed_train_df = process_dataframe(train_df)
processed_test_df = process_dataframe(test_df)

final_df = pd.concat([processed_dev_df, processed_train_df, processed_test_df], ignore_index=True)

processed_test_df.head()
# Out:
#    idx                                               text  \
# 0    1  Full Stack Software Engineer - Java / JavaScri...
# 1    2  Software Engineer - Java <ORGANIZATION> <ORGAN...
# 2    3  DevOps Ninja Engineer ( . NET/Azure ) <ORGANIZ...
# 3    4  Principle Software Engineer | Java <ORGANIZATI...
# 4    5  Python Software Engineer Intern for <ORGANIZAT...
#
#                                               skills  \
# 0  [solving business problems, apply your depth o...
# 1  [solving business problems, apply your depth o...
# 2  [Open for continuous change, Enhance and maint...
# 3  [solving business problems, apply your depth o...
# 4  [build highly efficient accurate and scalable ...
#
#                                            knowledge source
# 0  [javascript, reactjs, java, javascript, reactj...   tech
# 1  [java, spring, java-ee, java, spring, java-ee,...   tech
# 2  [Financial Technology, SaaS, wealthtech, azure...   tech
# 3  [Financial Services, java, reactjs, web-servic...   tech
# 4  [Artificial Intelligence, Computer Graphics, S...   tech

# %%
test_df_tech_only = processed_test_df[processed_test_df['source'] == 'tech']
test_df_tech_only.to_csv('./data/test_df_tech_only_combined.csv', index=False)

test_df_tech_only
# Out:
#     idx                                               text  \
# 0     1  Full Stack Software Engineer - Java / JavaScri...
# 1     2  Software Engineer - Java <ORGANIZATION> <ORGAN...
# 2     3  DevOps Ninja Engineer ( . NET/Azure ) <ORGANIZ...
# 3     4  Principle Software Engineer | Java <ORGANIZATI...
# 4     5  Python Software Engineer Intern for <ORGANIZAT...
# 5     6  Senior Ruby on Rails Developer 12.000-18.000 P...
# 6     7  UI Software Engineer <ORGANIZATION> <ORGANIZAT...
# 7     8  Backend Engineer ( m/f/d ) <ORGANIZATION> <ORG...
# 8     9  BI Developer <LOCATION> <LOCATION> <LOCATION> ...
# 9    10  System Architect for our new Digital Developme...
# 10   11  Senior Back End Engineer <ORGANIZATION> <LOCAT...
# 11   12  QA Tester <ORGANIZATION> <ORGANIZATION> <ORGAN...
# 12   13  Quality Engineer <ORGANIZATION> <ORGANIZATION>...
# 13   14  Software Engineer - Service Desk UI <ORGANIZAT...
# 14   15  Software Engineer - Performance Technology <OR...
# 15   16  Unity Gameplay Programmer <ORGANIZATION> <ORGA...
# 16   17  Software Engineer - Database - Java Core <ORGA...
# 17   18  Senior Software Engineer - . NET ( online comp...
# 18   19  Senior Software Developer Java ( all genders )...
# 19   20  Web Frontend Developer with an eye for profess...
# 20   21  Senior Full Stack Developer <ORGANIZATION> <LO...
# 21   22  Senior Java Software Engineer ( VP ) <ORGANIZA...
# 22   23  Dynamics 365 Developer <ORGANIZATION> <ORGANIZ...
# 23   24  Backend Developer <ORGANIZATION> <ORGANIZATION...
# 24   25  QA Engineer ( f/m/d ) <ORGANIZATION> <ORGANIZA...
# 25   26  Automation Test Analyst <ORGANIZATION> <ORGANI...
# 26   27  Cloud DevOps Engineer <ORGANIZATION> <ORGANIZA...
# 27   28  Node.js Backend Engineer ( m/f/d ) <ORGANIZATI...
# 28   29  SENIOR PYHTON DEVELOPER <ORGANIZATION> <LOCATI...
# 29   30  Senior Distributed Systems Engineer ( Java ) <...
# 31   32  Software Architect Backend ( d/f/m ) <ORGANIZA...
#
#                                                skills  \
# 0   [solving business problems, apply your depth o...
# 1   [solving business problems, apply your depth o...
# 2   [Open for continuous change, Enhance and maint...
# 3   [solving business problems, apply your depth o...
# 4   [build highly efficient accurate and scalable ...
# 5   [gather technical requirements, architect solu...
# 6   [Deliver initiatives, modernizing and transfor...
# 7   [build software, help our customers, build and...
# 8   [building front-end layer, Design and build fr...
# 9   [making the right decisions, definition & comm...
# 10  [maintain quality, work with AWS infrastructur...
# 11  [introduce and implement the newest standards ...
# 12  [Ensuring high quality for customer-specific s...
# 13  [solving business problems, innovation and eng...
# 14  [solving business problems, innovation & engin...
# 15  [flair for gameplay, aesthetic know-how?, work...
# 16  [solve technical challenges, deliver high qual...
# 17  [Development test and deployment of new compon...
# 18  [enthusiasm, professional attitude, work toget...
# 19  [develop attractive state-of-the-art user inte...
# 20  [deliver software solutions, creation of progr...
# 21  [solving business problems, innovation & engin...
# 22  [developing, development, customisation, confi...
# 23  [analyzing, deciding the best approach, write ...
# 24  [delivering real quality, Planning test activi...
# 25  [Automation, Functional Testing, new feature t...
# 26  [solving business problems, innovation and eng...
# 27  [design and develop a micro-service architectu...
# 28  [Lead the design & implementation, Drive the i...
# 29  [base your decisions on solid data and metrics...
# 31  [high-quality well-tested and scalable code, E...
#
#                                             knowledge source
# 0   [javascript, reactjs, java, javascript, reactj...   tech
# 1   [java, spring, java-ee, java, spring, java-ee,...   tech
# 2   [Financial Technology, SaaS, wealthtech, azure...   tech
# 3   [Financial Services, java, reactjs, web-servic...   tech
# 4   [Artificial Intelligence, Computer Graphics, S...   tech
# 5   [e-commerce, open-source, ruby-on-rails, sql, ...   tech
# 6   [Financial Services, reactjs, cloud, python, F...   tech
# 7   [django, postgresql, redis, django, postgresql...   tech
# 8   [Power BI reports, DAX queries, Azure Analysis...   tech
# 9   [Agile Software Development, Financial Technol...   tech
# 10  [Financial Technology, c#, f#, typescript, Fin...   tech
# 11  [qa, testing, cypress, mocha.js, chai, qa, tes...   tech
# 12  [Collaboration Tools, Computer Software, Open-...   tech
# 13  [Financial Services, Financial Services, BS/BA...   tech
# 14  [r, java, nosql, r, java, nosql, JAVA, REST/We...   tech
# 15  [Entertainment, Gaming, Mobile Game, unity3d, ...   tech
# 16  [Computer Software, Databases, Information Tec...   tech
# 17  [eCommerce, Price Comparison, Online Portal, ....   tech
# 18  [Data Science, IT Security, Software Developme...   tech
# 19  [Digital Agency, Software Development / Engine...   tech
# 20  [Financial Services, Financial Technology, Reg...   tech
# 21  [java, testing, web-services, java, testing, w...   tech
# 22  [Cloud Services, Information Technology, Techn...   tech
# 23  [Vehicle Tracking, azure, . net, c#, azure-cos...   tech
# 24  [qa, automation, testing, qa, automation, test...   tech
# 25  [Financial Services, qa, python, automation, F...   tech
# 26  [Financial Services, cloud, java, amazon-web-s...   tech
# 27  [Artificial Intelligence, Machine Learning, Tr...   tech
# 28  [python, django, docker, orm, sqlalchemy, pyth...   tech
# 29  [Information Technology, Online Travel, java, ...   tech
# 31  [eCommerce, Internet Marketing, java, spring, ...   tech

# %%
def extract_columns(row):
    print(row['text'])
    print('>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>')
    print(row['skills'])
    print('>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>')
    print(row['knowledge'])
    print('>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>\n')

train_df_tech_only = processed_train_df[processed_train_df['source'] == 'tech']
train_df_tech_only.apply(extract_columns, axis=1)
# Out:
# Senior QA Engineer ( m/f/d ) <ORGANIZATION> <ADDRESS> <ADDRESS> <ADDRESS> <ADDRESS> <LOCATION> Date posted: 2021-07-14 Likes: 0 Dislikes: 0 Love: 0 Job description: Location options: Remote Visa sponsor Paid relocation Job type: Full-time Experience level: Senior Role: QA/Test Developer Industry: Business to Business Information Technology Web Technology Company size: 501-1k people Company type: Private Technologies docker agile selenium circleci jenkins Job description In order to support our ongoing international growth we are looking for a Senior QA Engineer to join our Engineering department . You will be working in an end-to-end cross-functional team being responsible for implementing and promoting all QA relevant topics on team level . Responsibilities Design and implement complex end-to-end tests . Work hands-on together with the other engineers within the Agile team - to ensure continuous quality delivery of automated acceptance API and performance tests - while constantly collaborating with the QA Engineers of the other teams . Own a thought-leadership influence regarding QA relevant topics within the Agile team . Requirements At least 5 years of combined experience in Java or Kotlin and JavaScript or TypeScript programming and related test frameworks ( Selenium TestCafe etc.) . Good understanding of Agile methodologies and Continuous Delivery . Experience in testing applications on every level of the testing pyramid . Great communicator being able to relate to the different challenges that developers product managers and other stakeholders within the engineering department face . Experience in working on a cloud-based application running on Docker . A degree in Computer Science or related fields or equivalent practical experience . Experience in working with CircleCI pipelines on running tests automatically prior to the deployment; Jenkins is a plus . Performance and security testing experience is a plus . What we offer We keep things open agile and communicative . It is all based on trust not micromanaging . The whole department is located together in one office in beautiful <LOCATION> however due to the current situation we work and onboard 100% remotely to keep our employees safe . Our team members are self-organized within their teams working on independent projects or closely with Product Leads developers and UX designers . We value your thoughts and ideas and will give you the freedom to push and implement them! We offer competitive salaries and support personal growth with functional in-house coaching and a personal development budget that includes three days off per year . You will gain – and share – knowledge during recurring learning groups jours fixes and our annual Code Camp . You are free to use the OS of your choice the tooling you are comfortable with and set up your workspace the way you like it . <ORGANIZATION> will support you with all the necessary office equipment even when working from home! We get that balancing a family and work can be a challenge so everyone gets flexible working hours and 30 days of holidays per year . Moreover <ORGANIZATION> will support you in case of relocation and visa application . Note: We support your relocation but due to tax reason you’d be required to be resident in one of the following countries: <LOCATION> <LOCATION> <LOCATION> <LOCATION> <LOCATION> <LOCATION> . Visa support can currently be offered only for <LOCATION> . *Do I need to meet all the requirements to apply? * Studies by several different sources have shown that on average men will apply for a job if they meet 60% of the application requirements . In contrast women/non-binary people will seek to match a much higher percentage of the requirements before applying . We encourage everyone to apply and give us a chance to evaluate your skills and experience . We are all learning on the job and although the listing above has been carefully compiled we are also open-minded and interested to hear about the val ...
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ['implementing and promoting all QA relevant topics', 'Design and implement complex end-to-end tests', 'Work hands-on', 'ensure continuous quality delivery of automated acceptance API and performance tests', 'constantly collaborating', 'Own a thought-leadership influence regarding QA relevant topics', 'working on a cloud-based application', 'running tests automatically']
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ['Business to Business', 'Information Technology', 'Web Technology', 'docker', 'agile', 'selenium', 'circleci', 'jenkins', 'QA', 'automated acceptance API and performance tests', 'Java', 'Kotlin', 'JavaScript', 'TypeScript', 'test frameworks', 'Selenium', 'TestCafe', 'Agile methodologies', 'Continuous Delivery', 'Docker', 'degree in Computer Science', 'CircleCI', 'Jenkins', 'Performance and security testing']
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
#
# Cloud DevOps Engineer <ORGANIZATION> <ORGANIZATION> <ORGANIZATION> <ORGANIZATION> <ORGANIZATION> <ADDRESS> <ADDRESS> <LOCATION> - <LOCATION> Date posted: 2021-01-21 Likes: 0 Dislikes: 0 Love: 0 Job description: Job type: Full-time Role: DevOps Industry: Financial Services Company size: 10k+ people Company type: Public Technologies cloud java amazon-web-services Job description As a member of our Software Engineering Group we look first and foremost for people who are passionate about solving business problems through innovation and engineering practices . You'll be required to apply your depth of knowledge and expertise to all aspects of the software development lifecycle as well as partner continuously with your many stakeholders on a daily basis to stay focused on common goals . We embrace a culture of experimentation and constantly strive for improvement and learning . You'll work in a collaborative trusting thought-provoking environment-one that encourages diversity of thought and creative solutions that are in the best interests of our customers globally . This role requires a variety of strengths and capabilities including: * BS/BA degree or equivalent experience * Hands-on experience in Core Java Spring Boot and Microservices * Experience with cloud technologies such as AWS and Kubernetes * Experience with Docker or similar container technologies * Experience with cloud deployment tools like Spinnaker is beneficial * Knowledge of best practices in DevOps and CI/CD automation * Advanced knowledge of application data and infrastructure architecture disciplines * Knowledge of industry-wide technology trends and best practices * Ability to work in large collaborative teams to achieve organizational goals * Passionate about building an innovative culture * Proficiency in one or more modern programming languages * Understanding of software skills such as business analysis development maintenance and software improvement <ORGANIZATION> <ORGANIZATION> <ORGANIZATION> is a global leader in financial services providing strategic advice and products to the world's most prominent corporations governments wealthy individuals and institutional investors . Our first-class business in a first-class way approach to serving clients drives everything we do . We strive to build trusted long-term partnerships to help our clients achieve their business objectives . We recognize that our people are our strength and the diverse talents they bring to our global workforce are directly linked to our success . We are an equal opportunity employer and place a high value on diversity and inclusion at our company . We do not discriminate on the basis of any protected attribute including race religion color national origin gender sexual orientation gender identity gender expression age marital or veteran status pregnancy or disability or any other basis protected under applicable law . In accordance with applicable law we make reasonable accommodations for applicants' and employees' religious practices and beliefs as well as any mental health or physical disability needs . Job benefits: Healthcare and Insurance Plans Wellness Programs Maternity and Paternity Leave Adoption Assistance Retirement Savings Programs Paid Time Off Tuition Assistance Access to Arts and Entertainment Program Stock Purchase Plan Charitable Contribution Matching Learning & Development Resources Company description: <DESCRIPTION>
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ['solving business problems through innovation and engineering practices', 'apply your depth of knowledge and expertise', 'partner continuously with your many stakeholders', 'work in large collaborative teams', 'building an innovative culture']
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ['Financial Services', 'cloud', 'java', 'amazon-web-services', 'BS/BA degree', 'Core Java', 'Spring Boot', 'Microservices', 'cloud technologies', 'AWS', 'Kubernetes', 'Docker', 'cloud deployment tools', 'Spinnaker', 'best practices in DevOps and CI/CD automation', 'application data and infrastructure architecture', 'industry-wide technology trends and best practices', 'modern programming languages', 'business analysis', 'development', 'maintenance', 'software improvement']
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
#
# Front-end Developer <ORGANIZATION> <ADDRESS> <ADDRESS> <ADDRESS> <ADDRESS> <LOCATION> Date posted: 2021-04-21 Likes: 0 Dislikes: 0 Love: 0 Job description: Compensation: £40k - 50k Location options: Remote Job type: Full-time Technologies front-end agile css Job description About <ORGANIZATION> <ORGANIZATION> is a Content Operations Platform that helps teams produce high quality content at scale . Content has never been such a fundamental part of the way organisations operate and communicate and our customers use <ORGANIZATION> to manage the people and process required to create effective content that truly meets user needs . We work with leading digital agencies higher education institutions governments non-profits and membership organisations . Some of our customers include <ORGANIZATION> <ORGANIZATION> <ORGANIZATION> <ORGANIZATION> <ORGANIZATION> <ORGANIZATION> <ORGANIZATION> and <ORGANIZATION> <ORGANIZATION> <ORGANIZATION> . We launched in 2012 and now help thousands of customers all over the world . Our team is fully remote working from all over the <LOCATION> . The Role We're looking for an experienced <LOCATION> Front-end Developer who wants to be part of a remote ( we've been remote-first for 5 years and so we have very well established processes for working effectively together) fast-growing startup . You will be working as part of our Agile 10 person team to help deliver iterations and new features to our product . Start date: as soon as possible Pay: Starting at 40k dependent on what you bring to the table Working remotely anywhere in the <LOCATION> . ( we offer budget for co-working spaces or to support your home office ) Please be aware that although the position is remote we will need you to travel to <LOCATION> to attend a team days / product team meet-ups every few months . Benefits What we can offer you Remote working - We're a distributed team and have been since before it was cool ( / mandatory) . Whether you want to join a co-working space or get your work done from home the choice and flexibility are yours . Work/life balance - We work a 35 hour week and encourage downtime . We don't want people burning out . We offer a full Headspace or Calm subscription and have free mental health support available . 4 day week - We work to a 4-day week during the summer ( Fridays off for all of Jun July and August ) - this is great for wellness and to hone our radical prioritisation skills . The chance to make a big impact - We're a small team of 25 ( and growing) and we don't do silos so there's a big opportunity for you to collaborate closely with people across the whole company and make your mark . A driven team - We care about what we do and we enjoy spending time with each other . Not being in the office together every day makes the heart grow fonder so every 3 months or so we organise for the whole team to hang out and catch up . Need a holiday? We offer 35 days of holiday per year which means more time to do something off the beaten path Growth - We believe it's important for people to have the resources to grow both personally and professionally so we offer a generous conference and books budget to help you scratch that knowledge itch . You need to include the word ‘fennel’ in your cover letter to show that you’ve read the job role ( this helps us weed out time wasters! ) Closing date : 1st of May 2021 We are an equal opportunity employer and value diversity at our company . We do not discriminate on the basis of race religion colour national origin gender sexual orientation age marital status or disability status . Skills & requirements What we need Your undivided passion energy focus and enthusiasm for both the role and our business . A self-starter attitude with experience managing and prioritising your own workload . An ability to get things done quickly ( whilst maintaining quality); working to a pace . A team-player who works as well with others as well as individually . Strong opinions loosely held - you  ...
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ['passion', 'energy', 'focus', 'enthusiasm', 'self-starter', 'managing and prioritising your own workload', 'get things done quickly ( whilst maintaining quality);', 'working to a pace', 'team-player', 'works as well with others as well as individually', 'contributing ideas', 'participating in discussions with the team', 'take critique', 'self-improve', 'move forward fast', 'open', 'adopt new ways of working', 'giving and receiving feedback', 'always looking for ways to better yourself and company processes', 'live a balanced routine', 'Working remotely', 'Working in a startup environment']
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ['front-end', 'agile', 'css', 'JavaScript', 'Package management', 'Webpack', 'React', 'Redux', 'Test Driven Development', 'HTML', 'CSS', 'Full-stack', 'SaaS', 'Agile Development Principles', 'Pair programming', 'ES6', 'Node.js', 'Content Management Systems', 'marketing technology']
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
#
# Senior Full-Stack Engineer ( m/f/d ) <ORGANIZATION> <ADDRESS> <ADDRESS> <ADDRESS> <ADDRESS> <LOCATION> Date posted: 2021-02-03 Likes: 2 Dislikes: 0 Love: 1 Job description: Location options: Remote Job type: Full-time Experience level: Senior Role: Frontend Developer Full Stack Developer Industry: B2B Computer Software SaaS Company size: 11–50 people Company type: VC Funded Technologies vue.js vuex laravel mysql typescript Job description <ORGANIZATION> is a VC-backed SaaS start-up based in <LOCATION> <LOCATION> but operating globally . Our goal is to transform internal inspections in a massive untapped market which still relies on pen & paper . We enable companies to simplify and digitalize their inspection workflows to improve quality & safety and save time . The Role We are looking for a passionate full-stack engineer who gets the chance to work on all levels of our stack . Our goal for the next 3 months is to make the desktop app more reliable and intuitive while after 3 months you will work with your future colleagues on developing our worldwide unique workflow management system . You will work with our state-of-the-art technology such as functional programming and Typescript . While you should have a knowledge of Typescript functional programming is just a nice-to-have . With our learning culture we want to support your personal and professional growth . We provide a learning budget and reserved every Friday afternoon for acquiring new skills . Just as important by working at <ORGANIZATION> you not only get the chance to develop as an engineer and person but in this early phase of the company you also get the unique opportunity to shape the success of <ORGANIZATION> and our mission: To help millions of employees and organizations exceed their quality promises and make jobs safe . You will work closely together with a highly experienced ever-growing team of engineers: 2 full-stack 1 front-end and 2 native app developers . Our tech stack we use Vue.js Vuex Typescript fp-ts io-ts SCSS PHP 7 Laravel 6 MySQL 8 Docker AWS ( EC2 S3 ) This is how your first weeks could look like Week 1-2: Familiarize yourself with all aspects of <ORGANIZATION> . You will be extensively onboarded and you will have time to settle yourself at <ORGANIZATION> . Week 3-8: You are writing your first lines of code and get your first tasks . Half a day a week you can also train in an area that interests you . You will have constant discussions and feedback with our tech lead <NAME> and daily interaction with the entire development team is routine . You will get familiar with our whole tech stack Month 2-4: By this time you know our system already quite well . You together with the whole team will focus on tasks to improve intuitiveness and reliability of our product to provide the users the best possible experience From month 4: You are ready for the next phase: Building our workflow automation system that will save our Users even more time . After that you will work on new type of inspections like collaborative inspections via Video Tasks in general You are fully involved in all processes and you already understand the <ORGANIZATION> system very well . As always you get completely pre-defined designs by our product designer and well-structured tickets in Jira by our product manager . Collaborate with our QA engineer that will support you with developing reliable code You work at all levels of the stack from PHP and MySQL on the back-end to Vue Typescript SCSS on the front-end You are heavily involved in the end-to-end lifecycle of <ORGANIZATION> features from concept to deployment You take part in a process of conceptualizing and implementing complex new systems focusing not only on performance and scalability but also on crafting a beautiful user experience Requirements 3+ years full-stack engineering experience with PHP SQL and Javascript At least 1 years of experience with Vue.js Vuex Laravel MySQL or with similar frameworks ( React Symfony ) You als ...
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ['passionate', 'developing reliable code', 'conceptualizing and implementing complex new systems', 'crafting a beautiful user experience', 'effectively using indexes', 'optimizing slow queries', 'avoid common problems', 'personal and professional skills', 'result-oriented mindset', 'empathetic']
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ['B2B', 'Computer Software', 'SaaS', 'vue.js', 'vuex', 'laravel', 'mysql', 'typescript', 'functional programming', 'Typescript', 'Typescript', 'functional programming', 'Jira', 'PHP', 'MySQL', 'back-end', 'Vue', 'Typescript', 'SCSS', 'front-end', 'end-to-end lifecycle', 'performance', 'scalability', 'PHP', 'SQL', 'Javascript', 'Vue.js', 'Vuex', 'Laravel', 'MySQL', 'React', 'Symfony )', 'Typescript', 'Vue', 'Composition API', 'fp-ts', 'io-ts', 'Ramda', 'PHP', 'Javascript', 'unit and e2e tests', 'MySQL', 'application architecture design', 'database and API design', 'modern application infrastructure setup', 'Docker)', 'operations', 'monitoring']
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
#
# Full Stack Software Engineer ( JavaScript / React /Node JS ) <ORGANIZATION> <ORGANIZATION> <ORGANIZATION> <ORGANIZATION> <ORGANIZATION> <ADDRESS> <ADDRESS> <LOCATION> - <LOCATION> Date posted: 2021-08-09 Likes: 0 Dislikes: 0 Love: 0 Job description: Job type: Full-time Role: Full Stack Developer Industry: Financial Services Company size: 10k+ people Company type: Public Technologies reactjs javascript node.js Job description <ORGANIZATION> <ORGANIZATION> <ORGANIZATION> is looking full stack JS / React developers to join the global team that is responsible for building Content as a platform Content as a Service and customer personalization engine for all public facing websites for <ORGANIZATION> . The role entails working with marketing and tech teams across <ORGANIZATION> to build and rollout capabilities that will be drive customer engagement on the web platform . As an experienced member of our <ORGANIZATION> <ORGANIZATION> <ORGANIZATION> we look first and foremost for people who are passionate around solving business problems through innovation and engineering practices . You'll be required to apply your depth of knowledge and expertise to all aspects of the software development lifecycle as well as partner continuously with your many stakeholders on a daily basis to stay focused on common goals . We embrace a culture of experimentation and constantly strive for improvement and learning . You'll work in a collaborative trusting thought-provoking environment-one that encourages diversity of thought and creative solutions that are in the best interests of our customers globally . This role requires a wide variety of strengths and capabilities including: * BS/BA degree or equivalent experience * Advanced knowledge of architecture and design across all systems * Proficiency in multiple modern programming languages * Knowledge of industry-wide technology trends and best practices * Ability to work in large collaborative teams to achieve organizational goals * Passionate about building an innovative culture * Experience developing desktop and mobile applications * Familiarity with common stacks * Knowledge of multiple front-end languages and libraries ( e.g . HTML/ CSS JavaScript XML jQuery ) * Knowledge JavaScript frameworks ( e.g . React Node.js ) * Familiarity with databases ( e.g . MySQL MongoDB) web servers ( e.g . Apache ) and UI/UX design <ORGANIZATION> <ORGANIZATION> <ORGANIZATION> is a global leader in financial services providing strategic advice and products to the world's most prominent corporations governments wealthy individuals and institutional investors . Our first-class business in a first-class way approach to serving clients drives everything we do . We strive to build trusted long-term partnerships to help our clients achieve their business objectives . We recognize that our people are our strength and the diverse talents they bring to our global workforce are directly linked to our success . We are an equal opportunity employer and place a high value on diversity and inclusion at our company . We do not discriminate on the basis of any protected attribute including race religion color national origin gender sexual orientation gender identity gender expression age marital or veteran status pregnancy or disability or any other basis protected under applicable law . In accordance with applicable law we make reasonable accommodations for applicants' and employees' religious practices and beliefs as well as any mental health or physical disability needs . Job benefits: Healthcare and Insurance Plans Wellness Programs Maternity and Paternity Leave Adoption Assistance Retirement Savings Programs Paid Time Off Tuition Assistance Access to Arts and Entertainment Program Stock Purchase Plan Charitable Contribution Matching Learning & Development Resources Company description: <DESCRIPTION>
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ['build and rollout capabilities', 'drive customer engagement', 'solving business problems through innovation and engineering practices', 'apply your depth of knowledge and expertise', 'partner continuously with your many stakeholders', 'stay focused on common goals', 'work in large collaborative teams', 'building an innovative culture', 'developing desktop and mobile applications']
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ['Financial Services', 'reactjs', 'javascript', 'node.js', 'BS/BA degree', 'architecture and design across all systems', 'modern programming languages', 'industry-wide technology trends and best practices', 'front-end languages and libraries', 'CSS', 'JavaScript', 'XML', 'jQuery )', 'JavaScript', 'Node.js )', 'databases', 'MongoDB)', 'web servers', 'Apache )', 'UI/UX design']
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
#
# Senior Java Developer <ORGANIZATION> <LOCATION> <LOCATION> <LOCATION> <LOCATION> <LOCATION> <LOCATION> <LOCATION> <LOCATION> Date posted: 2021-04-21 Likes: 0 Dislikes: 0 Love: 0 Job description: Job type: Full-time Experience level: Senior Industry: Charity Non-Profit Publishing Company size: 501–1k people Company type: Private Technologies java kotlin spring-boot tdd amazon-web-services Job description We're looking for an experienced Java Developer to join our fantastic Backend Engineering team at <ORGANIZATION> . It's a pivotal time for Technology at <ORGANIZATION> as we drive forward our ambitious transformation programme putting users at the heart of every product we create evolving our technologies to deliver best in class user experiences . Over the next few years we will be developing both our commercial and advocacy product offering trialing new ways of working driving innovative approaches and introducing cutting edge technology at every opportunity . Despite the current circumstances we are still actively recruiting for roles . In compliance with UK Government advice relating to COVID-19 this role may initially be remotely based in line with the rest of our workforce and we will supply you with the tools and technologies to enable you to work in this way . During this phase interviews will likely be conducted over video conferencing technology e.g . Google Hangouts or similar . What you'll be doing Work as part of a dedicated backend team to deliver resilient and scalable APIs in Kotlin/SpringBoot . Understand business requirements and deliver clean tested and maintainable code Continually aim to improve technical ability through a combination of pairing and self-directed learning Work in an agile environment and contribute to agile ceremonies - standups refinements and retrospectives . Support and mentor other engineers through code reviews and pair programming sessions Support and maintain existing products What's the team like We are a friendly and supportive team . Sharing knowledge collaboration and communication are the core team values . We encourage open communication amongst team members; discuss and embrace ideas on their merit . We have been growing and upgrading our backends recently and hope to learn from your experience of working in challenging environments to deliver optimum well planned out solutions to some interesting problems What we'll need from you Positive attitude and willingness to learn and discover new technologies . With the digital transformation we have some interesting challenges to solve . A proactive problem solver who doesn't mind gathering requirements and business analysis will fit right in . We expect you to be a team player who is happy to discuss and resolve conflicts positively . On the technical front we know that you can spot a pesky bug from a mile away but we also need to see the following experience: In-depth knowledge of Spring Boot and must have used in production environments . Familiarity with the JVM ecosystem in general . Excellent understanding of OO programming techniques and design patterns Experience of using GraphQL in a production environment Experience and familiarity with the docker ecosystem ( e.g . docker-compose ) Previous experience of TDD using JUnit and Mockk Experience in using core development tools such as shell scripting version control ( e.g . Git) CI ( e.g . CircleCI Jenkins ) Experience using AWS EC2 and Elastic Beanstalk RDS SNS/SQS and AWS Lambda . Experience of using gradle as a build tool We'd get really excited if you had experience with: JOOQ PostgreSQL Terraform or Serverless Framework Elasticsearch What we'll offer you We believe in getting the best out of people and our refurbished modern working environment is relaxed and friendly including a subsidised canteen with access to its own roof terrace . There are excellent benefits including 28 days annual leave private healthcare an excellent pension scheme and the usuals like flexible wor ...
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ['deliver resilient and scalable APIs in Kotlin/SpringBoot .', 'deliver clean tested and maintainable code', 'pairing', 'self-directed learning', 'Work in an agile environment', 'contribute to agile ceremonies - standups refinements and retrospectives', 'Support and mentor other engineers', 'Support and maintain existing products', 'Positive attitude', 'learn and discover new technologies', 'proactive', 'problem solver', 'gathering requirements and business analysis', 'team player', 'discuss and resolve conflicts positively', 'spot a pesky bug from a mile away']
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ['Charity', 'Non-Profit', 'Publishing', 'java', 'kotlin', 'spring-boot', 'tdd', 'amazon-web-services', 'Kotlin/SpringBoot .', 'code reviews', 'pair programming sessions', 'Spring Boot', 'production environments', 'JVM ecosystem', 'OO programming techniques and design patterns', 'GraphQL', 'production environment', 'docker ecosystem', 'docker-compose )', 'TDD', 'JUnit', 'Mockk', 'shell scripting', 'version control', 'CI', 'Jenkins )', 'AWS EC2', 'Elastic Beanstalk', 'RDS', 'SNS/SQS', 'AWS Lambda', 'gradle', 'JOOQ', 'PostgreSQL', 'Terraform', 'Serverless Framework', 'Elasticsearch']
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
#
# Software Engineer - Java <ORGANIZATION> <ORGANIZATION> <ORGANIZATION> <ORGANIZATION> <ORGANIZATION> <ADDRESS> <ADDRESS> <LOCATION> - <LOCATION> Date posted: 2021-07-10 Likes: 0 Dislikes: 0 Love: 0 Job description: Job type: Full-time Industry: Financial Services Company size: 10k+ people Company type: Public Technologies cloud java web-services Job description The Digital Event Bus team sits alongside Notifications Metrics and Application Monitoring teams that form the Foundational Services of the Digital Platform . Collectively you will work with your peers and across the Digital Platform which includes other engineers architects designers cyber and product teams to build the best solutions possible . You will help to shape the engineering culture to be centered on collaboration quality and best practice . You will be empowered to make changes to make sure we're building the right software in the right way . Key responsibilities * Design and delivery of the new event bus * Build reusable code and libraries with excellent documentation * Optimize our services to scale from the outset with telemetry * Collaborate with other team members and stakeholders * Coach and mentor less experienced peers * Strive for continuous improvement through active participation in team <ORGANIZATION> <ORGANIZATION> <ORGANIZATION> community and site-wide activities You have: * Strong background in Object Orientated Programming * Strong knowledge of messaging and asynchronous communication * Experience of Cloud Technologies ( e.g . AWS Google Cloud or Azure ) * Experience of Function as a Service * Test driven approach to development * Strong interpersonal and communication skills * NoSQL Database experience ( e.g . Cassandra ) * Continuous Integration/ Continuous Deployment * Knowledge of software design patterns <ORGANIZATION> <ORGANIZATION> <ORGANIZATION> is a global leader in financial services providing strategic advice and products to the world's most prominent corporations governments wealthy individuals and institutional investors . Our first-class business in a first-class way approach to serving clients drives everything we do . We strive to build trusted long-term partnerships to help our clients achieve their business objectives . We recognize that our people are our strength and the diverse talents they bring to our global workforce are directly linked to our success . We are an equal opportunity employer and place a high value on diversity and inclusion at our company . We do not discriminate on the basis of any protected attribute including race religion color national origin gender sexual orientation gender identity gender expression age marital or veteran status pregnancy or disability or any other basis protected under applicable law . In accordance with applicable law we make reasonable accommodations for applicants' and employees' religious practices and beliefs as well as any mental health or physical disability needs . Job benefits: Healthcare and Insurance Plans Wellness Programs Maternity and Paternity Leave Adoption Assistance Retirement Savings Programs Paid Time Off Tuition Assistance Access to Arts and Entertainment Program Stock Purchase Plan Charitable Contribution Matching Learning & Development Resources Company description: <DESCRIPTION>
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ['shape the engineering culture', 'Design', 'delivery', 'Build reusable code and libraries', 'Optimize our services', 'Collaborate with other team members and stakeholders', 'Coach and mentor less experienced peers', 'Strive for continuous improvement', 'Test driven approach to development', 'interpersonal and communication skills']
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ['Financial Services', 'cloud', 'java', 'web-services', 'telemetry', 'Object Orientated Programming', 'messaging', 'asynchronous communication', 'Cloud Technologies', 'Google Cloud', 'Azure )', 'Function as a Service', 'NoSQL Database', 'Cassandra )', 'Continuous Integration/', 'Continuous Deployment', 'software design patterns']
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
#
# Backend Services Engineer <ORGANIZATION> <ORGANIZATION> <ORGANIZATION> <ORGANIZATION> <ORGANIZATION> <ADDRESS> <ADDRESS> <LOCATION> - <LOCATION> Date posted: 2021-01-21 Likes: 0 Dislikes: 0 Love: 0 Job description: Job type: Full-time Role: Backend Developer Industry: Financial Services Company size: 10k+ people Company type: Public Technologies spring java cloud Job description Key responsibilities: • Write well designed secure testable efficient code using best software development practices • Adhere to agile principles and work closely and collaboratively with the wider team • Design and implement cloud native microservices to support the growing capabilities of the mobile stack • Ensure code hygiene and documentation is maintained to the highest levels • Be passionate and your field and keep updated on emerging technologies • Be critical of the design and styling of all components and products and ensure consistency and quality Interested? This is what you will need to have: • Must have experience developing Java based services ( including restful web services ) • Extensive knowledge of cloud native design patterns microservices and twelve-factor application methodology • Experience using Spring Boot Spring Cloud ORM JUnit Maven Jenkins Messaging and Caching • Experience with Linux based environments including shell scripting and basic infrastructure diagnostics • Experience with Apache and Tomcat setup and configuration • Understanding of the mobile development space and some experience in developing responsive web apps . <ORGANIZATION> <ORGANIZATION> <ORGANIZATION> is a global leader in financial services providing strategic advice and products to the world's most prominent corporations governments wealthy individuals and institutional investors . Our first-class business in a first-class way approach to serving clients drives everything we do . We strive to build trusted long-term partnerships to help our clients achieve their business objectives . We recognize that our people are our strength and the diverse talents they bring to our global workforce are directly linked to our success . We are an equal opportunity employer and place a high value on diversity and inclusion at our company . We do not discriminate on the basis of any protected attribute including race religion color national origin gender sexual orientation gender identity gender expression age marital or veteran status pregnancy or disability or any other basis protected under applicable law . In accordance with applicable law we make reasonable accommodations for applicants' and employees' religious practices and beliefs as well as any mental health or physical disability needs . Job benefits: Healthcare and Insurance Plans Wellness Programs Maternity and Paternity Leave Adoption Assistance Retirement Savings Programs Paid Time Off Tuition Assistance Access to Arts and Entertainment Program Stock Purchase Plan Charitable Contribution Matching Learning & Development Resources Company description: <DESCRIPTION>
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ['Write well designed secure testable efficient code', 'Adhere to agile principles', 'work closely and collaboratively with the wider team', 'Design and implement cloud native microservices', 'support the growing capabilities of the mobile stack', 'Ensure code hygiene and documentation is maintained', 'passionate and your field', 'keep updated on emerging technologies', 'critical of the design and styling of all components and products', 'ensure consistency and quality', 'developing Java based services', 'developing responsive web apps .']
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ['Financial Services', 'spring', 'java', 'cloud', 'best software development practices', 'Java', 'restful web services )', 'cloud native design patterns', 'microservices', 'twelve-factor application methodology', 'Spring Boot', 'Spring Cloud', 'ORM', 'JUnit', 'Maven', 'Jenkins', 'Messaging', 'Caching', 'Linux based environments', 'shell scripting', 'basic infrastructure diagnostics', 'Apache', 'Tomcat', 'mobile development space', 'responsive web apps .']
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
#
# Head of IT ( m/f/d ) <ORGANIZATION> <LOCATION> <LOCATION> <LOCATION> <LOCATION> <LOCATION> <LOCATION> Date posted: 2021-03-23 Likes: 0 Dislikes: 0 Love: 0 Job description: Job type: Full-time Experience level: Senior Lead Role: DevOps System Administrator Industry: IT Security Software Development Company size: 51–200 people Technologies security infrastructure iam pki configurationmanager sysadmin Job description About us: Would you like to work in a technology-driven scale up where you can make an actual impact? <ORGANIZATION> is one of <LOCATION> most successful cyber security scale ups with strong international growth and an upper management with technical expertise . Our unique technology and innovative products secure numerous government and corporate networks all over the world effectively against cyberattacks . We protect the data brands and values of our customers worldwide and help to make the online world a safer place . Why you should join: Do you think a company’s IT department plays a crucial role in enabling growth? Do you want to build secure and maintain an environment in which modern technology and tools foster frictionless operations within the company? Do you enjoy building your own infrastructure where necessary and using the Cloud where it makes sense? Being the proxy that translates people’s needs and expectations into actionable technical tasks is your thing? Then we should talk! Your tasks: You lead and develop <ORGANIZATION> IT team You are responsible for our global IT operations You strive to advance the organization’s IT strategy and work on continuous improvements while taking technical financial and security aspects into account You plan and ensure resource availability for timely fixes of IT infrastructure issues You operate company DNS website hosting and email infrastructure You establish IT processes and automations according to common best practices You as an important decision maker work together with all departments of the company to ensure everybody has the tools they need to maximize their productivity You are responsibile to create update implement and communicate internal policies and procedures to ensure the company’s and its customers’ high security standards are met You are engaged in the establishment and maintenance of our ISO 27001 certification Our requirements: Bachelor’s or Master’s degree in the IT field 5+ years of working experience in an international IT role Very Good experience with and knowledge of recent technologies for Infrastructure IAM PKI Configuration Management Security Logging & Monitoring Leadership experience Excellent interpersonal skills and the ability to work together with all departments of the company in an international context Pragmatic and solution-oriented way of working Good communication skills Fluent in German and English ( verbal and written ) What we offer: <ORGANIZATION> offers a chance to be part of a fast-growing company many different career development possibilities a friendly and open work atmosphere flexible working times and various benefits . If you are looking for an unique opportunity to continuously develop yourself learn from security experts and work with cutting edge technology apply now! You can send also send us your application directly to <CONTACT> <CONTACT> . Job benefits: Flexible working hours with home office opportunities Diversity Weekly sport activities Regular team events Extended Training opportunities and mentoring program Daily fresh breakfast/hot & cold drinks International presence and exposure Working together with leading security experts Cutting-edge in-house technology Modern and independent workspaces Company description: Wir sind ein global agierendes IT-Unternehmen aus dem Herzen des Ruhrgebiets und entwickeln innovative Sicherheitslösungen zur Erkennung und Abwehr von Cyberangriffen . Unsere einzigartige Hypervisor-Technologie ermöglicht eine überwindungssichere Sandbox-Analyse unbekannter Dateien und ist ...
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ['build secure and maintain an environment in which modern technology and tools foster frictionless operations within the company?', 'building your own infrastructure', 'using the Cloud', 'translates people’s needs and expectations into actionable technical tasks', 'lead', 'develop', 'responsible for our global IT operations', 'strive to advance the organization’s IT strategy', 'work on continuous improvements', 'taking technical financial and security aspects into account', 'plan and ensure resource availability for timely fixes of IT infrastructure issues', 'operate company DNS website hosting and email infrastructure', 'establish IT processes and automations according to common best practices', 'work together with all departments', 'ensure everybody has the tools they need to maximize their productivity', 'responsibile', 'create update implement and communicate internal policies and procedures', 'interpersonal skills', 'work together with all departments of the company', 'Pragmatic', 'solution-oriented', 'communication skills', 'German', 'English']
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ['IT Security', 'Software Development', 'security', 'infrastructure', 'iam', 'pki', 'configurationmanager', 'sysadmin', 'IT infrastructure', 'DNS', 'website hosting', 'email infrastructure', 'ISO 27001 certification', 'Bachelor’s or Master’s degree in the IT field', 'international IT', 'Infrastructure', 'IAM', 'PKI', 'Configuration Management', 'Security', 'Logging', 'Monitoring']
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
#
# Senior Product Security Engineer <ORGANIZATION> <ORGANIZATION> <ADDRESS> <ADDRESS> <ADDRESS> <ADDRESS> <LOCATION> Date posted: 2021-01-01 Likes: 0 Dislikes: 0 Love: 0 Job description: Compensation: £60k - 80k Location options: Remote Paid relocation Job type: Full-time Experience level: Senior Lead Industry: Information Technology Newspapers Publishing Company size: 1k–5k people Company type: Private Technologies security amazon-web-services cloud Job description We are: <ORGANIZATION> <ORGANIZATION> is a company full of talented dedicated and creative people . We are an ambitious and ever-growing organisation with a passion for storytelling capturing moments meaning and magic to make sense of the world . Our newspapers reach more than 30 million people each week and include <ORGANIZATION> <ORGANIZATION> <ORGANIZATION> <ORGANIZATION> and <ORGANIZATION> <ORGANIZATION> <ORGANIZATION> . <ORGANIZATION> <ORGANIZATION> is also home to <ORGANIZATION> a leading <LOCATION> and <LOCATION> media company boasting independent local and national radio stations including <ORGANIZATION> <ORGANIZATION> <ORGANIZATION> and <ORGANIZATION> <ORGANIZATION> . We are <ORGANIZATION> <ORGANIZATION> a shared technology division of <ORGANIZATION> <ORGANIZATION> providing both digital applications websites and IT solutions across <ORGANIZATION> <ORGANIZATION> <ORGANIZATION> <ORGANIZATION> <ORGANIZATION> <ORGANIZATION> <ORGANIZATION> <ORGANIZATION> <ORGANIZATION> <ORGANIZATION> <ORGANIZATION> and <ORGANIZATION> . <ORGANIZATION> operates globally with the aim of optimizing technology needs for <ORGANIZATION> <ORGANIZATION> companies so they can focus on what they do best . Your role: As a Senior Product Security Engineer you will be joining our shared cyber services department . Where you will be working with a modern cloud based ( AWS ) tech stack alongside our talented team of engineers reviewing all of our world class products across our diverse brands ensuring their protection . You will be able to recognise risk design preventative or detective controls and have experience in automation . Day to day you will: Help build maintain and execute a strategy to secure our customer-facing products Perform security reviews and code reviews of our products whilst overseeing our Agile-SDL process ensuring security throughout all phases of the SDL Serve as the security SME for product engineering teams Develop threat models for new and updated products as well as designing preventative and/or detective controls for specific security issues . Socialise automated security tools and guide product engineering teams to integrate these within their CI/CD workflows and test environments Work with members of security intelligence and response team to integrate security monitoring of products and build use cases Work with members of security engineering team to develop evangelise security solutions that solve security challenges that engineering teams face . What we’re looking for from you: You will have experience with application design & architecture using modern design patterns You will have previously worked with cloud security technologies particularly AWS You will thrive working in a Dev/Sec Ops culture You will enjoy working with a modern tech stack and have knowledge of modern languages/frameworks - HTML5 Ruby node.js JavaScript PHP Python Java You will have an understanding of application security topics such as authn authz encryption session management federation Ability to communicate complicated technical issues and risks to engineers project managers and product managers You will be an expert of application security attacks Check out our latest blogs What's in it for you? We are a diverse and dynamic team with opportunities to learn and develop your skills in a supportive environment . We have an amazing office a flexible working pattern and a great team culture . We’ll help you deliver your best work and grow you with career and personal development through t ...
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ...
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ['contributing to core software components', 'develop high-quality software', 'constantly learn', 'balancing innovation and pragmatism', 'striving for simplicity and high quality', 'care about clarity:', 'building tests', 'take ownership of the machine firmware domain;', 'understanding the various architectures;', 'deliver on product requirements and features;', 'improving testability and functionality', 'participate in the service duty rotation;', 'assist with any issues that are reported']
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ['kubernetes', 'docker', 'linux', 'google-cloud-platform', 'C++', 'embedded linux systems', 'IoT cloud infrastructure', 'agile development', 'architecture design', 'planning', 'testing', 'documentation', 'deployment', 'Embedded Systems', 'modern C++', 'software development', 'embedded ecosystem', 'Real-time operating systems', 'Firmware development', 'C/C++', 'GCC', 'Clang', 'Keil', 'Yocto', 'Linux ARM', 'SoC’s', 'Digital Signal Processing', 'Modern Control Systems', 'scripting languages', 'Bash', 'Python', 'build tooling', 'CMake', 'code commits documentation and communication', 'automated testing', 'machine firmware', 'English', 'C', 'C++17/20', 'Rust', 'Go', 'Kubernetes', 'Docker', 'GCP']
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
#
# Quality Assurance Engineer ( f/m/d ) <ORGANIZATION> <ORGANIZATION> <ORGANIZATION> <ORGANIZATION> <ADDRESS> <ADDRESS> <LOCATION> - <LOCATION> Date posted: 2021-07-26 Likes: 0 Dislikes: 0 Love: 0 Job description: Compensation: Equity Location options: Paid relocation Job type: Full-time Experience level: Mid-Level Role: QA/Test Developer Industry: Digital Health Mobile Application Music Company size: 51-200 people Technologies qa testing selenium java python Job description ABOUT <LOCATION> Our mission at <ORGANIZATION> is to give everyone the best possible hearing experience . We are the world’s leading provider of hearing-based audio personalization and digital hearing test technologies . Our team has developed a biologically-inspired and proprietary audio processing technology that knows how well you hear in order to personalize your listening experience . <ORGANIZATION> technology can be integrated into consumer electronics devices such as headphones smartphones TVs in-flight entertainment systems and a range of systems and platforms . To help us bring amazing hearing technology to more people around the world we are looking for a Quality Assurance Engineer ( f/m/d ) for full-time employment in <LOCATION> . WHAT YOU WILL DO Work on hearing test and audio personalization technology testing our iOS and Android audio SDK and its integration into both internal and third-party system platforms Plan conduct and document test cases to ensure product quality and compliance with high-level software requirements Develop and execute manual and automated tests for our existing products and new features Take responsibility for developing standards and procedures to conclude high software quality and release readiness Create clear and concise bug reports with sufficient information for the developers to work on resolving the bug in a timely manner Work closely with product management and development to evaluate findings Continuously improve test coverage and quality standards WHAT YOU BRING TO THE TABLE: Computer Science Computer Engineering or an equivalent engineering degree 3+ years of experience in mobile testing integration testing or similar Have a strong voice to drive and manage quality assurance tasks and projects end to end Excellent knowledge of software development lifecycle testing methodologies and testing tools Experience in backend communication protocols such as APIs and web services Strong knowledge of software QA metrics operations and statistics Experience with at least one programming language such as Python / Java / Ruby etc Detail-oriented analytical and creative thinker with a passion for quality processes Fluent in English Good to have Experience in System Integration Testing embedded systems or integrated devices Comfortable with a dynamic fast-moving and entrepreneurial environment Previous experience with an agile development process Basic working knowledge of shell scripting and various Unix command line tools Knowledge of test automation frameworks ( eg Appium Selenium ) Knowledge of version control systems such as GIT or similar tools WHAT WE OFFER A top-caliber diverse and international team of dedicated domain experts Flexible working and full responsibility for your own projects Remote working opportunities and equipment Yearly education budget and a company culture that nourishes personal growth Modern working equipment plus plenty of audio perks and cool toys to try out Weekly company meals team-building events and an annual summer trip Flexible holiday policy Monthly <ORGANIZATION> credit The opportunity to make an impact on an untapped market and contribute to the development of a truly innovative product and company Find out more about us on our website: <CONTACT> DISCLAIMER We know that some people have a tendency not to apply to jobs unless they meet 100% of the requirements . However if you think that this job is great for you then please send in your application! Job benefits: Flexible working ho ...
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ['Plan conduct and document test cases', 'ensure product quality and compliance with high-level software requirements', 'Develop and execute manual and automated tests', 'Take responsibility for developing standards and procedures', 'conclude high software quality and release readiness', 'Create clear and concise bug reports', 'resolving the bug in a timely manner', 'Work closely with product management and development', 'evaluate findings', 'Continuously improve test coverage and quality standards', 'strong voice', 'drive and manage quality assurance tasks and projects end to end', 'analytical', 'creative thinker', 'Comfortable with a dynamic fast-moving and entrepreneurial environment']
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ['Digital Health', 'Mobile Application', 'Music', 'testing', 'selenium', 'java', 'python', 'hearing test', 'audio personalization technology', 'iOS and Android audio SDK', 'Computer Science', 'Computer Engineering', 'mobile testing', 'integration testing', 'quality assurance', 'software development lifecycle', 'testing methodologies', 'testing tools', 'backend communication protocols', 'APIs', 'web services', 'software QA metrics operations', 'statistics', 'Python', 'Java', 'Ruby', 'quality processes', 'English', 'System Integration Testing', 'embedded systems', 'integrated devices', 'agile development process', 'shell scripting', 'Unix command line tools', 'test automation frameworks', 'Appium', 'Selenium', 'version control systems', 'GIT']
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
#
# Senior Frontend Developer | React JS Developer f/m/x <ORGANIZATION> <LOCATION> <LOCATION> <LOCATION> <LOCATION> <LOCATION> - <LOCATION> Date posted: 2021-04-21 Likes: 0 Dislikes: 0 Love: 0 Job description: Location options: Visa sponsor Job type: Full-time Role: Frontend Developer Technologies reactjs javascript frontend react-fullstack web-applications Job description Senior Frontend | React JS Developer | UI f/m/x - Full-time contract | <LOCATION> ( <LOCATION> ) / Remote | Start date: As soon as possible We’re a fast-growing Berlin-based HR-tech software company . Our mission is to provide the only software businesses need to manage their human resources . Our goal is to help companies save time and focus on what they do best . We connect all separate HR processes into a single and easy-to-use platform and help HR managers and supervisors in their daily office life . To date more than 1,300 customers use our innovative product . We're looking for an experienced smart and motivated Senior Frontend Developer f/m/x to join our team who enjoys working in a start-up environment and develops HR software our customers love . Current information on the application process Our team is currently working remotely due to the pandemic . To make sure everyone stays secure we have adapted the application process to the recent conditions and conduct our interviews by video telephone and occasionally in person - in compliance with the necessary distance and hygiene rules . For further information please contact our recruiting team . We wish you much success with your application . Take care of yourself and stay healthy! What you’ll do: Write and test high-quality maintainable code Scope design and own project delivery Ensure accessibility usability and performance of our application Collaborate well with others be a great teammate Be ready to adapt and pitch in on other projects as needed Build an excellent product on a technical and qualitative level Optimise website responsiveness for mobile and tablet Partner with our management developers product managers and other stakeholders You’re up to date with the world’s newest technologies and keen to implement and evolve them with us About You: Bachelor's and/or Master's in Computer Science or a similar technical field of study You are experienced in building web applications and have ideally worked on similar projects in the past Very good JavaScript knowledge in particular React JS Experience with modern web architectures and server side rendering Working experience in CI/CD is a plus You are solution oriented adaptable to change and have a strong sense ownership Passionate about HR and creating a platform that automatises workflows Working proficiency and communication skills in verbal and written English Why join our team? Regular virtual meetings and feedback sessions Diverse international and family-like work environment where everyone knows each other A choice to work from Mac or Linux Extra paid holiday time Competitive salary A range of great employee benefits including a company supported retirement plan The ability to either work remotely or be based in our office in <LOCATION> once the pandemic is over Opportunity to build a great HR software that our customers love whilst reducing our footprint Want to relocate to <LOCATION> and work remotely? Go ahead we’ll support you in the process and make your wish come true . Sounds like a good fit? Great! Please apply via the provided link . If you have any questions feel free to get in touch with our HR team . You can get in touch with our Recruiter <NAME> or <NAME> our Head of HR . We can't wait to hear from you! Job benefits: - Company description: We’re a fast-growing <LOCATION> HR-tech software company Our mission is to provide the only software businesses need to manage their human resources Our goal is to help companies save time and focus on what they do best We connect all separate HR processes into a single and easy-to-use platform ...
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ['experienced', 'smart', 'motivated', 'working in a start-up environment', 'develops HR software', 'Write and test high-quality maintainable code', 'Scope design', 'own project delivery', 'Ensure accessibility usability and performance of our application', 'Collaborate well with others', 'great teammate', 'pitch in on other projects', 'Build an excellent product on a technical and qualitative level', 'Optimise website responsiveness', 'Partner with our management developers product managers and other stakeholders', 'building web applications', 'solution oriented', 'adaptable', 'strong sense ownership', 'creating a platform that automatises workflows', 'communication skills']
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ['javascript', 'frontend', 'react-fullstack', 'web-applications', 'HR software', 'mobile', 'tablet', "Master's", 'Computer Science', 'JavaScript', 'React JS', 'modern web architectures', 'server side rendering', 'CI/CD', 'HR', 'English', 'HR software']
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
#       ...
# 75    None
# 76    None
# 77    None
# 78    None
# 79    None
# Length: 80, dtype: object
